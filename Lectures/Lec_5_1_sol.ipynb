# %% [markdown]
# # Lecture 5.1 More plotting and statistics

# %% [markdown]
# Sep 24, 2019

# %% [markdown]
# ## Announcements

# %% [markdown]
# ### 1. Bring headphones next time!
#
# We are doing a pandas tutorial:
#
# https://github.com/justmarkham/pycon-2019-tutorial
#
# ### 2. New: grading warm-up exercises as assignments
# If you don’t finish, go back and correct your work.
# Grades will be up on blackboard in the next week

# %% [markdown]
# ## Warm-up

# %% [markdown]
# Using the hares/carrots/lynxes data set we used last week, plot the data in one plot with three different subplots, each with a different lifestyle or color. Label your subplots appropriately.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = np.loadtxt('populations.txt')

# %%
data
# Out:
# array([[ 1900., 30000.,  4000., 48300.],
#        [ 1901., 47200.,  6100., 48200.],
#        [ 1902., 70200.,  9800., 41500.],
#        [ 1903., 77400., 35200., 38200.],
#        [ 1904., 36300., 59400., 40600.],
#        [ 1905., 20600., 41700., 39800.],
#        [ 1906., 18100., 19000., 38600.],
#        [ 1907., 21400., 13000., 42300.],
#        [ 1908., 22000.,  8300., 44500.],
#        [ 1909., 25400.,  9100., 42100.],
#        [ 1910., 27100.,  7400., 46000.],
#        [ 1911., 40300.,  8000., 46800.],
#        [ 1912., 57000., 12300., 43800.],
#        [ 1913., 76600., 19500., 40900.],
#        [ 1914., 52300., 45700., 39400.],
#        [ 1915., 19500., 51100., 39000.],
#        [ 1916., 11200., 29700., 36700.],
#        [ 1917.,  7600., 15800., 41800.],
#        [ 1918., 14600.,  9700., 43300.],
#        [ 1919., 16200., 10100., 41300.],
#        [ 1920., 24700.,  8600., 47300.]])

# %%
data.T
# Out:
# array([[ 1900.,  1901.,  1902.,  1903.,  1904.,  1905.,  1906.,  1907.,
#          1908.,  1909.,  1910.,  1911.,  1912.,  1913.,  1914.,  1915.,
#          1916.,  1917.,  1918.,  1919.,  1920.],
#        [30000., 47200., 70200., 77400., 36300., 20600., 18100., 21400.,
#         22000., 25400., 27100., 40300., 57000., 76600., 52300., 19500.,
#         11200.,  7600., 14600., 16200., 24700.],
#        [ 4000.,  6100.,  9800., 35200., 59400., 41700., 19000., 13000.,
#          8300.,  9100.,  7400.,  8000., 12300., 19500., 45700., 51100.,
#         29700., 15800.,  9700., 10100.,  8600.],
#        [48300., 48200., 41500., 38200., 40600., 39800., 38600., 42300.,
#         44500., 42100., 46000., 46800., 43800., 40900., 39400., 39000.,
#         36700., 41800., 43300., 41300., 47300.]])

# %%
year, hares, lynxes, carrots = data.T

# %%
year = data[:,0]
hares = data[:,1]

# %%
plt.plot(year,hares, label = 'Hares')
plt.plot(year, lynxes, label = 'Lynxes')
plt.plot(year,carrots, label = 'Carrots')
plt.legend()

# %%
# trick to change the plotting settings:
import matplotlib as mpl
mpl.rcParams['font.size'] = 16
mpl.rcParams['lines.linewidth']= 2.0

# %%
#plt.figure(figsize = (6,4))
plt.plot(year,hares, label = 'Hares')
plt.plot(year, lynxes, label = 'Lynxes')
plt.plot(year,carrots, label = 'Carrots')
plt.legend(loc = 'upper right', fontsize = 12)
plt.xlabel('Years')
plt.ylabel('Population')
# Out:
# Text(0, 0.5, 'Population')

# %%
fig = plt.figure(figsize = (16,4)) # play around until it looks good
# make a handle for the whole figure "fig"

plt.subplot(1,3,1) # rows, columns, which one to plot in
plt.plot(year,hares/1000, color = 'brown', label = "Hares")
plt.xlabel('Years', fontsize = 18)
plt.title('Hares (thousands)')
plt.ylim([0, 80])
plt.ylabel('Population', fontsize = 18)

plt.subplot(1,3,2)
plt.plot(year,lynxes/1000, color = 'black', label = 'Lynxes')
plt.xlabel('Years', fontsize = 18)
plt.title('Lynxes')
plt.ylim([0, 80])

plt.subplot(1,3,3)
plt.plot(year, carrots/1000, 'green', label = 'Carrots')
plt.xlabel('Years', fontsize = 18)
plt.title('Carrots')
plt.ylim([0, 80])

#plt.suptitle('Title for the whole plot')

fig.legend()

# %% [markdown]
# ## Lecture Examples

# %% [markdown]
# * Go over hares/carrots/lynxes homework problem (scipy 1.3.15.3)
#
# Didn't get to, moved to 6.1:
# * Plot y = sin(x) on -pi to pi
#     * Go over linespace
#     * Turn the grid on
# * Create a color plot of z = sin(x)sin(y) on the interval [−π,π]×[−π,π][−π,π]×[−π,π].
# * Plot an Archimedean spiral (https://en.wikipedia.org/wiki/Archimedean_spiral)
# *     Note this involves translating some r code into python

# %% [markdown]
# ### Go over hares/carrots/lynxes homework problem (scipy 1.3.15.3)

# %% [markdown]
# ### First load the data

# %%
year, hares, lynxes, carrots = data.T
populations = data[:,1:] # getting rid of the first column of year data

# %%
data[:, 1:]
# Out:
# array([[30000.,  4000., 48300.],
#        [47200.,  6100., 48200.],
#        [70200.,  9800., 41500.],
#        [77400., 35200., 38200.],
#        [36300., 59400., 40600.],
#        [20600., 41700., 39800.],
#        [18100., 19000., 38600.],
#        [21400., 13000., 42300.],
#        [22000.,  8300., 44500.],
#        [25400.,  9100., 42100.],
#        [27100.,  7400., 46000.],
#        [40300.,  8000., 46800.],
#        [57000., 12300., 43800.],
#        [76600., 19500., 40900.],
#        [52300., 45700., 39400.],
#        [19500., 51100., 39000.],
#        [11200., 29700., 36700.],
#        [ 7600., 15800., 41800.],
#        [14600.,  9700., 43300.],
#        [16200., 10100., 41300.],
#        [24700.,  8600., 47300.]])

# %% [markdown]
# ### 1. Compute and print the mean and std of the populations of each species for the years in the period.

# %%
print("       Hares, Lynxes, Carrots")
print("Mean:", populations.mean(axis=0)) # the first axis is time
print("Std:", populations.std(axis=0))
# Out:
#        Hares, Lynxes, Carrots
# Mean: [34080.95238095 20166.66666667 42400.        ]
# Std: [20897.90645809 16254.59153691  3322.50622558]

# %%
np.mean(populations, axis = 0) # take the mean along the time axis
# Out:
# array([34080.95238095, 20166.66666667, 42400.        ])

# %%
np.mean(hares)
# Out:
# 34080.95238095238

# %%
np.mean(lynxes)
# Out:
# 20166.666666666668

# %% [markdown]
# ### 2. Which year did each species had the largest population?

# %%
# argmax Returns the indices of the maximum values along an axis.
j_max_years = np.argmax(populations, axis=0)
print("Max. year (hares, lynxes, carrots):", year[j_max_years])
# Out:
# Max. year (hares, lynxes, carrots): [1903. 1904. 1900.]

# %%
# get the index for the maximum for each population
np.argmax(populations, axis=0)
# hares are max at index 3
# lynxes at index 4
# carrots at index 0
# check with plots, looks good
# Out:
# array([3, 4, 0])

# %%
max_ind = np.argmax(populations, axis=0)

# %%
# pass max index to years array
year[max_ind]
# Out:
# array([1903., 1904., 1900.])

# %% [markdown]
# ### 3. Which species has the largest population for each year. (Hint: argsort & fancy indexing of np.array(['H', 'L', 'C']))

# %%
populations
# Out:
# array([[30000.,  4000., 48300.],
#        [47200.,  6100., 48200.],
#        [70200.,  9800., 41500.],
#        [77400., 35200., 38200.],
#        [36300., 59400., 40600.],
#        [20600., 41700., 39800.],
#        [18100., 19000., 38600.],
#        [21400., 13000., 42300.],
#        [22000.,  8300., 44500.],
#        [25400.,  9100., 42100.],
#        [27100.,  7400., 46000.],
#        [40300.,  8000., 46800.],
#        [57000., 12300., 43800.],
#        [76600., 19500., 40900.],
#        [52300., 45700., 39400.],
#        [19500., 51100., 39000.],
#        [11200., 29700., 36700.],
#        [ 7600., 15800., 41800.],
#        [14600.,  9700., 43300.],
#        [16200., 10100., 41300.],
#        [24700.,  8600., 47300.]])

# %%
# get the index for the poplulation that is largest each year
max_species_ind = np.argmax(populations, axis = 1)

# %%
max_species_ind
# Out:
# array([2, 2, 0, 0, 1, 1, 2, 2, 2, 2, 2, 2, 0, 0, 0, 1, 2, 2, 2, 2, 2])

# %%
# make an array of names
species = np.array(['Hare', 'Lynx', 'Carrot'])

# %%
print("Max species:")
print(year)
print(species[max_species_ind])
# Out:
# Max species:
# [1900. 1901. 1902. 1903. 1904. 1905. 1906. 1907. 1908. 1909. 1910. 1911.
#  1912. 1913. 1914. 1915. 1916. 1917. 1918. 1919. 1920.]
# ['Carrot' 'Carrot' 'Hare' 'Hare' 'Lynx' 'Lynx' 'Carrot' 'Carrot' 'Carrot'
#  'Carrot' 'Carrot' 'Carrot' 'Hare' 'Hare' 'Hare' 'Lynx' 'Carrot' 'Carrot'
#  'Carrot' 'Carrot' 'Carrot']

# %% [markdown]
# ### 4. Which years any of the populations is above 50000. (Hint: comparisons and np.any)

# %%
np.where(populations>50000)
# Out:
# (array([ 2,  3,  4, 12, 13, 14, 15]), array([0, 0, 1, 0, 0, 0, 1]))

# %%
iyear, ipop = np.where(populations>50000)
# note this gives back to arrays, one with the time index and one with the population index

# %%
populations[iyear,ipop] # check to see that this is correct
# Out:
# array([70200., 77400., 59400., 57000., 76600., 52300., 51100.])

# %%
# print out which year and for which population
print('Years where pouplation was over 50000 and for which species:')
print(year[iyear])
print(species[ipop])
# Out:
# Years where pouplation was over 50000 and for which species
# [1902. 1903. 1904. 1912. 1913. 1914. 1915.]
# ['Hare' 'Hare' 'Lynx' 'Hare' 'Hare' 'Hare' 'Lynx']

# %% [markdown]
# ### 5. The top 2 years for each species when they had the lowest populations. (Hint: argsort, fancy indexing)

# %%
hares
# Out:
# array([30000., 47200., 70200., 77400., 36300., 20600., 18100., 21400.,
#        22000., 25400., 27100., 40300., 57000., 76600., 52300., 19500.,
#        11200.,  7600., 14600., 16200., 24700.])

# %%
np.argsort(hares) # 0 is the index of the lowest, 1 the next, etc
# Out:
# array([17, 16, 18, 19,  6, 15,  5,  7,  8, 20,  9, 10,  0,  4, 11,  1, 14,
#        12,  2, 13,  3])

# %%
hares[np.argsort(hares)] # puts the population data in ascending order
# Out:
# array([ 7600., 11200., 14600., 16200., 18100., 19500., 20600., 21400.,
#        22000., 24700., 25400., 27100., 30000., 36300., 40300., 47200.,
#        52300., 57000., 70200., 76600., 77400.])

# %%
hares[np.argsort(hares)][0] # gets the first index, i.e. the lowest population value
# Out:
# 7600.0

# %%
year[np.argsort(hares)][0] # gets the year of the lowest population value
# Out:
# 1917.0

# %%
year[np.argsort(hares)][0]
# Out:
# 1917.0

# %%
print('Lowest hare popuations: ')
print('Year: ' + str(year[np.argsort(hares)][0]) + 
        ' Population: ' + str(hares[np.argsort(hares)][0]))
print('Year: ' + str(year[np.argsort(hares)][1]) +
       ' Population: ' + str(hares[np.argsort(hares)][1]))
# Out:
# Lowest hare popuations:
# Year: 1917.0 Population: 7600.0
# Year: 1916.0 Population: 11200.0

# %% [markdown]
# Similar for lynxes and carrots

# %%
print('Lowest lynx popuations: ')
print('Year: ' + str(year[np.argsort(lynxes)][0]) + 
        ' Population: ' + str(lynxes[np.argsort(lynxes)][0]))
print('Year: ' + str(year[np.argsort(lynxes)][1]) +
       ' Population: ' + str(lynxes[np.argsort(lynxes)][1]))

print('Lowest carrot popuations: ')
print('Year: ' + str(year[np.argsort(carrots)][0]) + 
        ' Population: ' + str(carrots[np.argsort(carrots)][0]))
print('Year: ' + str(year[np.argsort(carrots)][1]) +
       ' Population: ' + str(carrots[np.argsort(carrots)][1]))
# Out:
# Lowest lynx popuations:
# Year: 1900.0 Population: 4000.0
# Year: 1901.0 Population: 6100.0
# Lowest carrot popuations:
# Year: 1916.0 Population: 36700.0
# Year: 1903.0 Population: 38200.0

# %%
# check (note the first time I did this check I realized I had errors above):
lynxes
# now looks good
# Out:
# array([ 4000.,  6100.,  9800., 35200., 59400., 41700., 19000., 13000.,
#         8300.,  9100.,  7400.,  8000., 12300., 19500., 45700., 51100.,
#        29700., 15800.,  9700., 10100.,  8600.])

# %%
carrots
# looks good
# Out:
# array([48300., 48200., 41500., 38200., 40600., 39800., 38600., 42300.,
#        44500., 42100., 46000., 46800., 43800., 40900., 39400., 39000.,
#        36700., 41800., 43300., 41300., 47300.])

# %% [markdown]
# ### 6. Compare (plot) the change in hare population (see help(np.gradient)) and the number of lynxes. Check correlation (see help(np.corrcoef))

# %%
hares
# Out:
# array([30000., 47200., 70200., 77400., 36300., 20600., 18100., 21400.,
#        22000., 25400., 27100., 40300., 57000., 76600., 52300., 19500.,
#        11200.,  7600., 14600., 16200., 24700.])

# %%
np.gradient(hares)
# this is a rate, population change per year
# Out:
# array([ 17200.,  20100.,  15100., -16950., -28400.,  -9100.,    400.,
#          1950.,   2000.,   2550.,   7450.,  14950.,  18150.,  -2350.,
#        -28550., -20550.,  -5950.,   1700.,   4300.,   5050.,   8500.])

# %%
plt.plot(np.gradient(hares), label = 'hares grad')
plt.plot(lynxes, label = 'lynxes')
plt.legend(loc = 'upper center')
# these appear to be anti-correlated, when lynxes go up, the hares gradient goes down (i.e. decreases)

# %%
plt.scatter(np.gradient(hares),lynxes)
# that's a pretty good correlation
plt.xlabel('Hares gradient (hares/year)')
plt.ylabel('Lynxes')
plt.title('r = -0.92')
# Out:
# Text(0.5, 1.0, 'r = -0.92')

# %%
np.corrcoef(np.gradient(hares), lynxes)
# the number we want is the -0.92
# Out:
# array([[ 1.        , -0.91792485],
#        [-0.91792485,  1.        ]])

# %%
# note the gradient is the slope at each point`
help(np.gradient)
# Out:
# Help on function gradient in module numpy:
#
# gradient(f, *varargs, **kwargs)
#     Return the gradient of an N-dimensional array.
#
#     The gradient is computed using second order accurate central differences
#     in the interior points and either first or second order accurate one-sides
#     (forward or backwards) differences at the boundaries.
#     The returned gradient hence has the same shape as the input array.
#
#     Parameters
#     ----------
#     f : array_like
#         An N-dimensional array containing samples of a scalar function.
#     varargs : list of scalar or array, optional
#         Spacing between f values. Default unitary spacing for all dimensions.
#         Spacing can be specified using:
#
#         1. single scalar to specify a sample distance for all dimensions.
#         2. N scalars to specify a constant sample distance for each dimension.
#            i.e. `dx`, `dy`, `dz`, ...
# ...

# %% [markdown]
# ## Scratch

# %%
np.argmax(hares)
# Out:
# 3

# %%
hares # index 3 is the largest value
# Out:
# array([30000., 47200., 70200., 77400., 36300., 20600., 18100., 21400.,
#        22000., 25400., 27100., 40300., 57000., 76600., 52300., 19500.,
#        11200.,  7600., 14600., 16200., 24700.])

# %%
hares[3]
# Out:
# 77400.0

# %%
#year[3] # the year the maximum value occured
year[np.argmax(hares)] 
# use the index from the argmax function to find the year the hare popul.
# was at the maximum
# Out:
# 1903.0

# %%
np.argmax?
# Out:
# Signature: np.argmax(a, axis=None, out=None)
# Docstring:
# Returns the indices of the maximum values along an axis.
#
# Parameters
# ----------
# a : array_like
#     Input array.
# axis : int, optional
#     By default, the index is into the flattened array, otherwise
#     along the specified axis.
# out : array, optional
#     If provided, the result will be inserted into this array. It should
#     be of the appropriate shape and dtype.
#
# Returns
# -------
# index_array : ndarray of ints
#     Array of indices into the array. It has the same shape as `a.shape`
#     with the dimension along `axis` removed.
#
# See Also
# --------
# ndarray.argmax, argmin
# amax : The maximum value along a given axis.
# unravel_index : Convert a flat index into an index tuple.
#
# Notes
# -----
# In case of multiple occurrences of the maximum values, the indices
# corresponding to the first occurrence are returned.
#
# Examples
# --------
# >>> a = np.arange(6).reshape(2,3) + 10
# >>> a
# ...

# %% [markdown]
# ## Exercise 1 (Saved for Lec. 6.1)

# %% [markdown]
# Plot a logarithmic spiral (google it)

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# Plot the hares/carrots/lynxes data as three scatterplots as subplots in one plot, comparing hares and lynxes, hares and carrots, and carrots and lynxes. Do a (Pearson) correlation analysis for each plot/data pares (google correlation). Display your correlation coefficient on each graph.

# %%
plt.figure(figsize = (4,20))
plt.subplot(3,1,1)
plt.scatter(hares,carrots)
plt.xlabel('Hares')
plt.ylabel('Carrots')
plt.title('r = %.3f' %np.corrcoef(hares, carrots)[0,1])
# see https://www.learnpython.org/en/String_Formatting

plt.subplot(3,1,2)
plt.scatter(hares,lynxes)
plt.xlabel('Hares')
plt.ylabel('Lynxes')
plt.title('r = %.3f' %np.corrcoef(hares, lynxes)[0,1])

plt.subplot(3,1,3)
plt.scatter(carrots,lynxes)
plt.xlabel('Carrots')
plt.ylabel('Lynxes')
plt.title('r = %.3f' %np.corrcoef(carrots, lynxes)[0,1]);

# %% [markdown]
# ## Exercise 3

# %% [markdown]
# More lab work (if time):
# Work more from the spicy 1.4 plotting examples, or play with the extras below

# %% [markdown]
# ## Extras:
#
# * More advanced spiral plotting: https://blog.anvetsu.com/posts/fibonacci-golden-spiral-matplotlib-python/
# * Also, a turtle package! https://trinket.io/python/43bc79b582
