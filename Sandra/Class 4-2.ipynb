# %%
import numpy as np

# %%
randnums= np.random.randint(1, 101, 5)

# %%
randnums
# Out:
# array([ 85, 100,  19,  76,  12])

# %%
import matplotlib.pyplot as plt

# %%
x = np.random.random((3,5))

# %%
x
# Out:
# array([[1.52919588, 0.38741497, 1.78931515, 0.32650033, 0.21928249],
#        [0.20546975, 0.2566408 , 0.23699705, 0.43607583, 1.88343025],
#        [1.72224232, 0.30164472, 0.10529316, 1.59038972, 0.04644406]])

# %%
 q= np.std(x, axis=0)

# %%
q
# Out:
# array([0.21320815, 0.05424612, 0.29632701, 0.10824723, 0.36078791])

# %%
r=np.std (x, axis=1)

# %%
r
# Out:
# array([0.19687854, 0.252943  , 0.26482679])

# %%
s=np.mean(x, axis =0)

# %%
t=np.mean(x, axis=1)

# %%
s
# Out:
# array([0.48563598, 0.31523349, 0.37720179, 0.45098863, 0.38305227])

# %%
t
# Out:
# array([0.45034176, 0.40372274, 0.35320279])

# %%
plt.plot(q)

# %%
plt.plot(r)

# %%
plt.plot(s)

# %%
plt.plot(t)

# %%
x[x>0.5]+=1

# %%
x
# Out:
# array([[1.52919588, 0.38741497, 1.78931515, 0.32650033, 0.21928249],
#        [0.20546975, 0.2566408 , 0.23699705, 0.43607583, 1.88343025],
#        [1.72224232, 0.30164472, 0.10529316, 1.59038972, 0.04644406]])

# %%
plt.plot(x)

# %%
plt.pcolormesh(x)
plt.colorbar ()

# %%
a = np.std(x, axis=0)

# %%
a
# Out:
# array([0.67413458, 0.05424612, 0.76470528, 0.57172873, 0.82823636])

# %%
b = np.std(x, axis=1)

# %%
b
# Out:
# array([0.66775157, 0.64487454, 0.74338672])

# %%
c = np.mean(x, axis=0)

# %%
c
# Out:
# array([1.15230265, 0.31523349, 0.71053512, 0.78432196, 0.7163856 ])

# %%
d = np.mean(x, axis=1)

# %%
d
# Out:
# array([0.85034176, 0.60372274, 0.75320279])

# %%
plt.plot(a)

# %%
plt.plot(b)

# %%
plt.plot(c)

# %%
plt.plot(d)

# %%
y=np.random.rand(300,500)

# %%
plt.pcolormesh(y)
plt.colorbar()

# %%
y.flatten() #this makes a one by number of elements in the array vector
# Out:
# array([0.24006404, 0.29655724, 0.25642706, ..., 0.64404677, 0.62294682,
#        0.60179544])

# %%
plt.hist(y)
# Out:
# ([array([32., 30., 29., 27., 29., 25., 28., 26., 41., 33.]),
#   array([27., 25., 27., 27., 33., 37., 32., 28., 34., 30.]),
#   array([30., 32., 35., 31., 31., 30., 25., 21., 32., 33.]),
#   array([32., 22., 28., 30., 35., 30., 30., 31., 40., 22.]),
#   array([34., 33., 23., 39., 38., 28., 26., 30., 33., 16.]),
#   array([25., 27., 22., 44., 29., 31., 23., 40., 28., 31.]),
#   array([26., 32., 28., 31., 30., 24., 33., 29., 38., 29.]),
#   array([23., 29., 34., 28., 34., 29., 23., 33., 34., 33.]),
#   array([26., 25., 23., 32., 34., 38., 30., 43., 24., 25.]),
#   array([31., 28., 35., 37., 37., 28., 27., 30., 17., 30.]),
#   array([22., 36., 31., 31., 31., 26., 32., 30., 28., 33.]),
#   array([26., 30., 34., 27., 34., 32., 32., 27., 33., 25.]),
#   array([36., 31., 31., 27., 25., 34., 27., 19., 32., 38.]),
#   array([32., 24., 35., 24., 39., 36., 23., 31., 23., 33.]),
#   array([33., 27., 32., 23., 29., 32., 25., 42., 25., 32.]),
# ...

# %%
plt.hist(y.flatten())
# Out:
# (array([14845., 14801., 15329., 15035., 15033., 14885., 15012., 14951.,
#         15250., 14859.]),
#  array([2.44560035e-06, 1.00002060e-01, 2.00001675e-01, 3.00001290e-01,
#         4.00000905e-01, 5.00000520e-01, 6.00000134e-01, 6.99999749e-01,
#         7.99999364e-01, 8.99998979e-01, 9.99998593e-01]),
#  <a list of 10 Patch objects>)

# %%
y[y>0.5]+=1
plt.hist(y.flatten())
# Out:
# (array([29646., 30365., 15032.,     0.,     0.,     0.,     0., 14885.,
#         29963., 30109.]),
#  array([2.44560035e-06, 2.00002060e-01, 4.00001675e-01, 6.00001290e-01,
#         8.00000905e-01, 1.00000052e+00, 1.20000013e+00, 1.39999975e+00,
#         1.59999936e+00, 1.79999898e+00, 1.99999859e+00]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# masking

# %%
plt.pcolormesh(x)
plt.colorbar()

# %%
x2= np.ma.masked_where(x<0.5, x)

# %%
plt.pcolormesh(x2, vmin=0, vmax=2)
plt.colorbar()

# %%
x2.sum()
# Out:
# 8.514573321441894

# %%
x.sum()
# Out:
# 11.03633646876694

# %%
plt.hist(x2.flatten())
# Out:
# (array([1., 1., 0., 0., 0., 1., 0., 1., 0., 1.]),
#  array([1.52919588, 1.56461932, 1.60004276, 1.63546619, 1.67088963,
#         1.70631307, 1.7417365 , 1.77715994, 1.81258338, 1.84800681,
#         1.88343025]),
#  <a list of 10 Patch objects>)

# %%
y2= np.ma.masked_where(y<0.5, y)

# %%
plt.hist(y2.flatten())
plt.xlim([0,2])
# Out:
# (0, 2)

# %% [markdown]
# Scipy Lecture 1.4 (plotting)

# %%
X = np.linspace(-np.pi, np.pi, 256, endpoint=True) #plotting with default settings
C, S = np.cos(X), np.sin(X)

plt.plot(X, C)
plt.plot(X, S)

plt.show()

# %%
plt.figure(figsize=(8, 6), dpi=80) #instantiating defaults

plt.subplot(1, 1, 1)

X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C, S = np.cos(X), np.sin(X)

plt.plot(X, C, color="blue", linewidth=1.0, linestyle="-")

plt.plot(X, S, color="green", linewidth=1.0, linestyle="-")

plt.xlim(-4.0, 4.0)

plt.xticks(np.linspace(-4, 4, 9, endpoint=True))

plt.ylim(-1.0, 1.0)

plt.yticks(np.linspace(-1, 1, 5, endpoint=True))

plt.show()

# %%
plt.figure(figsize=(10, 6), dpi=80) #changing colors and line width
plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-")
plt.plot(X, S, color="red",  linewidth=2.5, linestyle="-")

# %%
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi], #setting tick labels
          [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])

plt.yticks([-1, 0, +1],
          [r'$-1$', r'$0$', r'$+1$'])
# Out:
# ([<matplotlib.axis.YTick at 0xc2de8b0>,
# ...
#  <a list of 3 Text yticklabel objects>)

# %%
ax = plt.gca()  # moving spines
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
