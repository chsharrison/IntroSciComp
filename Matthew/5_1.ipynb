# %% [markdown]
# # Class 5_1
# #### Matthew Kutugata
# #### 09-24-2019

# %% [markdown]
# # Annocements
# 1. Bring headphones next time
# https://github.com/justmarkham/pycon-2019-tutorial
#
# 2. New: grading warm-ip exercises as assignments
# If you don't finish, go back and correct your work. Grades will be up on blackboard in the next week.

# %% [markdown]
# ## Warm-up
# Using hares/carrots/lynxes data set we used last week, plot the data in one plot with three different suplots, each with a different lifestyle or color. Label your subplots appropriately.

# %%
import matplotlib as mpl
mpl.rcParams['font.size'] = 16
mpl.rcParams['lines.linewidth'] = 2

# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.loadtxt('populations.txt')
year, hares, lynxes, carrots = data.T

fig = plt.figure(figsize=(16,4))
plt.legend(('Hares', 'Lynxes', 'Carrots'), loc=(1.05, 0.5), fontsize=15)

plt.subplot(1,3,1) # rows, columns, start
plt.plot(year, hares/1000, color='brown', label='Hares')
plt.ylabel('Population (thousands)', fontsize=20)
plt.xlabel('Years', fontsize=20)
plt.title('Hares')
plt.ylim([0,80])

plt.subplot(1,3,2)
plt.plot(year, lynxes/1000, color='gray', label='Lynxes')
plt.xlabel('Years', fontsize=20)
plt.title('Lynxes')
plt.ylim([0,80])


plt.subplot(1,3,3)
plt.plot(year, carrots/1000, color='orange', label = 'Carrots')
plt.xlabel('Years', fontsize=20)
plt.title('Carrots')
plt.ylim([0,80])

fig.legend()

# %% [markdown]
# ## Exercise 1
# Plot the logarthmic spiral (google it)

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib as mpl
from pylab import *

fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(hares,carrots, year)

# %% [markdown]
# ## Exercise 2
# Plot the hares/carrots/lynxes data as three scatterplots as subplots in one plot, comparing hares and lynxes, hares and carrots, and carrots and lynxes. Do a (Pearson) correlation analysis for each plot/data pares (google correlation). Display your correlation coefficient on each graph.

# %%
data = np.loadtxt('populations.txt')
year, hares, lynxes, carrots = data.T

fig = plt.figure(figsize=(15,4), dpi=80)
plt.legend(('Hares', 'Lynxes', 'Carrots'), loc=(1.05, 0.5), fontsize=15)

plt.subplot(1,3,1) # rows, columns, start
plt.scatter(year, hares/1000, color='brown', label='Hares')
plt.scatter(year, lynxes/1000, color='gray', label='Lynxes')
plt.ylabel('Population (thousands)', fontsize=20)
#plt.xlabel('Years', fontsize=20)
hare_grad = np.gradient(hares, 1.0)
plt.title('Hares/Lynxes')
plt.figtext(.15, .14, 'r = ' + str(np.corrcoef(hares, lynxes)[0,1]), fontsize=12)
plt.ylim([0,80])
#hare_grad = np.gradient(hares, 1.0)
#print("diff(Hares) vs. Lynxes correlation", np.corrcoef(hare_grad, lynxes)[0,1])


plt.subplot(1,3,2)
hare_grad = np.gradient(hares, 1.0)
plt.figtext(.42, .14, 'r = ' + str(np.corrcoef(hares, carrots)[0,1]), fontsize=12)
plt.scatter(year, hares/1000, color='brown', label='Hares')
plt.scatter(year, carrots/1000, color='orange', label='Carrots')

plt.xlabel('Years', fontsize=20)
plt.title('Hares/Carrots')
plt.ylim([0,80])

plt.subplot(1,3,3)
lynx_grad = np.gradient(lynxes, 1.0)
plt.figtext(.7, .14, 'r = ' + str(np.corrcoef(lynxes, carrots)[0,1]), fontsize=12)
plt.scatter(year, lynxes/1000, color='gray', label='Lynxes')
plt.scatter(year, carrots/1000, color='orange', label = 'Carrots')
#plt.xlabel('Years', fontsize=20)

plt.title('Carrots/Lynxes' + '')
plt.ylim([0,80])
# Out:
# (0, 80)

# %% [markdown]
# ## Exercise 3
# More lab work (if time): Work more from the spicy 1.4 plotting examples, or play with the extras below

# %% [markdown]
# # 1.4.1 Introduction
# http://scipy-lectures.org/intro/matplotlib/index.html#introduction

# %% [markdown]
# ### 1.4.1.1 IPyhton, Jupyter, and matplotlib modes

# %%
# In Jupyter Notebook insert at the beginning of the notebook the following magic:
# %matplotlib inline

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# ## 1.4.2 Simple Plot

# %%
import numpy as np

# %%
x = np.linspace(-np.pi, np.pi, 256, endpoint=True)
c, s = np.cos(x), np.sin(x)
plt.plot(x, c)
plt.plot(x, s)
plt.show()

# %%
# instantiating defualts
plt.figure(figsize=(8, 6), dpi=60)
plt.subplot(1, 1, 1)
x = np.linspace(-np.pi, np.pi, 256, endpoint=True)
c, s = np.cos(x), np.sin(x)
plt.plot(x, c, color='blue', linewidth=2.5, linestyle="-", label="cosine")
plt.plot(x, s, color='green', linewidth=2.5, linestyle="-", label="sine")
plt.legend(loc='upper left')

# adding annotations to points
t = 2 * np.pi / 3
plt.plot([t, t], [0, np.cos(t)], color='blue', linewidth=2.5, linestyle="--")
plt.scatter([t, ], [np.cos(t), ], 50, color='blue')

plt.annotate(r'$cos(\frac{2\pi}{3})=-\frac{1}{2}$',
             xy=(t, np.cos(t)), xycoords='data',
             xytext=(-90, -50), textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

plt.plot([t, t],[0, np.sin(t)], color='green', linewidth=2.5, linestyle="--")
plt.scatter([t, ],[np.sin(t), ], 50, color='red')

plt.annotate(r'$sin(\frac{2\pi}{3})=\frac{\sqrt{3}}{2}$',
             xy=(t, np.sin(t)), xycoords='data',
             xytext=(+10, +30), textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

# setting ticks and axis limits
plt.xlim(x.min(), x.max())
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi], [r'$-\pi$', r'$-\pi/2$', r'$0$', 
                                                  r'$+\pi/2$', r'$\pi/2$', r'$\pi$'])
plt.ylim(c.min() * 1.1, c.max() * 1.1)
plt.yticks([-1, 0, 1])
plt.show()

# %% [markdown]
# ## 1.4.3 Figures, subplots, axes, and ticks

# %% [markdown]
# ### 1.4.4.1 Regular Plots

# %%
n = 256
plt.figure()
x = np.linspace(-np.pi, np.pi, n, endpoint=True)
y = np.sin(2*x)
y2 = 1.2*np.sin(4*np.pi*x)


#top = plt.subplot(x, y + 1, color='blue', alpha=1)
#bottom = plt.subplot(x, y - 1, color='blue', alpha=1)

plt.fill_between(x, 0, y)

# %% [markdown]
# ### 1.4.4.2 Scatter Plots

# %%
n = 1024
x = np.random.normal(0, 1, n)
y = np.random.normal(0,1, n)
t = np.arctan2(y, x)

plt.scatter(x, y, s=75, c=t, alpha=.5)

plt.axes([0.025, 0.025, 0.95, 0.95])
plt.scatter(x, y, s=75, c=t, alpha=.5)

plt.xlim(-1.5, 1.5)
plt.xticks(())
plt.ylim(-1.5, 1.5)
plt.yticks(())

plt.show()

# %% [markdown]
# ### 1.4.4.3 Bar Plots

# %%
n = 12 
x = np.arange(n)
y1 = (1 - x / float(n)) * np.random.uniform(0.5, 1.0, n)
y2 = (1 - x / float(n)) * np.random.uniform(0.5, 1.0, n)
plt.bar(x, y1, facecolor='#9999ff', edgecolor='white')
plt.bar(x, -y2, facecolor='#ff9999', edgecolor='white')
for x, y in zip(x, y1):
    plt.text(x + 0.4, y + 0.05, '%.2f' % y, ha='center', va='bottom')
plt.ylim(-1.25, 1.25)
# Out:
# (-1.25, 1.25)

# %% [markdown]
# ### 1.4.4.4 Contour Plots

# %%
def f(x, y):
    return (1 - x / 2 + x ** 5 + y ** 3) * np.exp(-x ** 2 - y ** 2) # i don't fully understsand this

n = 256
x = np.linspace(-3, 3, n)
y = np.linspace(-3, 3, n)
x, y = np.meshgrid(x, y)

plt.axes([0.025, 0.025, 0.95, 0.95])

plt.contourf(x, y, f(x, y), 8, alpha=.75, 
             cmap=plt.cm.hot)
c = plt.contour(x, y, f(x, y), 8, colors='black', linewidth=.5)

plt.clabel(c, inline=1, fontsize=10)
plt.xticks(())
plt.yticks(())
plt.show()
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   del sys.path[0]

# %% [markdown]
# ### 1.4.4.5 Imshow

# %%
def f(x, y):
    return (1 - x / 2 + x ** 5 + y ** 3) * np.exp(-x ** 2 - y ** 2)

n = 10
x = np.linspace(-3, 3, 4 * n)
y = np.linspace(-3, 3, 3 * n)
X, Y = np.meshgrid(x, y)
z = f(X, Y)
plt.axes([0.025, .025, .95, .95])
#plt.imshow(z, interpolation='nearest', cmap='bone', origin='lower')
plt.imshow(f(X, Y))
plt.yticks(())
plt.xticks(())
plt.colorbar(shrink=.92)

# %% [markdown]
# ### 1.4.4.6 Pie Charts

# %%
z = np.random.uniform(0, 1, 20)
n = 20
col = 20
z[-1] *= 2
ex = np.ones(n)
plt.pie(z, explode=ex * .05, colors=['%f' % (i/float(col)) for i in range(col)])

plt.show()

# %% [markdown]
# ### 1.4.4.7 Quiver Plots

# %%
n = 8 
x, y, = np.mgrid[0:n, 0:n]
t = np.arctan2(y - n / 2., x - n/2.)
r = 10 + np.sqrt((y - n / 2.) ** 2 + (x - n / 2.) ** 2)
u, v = r * np.cos(t), r * np.sin(t)
plt.axes([0.025, 0.025, 0.95, 0.95])
plt.quiver(x, y, u, v, r, alpha=.9) # alpha is the transparency of colors inside arrow
plt.quiver(x, y, u, v, edgecolor='k', facecolor='None', linewidth=.5)
plt.xticks(())
plt.yticks(())
plt.ylim(-1, n)
plt.xlim(-1, n)
# Out:
# (-1, 8)

# %% [markdown]
# ### 1.4.4.8 Grids

# %%
# copy and pasted from
# http://scipy-lectures.org/intro/matplotlib/auto_examples/plot_grid.html
import matplotlib.pyplot as plt

ax = plt.axes([0.025, 0.025, 0.95, 0.95])

ax.set_xlim(0,4)
ax.set_ylim(0,3)
ax.xaxis.set_major_locator(plt.MultipleLocator(1.0))
ax.xaxis.set_minor_locator(plt.MultipleLocator(0.1))
ax.yaxis.set_major_locator(plt.MultipleLocator(1.0))
ax.yaxis.set_minor_locator(plt.MultipleLocator(0.1))
ax.grid(which='major', axis='x', linewidth=0.75, linestyle='-', color='0.75')
ax.grid(which='minor', axis='x', linewidth=0.25, linestyle='-', color='0.75')
ax.grid(which='major', axis='y', linewidth=0.75, linestyle='-', color='0.75')
ax.grid(which='minor', axis='y', linewidth=0.25, linestyle='-', color='0.75')
ax.set_xticklabels([])
ax.set_yticklabels([])

plt.show()

# %% [markdown]
# ### 1.4.4.9 Multiplots

# %%
fig = plt.figure()
fig.subplots_adjust(bottom=0.025, left=0.025, top=0.975, right=0.975)
plt.subplot(2, 1, 1)
plt.xticks(()), plt.yticks(())

plt.subplot(2, 3, 4)
plt.xticks(()), plt.yticks(())

plt.subplot(2, 3, 5)
plt.xticks(()), plt.yticks(())

plt.subplot(2, 3, 6)
plt.xticks(()), plt.yticks(())

plt.show()

# %% [markdown]
# ### 1.4.4.10 Polar Axis

# %%
ax = plt.axes([0, 0, 1, 1], polar=True)
n = 20
theta = np.arange(0, 2 * np.pi, 2 * np.pi / n)
radii = 10 * np.random.rand(n)
width = np.pi / 4 * np.random.rand(n)
bars = plt.bar(theta, radii, width=width, bottom=0)
for r, bar in zip(radii, bars):
    bar.set_facecolor(plt.cm.jet(r / 10))
    bar.set_alpha(0.5)
ax.set_yticklabels(())
ax.set_xticklabels(())
# Out:
# []

# %% [markdown]
# ### 1.4.4.11 3D Plots

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
x = np.arange(-4, 4, 0.25)
y = np.arange(-4, 4, 0.25)
x, y = np.meshgrid(x, y)
r = np.sqrt(x**2 + y**2)
z = np.sin(r)
ax.plot_surface(x, y, z, rstride=1, cstride=1, cmap='hot')
ax.contourf(x, y, z, zdir='z', offset=-2, cmap=plt.cm.hot)
ax.set_zlim(-2, 2)
# Out:
# (-2, 2)

# %% [markdown]
# ### 1.4.4..12 Demo Text Printing
# Code copy and pasted from http://scipy-lectures.org/intro/matplotlib/auto_examples/plot_text.html

# %%
import numpy as np
import matplotlib.pyplot as plt


eqs = []
eqs.append((r"$W^{3\beta}_{\delta_1 \rho_1 \sigma_2} = U^{3\beta}_{\delta_1 \rho_1} + \frac{1}{8 \pi 2} \int^{\alpha_2}_{\alpha_2} d \alpha^\prime_2 \left[\frac{ U^{2\beta}_{\delta_1 \rho_1} - \alpha^\prime_2U^{1\beta}_{\rho_1 \sigma_2} }{U^{0\beta}_{\rho_1 \sigma_2}}\right]$"))
eqs.append((r"$\frac{d\rho}{d t} + \rho \vec{v}\cdot\nabla\vec{v} = -\nabla p + \mu\nabla^2 \vec{v} + \rho \vec{g}$"))
eqs.append((r"$\int_{-\infty}^\infty e^{-x^2}dx=\sqrt{\pi}$"))
eqs.append((r"$E = mc^2 = \sqrt{{m_0}^2c^4 + p^2c^2}$"))
eqs.append((r"$F_G = G\frac{m_1m_2}{r^2}$"))

plt.axes([0.025, 0.025, 0.95, 0.95])

for i in range(24):
    index = np.random.randint(0, len(eqs))
    eq = eqs[index]
    size = np.random.uniform(12, 32)
    x,y = np.random.uniform(0, 1, 2)
    alpha = np.random.uniform(0.25, .75)
    plt.text(x, y, eq, ha='center', va='center', color="#11557c", alpha=alpha,
         transform=plt.gca().transAxes, fontsize=size, clip_on=True)
plt.xticks(())
plt.yticks(())

plt.show()

# %% [markdown]
# ## 1.4.5.1 Beyond the Tutorial: Image Tutorial
# https://matplotlib.org/users/image_tutorial.html

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
# load in image (documentation says matplotlib
# can only use png images but it worked for my
# jpg)
img = mpimg.imread('img.jpg')

# %%
imgplot = plt.imshow(img)

# %%
# choosing one channel of rgb images (channel index starts at 0)
# slicing the array
r_img = img[:, :, 0]

# %%
plt.imshow(r_img)

# %%
# changing color map
plt.imshow(r_img, cmap='hot')

# %%
# changing color map using set_cmap()
# list of other color maps here:
# https://matplotlib.org/examples/color/colormaps_reference.html
imgplot = plt.imshow(r_img)
imgplot.set_cmap('nipy_spectral')

# %% [markdown]
# ## Extras:
# - More advanced spiral plotting: https://blog.anvetsu.com/posts/fibonacci-golden-spiral-matplotlib-python/
# - Also, a turtle package! https://trinket.io/python/43bc79b582
#
# ## HOMEWORK
# plot your own data for presentation
