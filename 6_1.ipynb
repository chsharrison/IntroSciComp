# %% [markdown]
# # Lecure 6.1 More plotting and data analysis
# ## Matthew Kutugata
# ## October 1st, 2019

# %% [markdown]
# Warm up:
#     Class presentations of data plotting

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
np.arange(0,50, 1) # start stop step

# %%
np.linspace(0, 50, 2) # number of points
# Out:
# array([ 0., 50.])

# %%
x = np.arange(0, 100)
y = np.arange(0, 100)
X, Y = np.meshgrid(x,y)

# %%
plt.pcolormesh(X) # used to visualize two dimensional 
plt.colorbar()
plt.xlabel("Column index", fontsize='18')
plt.ylabel("Row index", fontsize='18')
# Out:
# Text(0, 0.5, 'Row index')

# %%
plt.yfont?
# Out:
# Object `plt.yfont` not found.

# %%
plt.pcolormesh(Y)
plt.colorbar
# Out:
# <function matplotlib.pyplot.colorbar(mappable=None, cax=None, ax=None, **kw)>

# %%
Z = X + Y
plt.pcolormesh(Z)
plt.colorbar()

# %%
Z.shape
# Out:
# (100, 100)

# %%
plt.pcolormesh(X,Y, X+Y)
plt.colorbar()

# %% [markdown]
# ## Lecture Examples
#
# Didn't get to in 5.1, moved here:
# * Plot y = sin(x) on -pi to pi using 100 points
#     * Go over linespace and meshgrid
# * Create a color plot of z = sin(x) * sin(y) on the interval [−π,π]×[−π,π][−π,π]×[−π,π]. using 100 x 100 points
# * Plot an Archimedean spiral (https://en.wikipedia.org/wiki/Archimedean_spiral)
# *     Note this involves translating some r code into python

# %%
x = np.linspace(-np.pi, np.pi, 100, endpoint=True)
y = np.sin(x)
plt.plot(x, y)

# %%
# exercise number 2
xbasis = np.linspace(-np.pi, np.pi, 100, endpoint=True)
ybasis = np.linspace(-np.pi, np.pi, 100, endpoint=True) # this is a 1 d array but
# want it to be a 2D array
X, Y = np.meshgrid(xbasis, ybasis)
Z = np.sin(X*Y)
plt.pcolormesh(X, Y, Z) # defining function using the two basis array as axis
plt.colorbar
# Out:
# <function matplotlib.pyplot.colorbar(mappable=None, cax=None, ax=None, **kw)>

# %%
Z
# Out:
# array([[-0.43030122, -0.24298364, -0.04603827, ...,  0.04603827,
#          0.24298364,  0.43030122],
#        [-0.24298364, -0.05006161,  0.14476494, ..., -0.14476494,
#          0.05006161,  0.24298364],
#        [-0.04603827,  0.14476494,  0.33028486, ..., -0.33028486,
#         -0.14476494,  0.04603827],
#        ...,
#        [ 0.04603827, -0.14476494, -0.33028486, ...,  0.33028486,
#          0.14476494, -0.04603827],
#        [ 0.24298364,  0.05006161, -0.14476494, ...,  0.14476494,
#         -0.05006161, -0.24298364],
#        [ 0.43030122,  0.24298364,  0.04603827, ..., -0.04603827,
#         -0.24298364, -0.43030122]])

# %% [markdown]
# ## Exercise 1 (Saved from Lec 5.1)

# %% [markdown]
# Plot a logarithmic spiral (google it)

# %%
# warmup archemedian spiral
a = 1.5 
b = -2.4
t = np.linspace(0, 5*np.pi, 500)
x = (a + b*t)*np.cos(t)
y = (a + b*t)*np.sin(t)
plt.plot(x, y)
plt.plot([-40, 40], [0,0])
plt.axis('equal')
plt.grid()

# %% [markdown]
# ## Exercise 2
# Experiment some more with your data set and pandas, exploring the plotting options in matplotlib

# %%
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['legend.fontsize'] = 18

fig = plt.figure()
ax = fig.gca(projection='3d')

a=0.5
b=0.20
th=np.linspace(475, 500, 10000)
x=a*np.exp(b*th)*np.cos(th)
y=a*np.exp(b*th)*np.sin(th)
z = np.linspace(0,2, len(th))
plt.plot(x, y, z)
#ax.legend()

plt.show()

# %% [markdown]
# ## Extras:
#
# * More advanced spiral plotting: https://blog.anvetsu.com/posts/fibonacci-golden-spiral-matplotlib-python/
# * Also, a turtle package! https://trinket.io/python/43bc79b582

# %% [markdown]
# ## Practice Python # 14 List remove duplicates

# %%
from random import randint
def remove_dup():
# Out:
# Welcom to cows and bulls game! Enter a number:  34
# bulls
