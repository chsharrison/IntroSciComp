# %% [markdown]
# # Jennifer Baez
# ## 09/19/19

# %% [markdown]
# ### Warm up

# %% [markdown]
# Define a 3x 5 array of random numbers

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
a = np.random.rand(3,5)

# %%
a
# Out:
# array([[0.24790869, 0.82032529, 0.12508082, 0.99532476, 0.49975983],
#        [0.60361848, 0.33938399, 0.35339416, 0.18528482, 0.34592546],
#        [0.32200412, 0.377984  , 0.65957654, 0.9518069 , 0.53346628]])

# %% [markdown]
# Plot the array

# %%
plt.plot(a, 'o')

# %%
plt.pcolormesh(a)
plt.colorbar()

# %% [markdown]
# # Adding masked

# %%
x2=np.ma.masked_where(a<0.5,a)

# %%
plt.pcolormesh(x)
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-114-2aabfccc43f7> in <module>()
# ----> 1 plt.pcolormesh(x)
#       2 plt.colorbar()
#
# NameError: name 'x' is not defined

# %%
plt.pcolormesh(x2, vmin =0, vmax=2)
plt.colorbar()

# %% [markdown]
# Take the mean and standad deviation along the first and second axis,
# Describe the results.

# %%
# sum ignores all the masked values

# %%
np.mean(a,axis=1)
# Out:
# array([0.53767988, 0.36552139, 0.56896757])

# %%
np.mean(a,axis=0) #this is the mean of each column (5 columns)
# Out:
# array([0.3911771 , 0.51256443, 0.37935051, 0.71080549, 0.45971719])

# %%
np.std(a,axis=0)
# Out:
# array([0.15323411, 0.2181896 , 0.2189775 , 0.37202369, 0.08163108])

# %% [markdown]
# Using logical inadexing add one to all the values grater than 0.5

# %%
a
# Out:
# array([[0.24790869, 0.82032529, 0.12508082, 0.99532476, 0.49975983],
#        [0.60361848, 0.33938399, 0.35339416, 0.18528482, 0.34592546],
#        [0.32200412, 0.377984  , 0.65957654, 0.9518069 , 0.53346628]])

# %%
a[a >0.5]
# Out:
# array([0.82032529, 0.99532476, 0.60361848, 0.65957654, 0.9518069 ,
#        0.53346628])

# %%
a[a >0.5]+=1

# %%
a
# Out:
# array([[0.24790869, 1.82032529, 0.12508082, 1.99532476, 0.49975983],
#        [1.60361848, 0.33938399, 0.35339416, 0.18528482, 0.34592546],
#        [0.32200412, 0.377984  , 1.65957654, 1.9518069 , 1.53346628]])

# %% [markdown]
# Plot the array again along with the new numbers

# %%
plt.pcolormesh(a)
plt.colorbar()

# %%
col_mean=np.mean(a,axis=1)
col_mean
# Out:
# array([0.93767988, 0.56552139, 1.16896757])

# %%
np.mean(a,axis=0)
# Out:
# array([0.72451043, 0.84589776, 0.71268384, 1.37747216, 0.79305053])

# %%
np.std(a,axis=0)
# Out:
# array([0.62235883, 0.68920449, 0.67601089, 0.84319094, 0.52730628])

# %%
#plot the mean
pltplot(col_mean,'k')
plt.plot(col_mean+col_std,'k--')
plt.plot(colmean-col_std,'k--')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-d2c33880bcd3> in <module>()
#       1 #plot the mean
# ----> 2 pltplot(col_mean,'k')
#       3 plt.plot(col_mean+col_std,'k--')
#       4 plt.plot(colmean-col_std,'k--')
#
# NameError: name 'pltplot' is not defined

# %% [markdown]
# Plot the 2x2 array in the first two indices in each dimesion, find the sum and the median of the array.

# %%
a[0:2,0:2]
# Out:
# array([[0.24790869, 1.82032529],
#        [1.60361848, 0.33938399]])

# %%
plt.pcolormesh(a[0:2,0:2])
plt.colorbar()

# %%
np.sum(a[0:2,0:2])
# Out:
# 4.011236454455446

# %%
np.median(a[0:2,0:2])
# Out:
# 0.971501238985905

# %% [markdown]
# Done?

# %%
y=np.random.rand(300,500)

# %%
plt.pcolormesh(y)
plt.colorbar()

# %%
#we need to flatten the array to make a histogram
y.flatten()
#makes a 1x number of elements in the array vector
# Out:
# array([0.07406939, 0.47035427, 0.97777512, ..., 0.20896932, 0.41730114,
#        0.37562683])

# %%
plt.hist(y)
# Out:
# ([array([29., 38., 26., 23., 33., 31., 32., 30., 32., 26.]),
#   array([24., 36., 27., 34., 41., 27., 23., 31., 28., 29.]),
#   array([40., 27., 39., 40., 28., 25., 28., 27., 21., 25.]),
#   array([39., 19., 26., 37., 32., 35., 19., 32., 31., 30.]),
#   array([28., 23., 29., 25., 30., 30., 37., 37., 23., 38.]),
#   array([33., 31., 38., 25., 35., 29., 28., 32., 23., 26.]),
#   array([36., 32., 27., 22., 29., 34., 28., 21., 28., 43.]),
#   array([28., 26., 29., 33., 26., 27., 36., 26., 31., 38.]),
#   array([30., 24., 33., 35., 37., 25., 29., 27., 34., 26.]),
#   array([35., 30., 24., 25., 37., 23., 30., 38., 22., 36.]),
#   array([46., 32., 30., 30., 33., 35., 18., 26., 21., 29.]),
#   array([33., 35., 28., 25., 42., 31., 26., 26., 25., 29.]),
#   array([35., 32., 22., 39., 21., 27., 40., 27., 25., 32.]),
#   array([34., 27., 26., 29., 31., 36., 29., 29., 30., 29.]),
#   array([33., 22., 33., 34., 27., 37., 24., 25., 38., 27.]),
# ...

# %%
plt.hist(y.flatten())
# Out:
# (array([15124., 15101., 15087., 14841., 14921., 14907., 14995., 14879.,
#         15203., 14942.]),
#  array([1.87130722e-06, 1.00001348e-01, 2.00000825e-01, 3.00000302e-01,
#         3.99999779e-01, 4.99999256e-01, 5.99998733e-01, 6.99998210e-01,
#         7.99997686e-01, 8.99997163e-01, 9.99996640e-01]),
#  <a list of 10 Patch objects>)

# %%
y[y >0.5]
# Out:
# array([1.97777512, 1.91965723, 1.94498924, ..., 1.57409921, 1.96751342,
#        1.5703867 ])

# %%
y[y>0.5]+=1

# %%
y
# Out:
# array([[0.07406939, 0.47035427, 2.97777512, ..., 0.0177257 , 2.95159764,
#         2.93701753],
#        [0.23269364, 2.52324443, 0.10234863, ..., 0.26393359, 2.94880656,
#         0.04362773],
#        [0.40910294, 0.40663313, 0.39447888, ..., 0.49613338, 2.8041277 ,
#         0.38716943],
#        ...,
#        [0.10400894, 0.0188791 , 2.69085974, ..., 2.82920251, 2.83468565,
#         0.38098902],
#        [0.17978305, 2.78930097, 0.03227889, ..., 2.68243697, 2.96486105,
#         0.17478989],
#        [0.43296037, 0.38648073, 0.19989659, ..., 0.20896932, 0.41730114,
#         0.37562683]])

# %%
plt.hist(y.flatten())
# Out:
# (array([45313., 29761.,     0.,     0.,     0.,     0.,     0.,     0.,
#         29902., 45024.]),
#  array([1.87130722e-06, 3.00001348e-01, 6.00000825e-01, 9.00000302e-01,
#         1.19999978e+00, 1.49999926e+00, 1.79999873e+00, 2.09999821e+00,
#         2.39999769e+00, 2.69999716e+00, 2.99999664e+00]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # Masking

# %%
np.ma #package

# %%
y2=np.ma.masked_where(y<0.5,y)
plt.hist(y.flatten())
plt.xlim([0,2])
# Out:
# (0, 2)

# %%
plt.pcolormesh(y)
plt.colorbar()

# %%
plt.hist(y.flatten())
# Out:
# (array([1., 1., 1., 0., 0., 0., 1., 0., 0., 2.]),
#  array([2.53346628, 2.57965213, 2.62583798, 2.67202383, 2.71820967,
#         2.76439552, 2.81058137, 2.85676722, 2.90295307, 2.94913891,
#         2.99532476]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # Scipy lectures (continued)

# %%
import numpy as np

# %% [markdown]
# Statistics

# %%
x=np.array([1,2,3,1])
y=np.array ([[1,2,3],[5,6,1]])
x.mean()
# Out:
# 1.75

# %%
np.median(x)
# Out:
# 1.5

# %%
np.median(y, axis=-1) # last axis
# Out:
# array([2., 5.])

# %%
x.std()
# Out:
# 0.82915619758885

# %%
# import data

# %%
from matplotlib import pyplot as plt
plt.axes([0.2, 0.1, 0.5, 0.8]) 
plt.plot(year, hares, year, lynxes, year, carrots) 
plt.legend(('Hare', 'Lynx', 'Carrot'), loc=(1.05, 0.5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-e486395619d9> in <module>()
#       1 from matplotlib import pyplot as plt
#       2 plt.axes([0.2, 0.1, 0.5, 0.8])
# ----> 3 plt.plot(year, hares, year, lynxes, year, carrots)
#       4 plt.legend(('Hare', 'Lynx', 'Carrot'), loc=(1.05, 0.5))
#
# NameError: name 'year' is not defined

# %% [markdown]
# # 1.3.2.4. Array shape manipulation

# %% [markdown]
# Flattening

# %%
a = np.array([[1, 2, 3], [4, 5, 6]])
a.ravel()
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
a.T
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
a.T.ravel()
# Out:
# array([1, 4, 2, 5, 3, 6])

# %% [markdown]
# Reshaping

# %%
a.shape
# Out:
# (2, 3)

# %%
b=a.ravel()

# %%
b=b.reshape((2,3))

# %%
b
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
b[0,0]=85

# %%
a
# Out:
# array([[85,  2,  3],
#        [ 4,  5,  6]])

# %%
a=np.zeros((3,2))

# %%
b=a.T.reshape(3*2)

# %%
b[0]=9

# %%
a
# Out:
# array([[0., 0.],
#        [0., 0.],
#        [0., 0.]])

# %% [markdown]
# Adding a dimension

# %%
z = np.array([1, 2, 3])

# %%
z
# Out:
# array([1, 2, 3])

# %%
z[:, np.newaxis]
# Out:
# array([[1],
#        [2],
#        [3]])

# %%
z[np.newaxis, :]
# Out:
# array([[1, 2, 3]])

# %% [markdown]
# Dimension shuffling

# %%
a = np.arange(4*3*2).reshape(4, 3, 2)
a.shape
# Out:
# (4, 3, 2)

# %%
a[0, 2, 1]
# Out:
# 5

# %%
b=a.transpose

# %%
b.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-a8244287b6af> in <module>()
# ----> 1 b.shape
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'shape'
