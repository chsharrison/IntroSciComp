# %% [markdown]
# # Lecure 8.2: linear regression and statistics continued

# %% [markdown]
# I was going to jump into netcdf files and doing data analysis with them, but decided it was more useful for your work to spend the time on digging in on model fitting. We will come back to netcdf files and climate data in the next two weeks
#
# ## Lecture:
#     - Root mean square error (RMSE)
#     - R^2, the "coefficient of determination"
#     - training and testing spitting

# %% [markdown]
# ### 8.2.1: Continue with what you were doing in Lec 8.1. Focus on the first exercises if you haven't done them yet

# %% [markdown]
# ### 8.2.2
# Make a pairplot using the housing data: https://scipy-lectures.org/packages/statistics/index.html#pairplot-scatter-matrices
#
# Explain what this tells you

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from scipy import stats

# %%
#tutorial!, how to download boston data from sklearn
from sklearn import datasets
data = datasets.load_boston() 
df = pd.DataFrame(data.data, columns=data.feature_names) #this makes a new dataframe named df with pandas
# target (housing value -- MEDV) in new data frame named target
target = pd.DataFrame(data.target, columns=["MEDV"])

df["MEDV"] = target["MEDV"]# this adds means

# %%
#scatter matrix 
sns.pairplot(df, vars=['CRIM', 'RM', 'AGE', 'DIS', 'MEDV'], kind = 'reg') #variables

# %%
df.dropna()#normalizing data?
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0     0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900   1.0  296.0
# 1     0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671   2.0  242.0
# 2     0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671   2.0  242.0
# 3     0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622   3.0  222.0
# 4     0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622   3.0  222.0
# 5     0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622   3.0  222.0
# 6     0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605   5.0  311.0
# 7     0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505   5.0  311.0
# 8     0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821   5.0  311.0
# 9     0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921   5.0  311.0
# 10    0.22489  12.5   7.87   0.0  0.524  6.377   94.3  6.3467   5.0  311.0
# 11    0.11747  12.5   7.87   0.0  0.524  6.009   82.9  6.2267   5.0  311.0
# 12    0.09378  12.5   7.87   0.0  0.524  5.889   39.0  5.4509   5.0  311.0
# 13    0.62976   0.0   8.14   0.0  0.538  5.949   61.8  4.7075   4.0  307.0
# 14    0.63796   0.0   8.14   0.0  0.538  6.096   84.5  4.4619   4.0  307.0
# 15    0.62739   0.0   8.14   0.0  0.538  5.834   56.5  4.4986   4.0  307.0
# 16    1.05393   0.0   8.14   0.0  0.538  5.935   29.3  4.4986   4.0  307.0
# 17    0.78420   0.0   8.14   0.0  0.538  5.990   81.7  4.2579   4.0  307.0
# 18    0.80271   0.0   8.14   0.0  0.538  5.456   36.6  3.7965   4.0  307.0
# 19    0.72580   0.0   8.14   0.0  0.538  5.727   69.5  3.7965   4.0  307.0
# 20    1.25179   0.0   8.14   0.0  0.538  5.570   98.1  3.7979   4.0  307.0
# 21    0.85204   0.0   8.14   0.0  0.538  5.965   89.2  4.0123   4.0  307.0
# 22    1.23247   0.0   8.14   0.0  0.538  6.142   91.7  3.9769   4.0  307.0
# 23    0.98843   0.0   8.14   0.0  0.538  5.813  100.0  4.0952   4.0  307.0
# 24    0.75026   0.0   8.14   0.0  0.538  5.924   94.1  4.3996   4.0  307.0
# 25    0.84054   0.0   8.14   0.0  0.538  5.599   85.7  4.4546   4.0  307.0
# 26    0.67191   0.0   8.14   0.0  0.538  5.813   90.3  4.6820   4.0  307.0
# 27    0.95577   0.0   8.14   0.0  0.538  6.047   88.8  4.4534   4.0  307.0
# 28    0.77299   0.0   8.14   0.0  0.538  6.495   94.4  4.4547   4.0  307.0
# 29    1.00245   0.0   8.14   0.0  0.538  6.674   87.3  4.2390   4.0  307.0
# ..        ...   ...    ...   ...    ...    ...    ...     ...   ...    ...
# 476   4.87141   0.0  18.10   0.0  0.614  6.484   93.6  2.3053  24.0  666.0
# 477  15.02340   0.0  18.10   0.0  0.614  5.304   97.3  2.1007  24.0  666.0
# 478  10.23300   0.0  18.10   0.0  0.614  6.185   96.7  2.1705  24.0  666.0
# 479  14.33370   0.0  18.10   0.0  0.614  6.229   88.0  1.9512  24.0  666.0
# 480   5.82401   0.0  18.10   0.0  0.532  6.242   64.7  3.4242  24.0  666.0
# 481   5.70818   0.0  18.10   0.0  0.532  6.750   74.9  3.3317  24.0  666.0
# 482   5.73116   0.0  18.10   0.0  0.532  7.061   77.0  3.4106  24.0  666.0
# 483   2.81838   0.0  18.10   0.0  0.532  5.762   40.3  4.0983  24.0  666.0
# 484   2.37857   0.0  18.10   0.0  0.583  5.871   41.9  3.7240  24.0  666.0
# 485   3.67367   0.0  18.10   0.0  0.583  6.312   51.9  3.9917  24.0  666.0
# 486   5.69175   0.0  18.10   0.0  0.583  6.114   79.8  3.5
# 478     20.2  379.70  18.03  14.6
# 479     20.2  383.32  13.11  21.4
# 480     20.2  396.90  10.74  23.0
# 481     20.2  393.07   7.74  23.7
# 482     20.2  395.28   7.01  25.0
# 483     20.2  392.92  10.42  21.8
# 484     20.2  370.73  13.34  20.6
# 485     20.2  388.62  10.58  21.2
# 486     20.2  392.68  14.98  19.1
# 487     20.2  388.22  11.45  20.6
# 488     20.1  395.09  18.06  15.2
# 489     20.1  344.05  23.97   7.0
# 490     20.1  318.43  29.68   8.1
# 491     20.1  390.11  18.07  13.6
# 492     20.1  396.90  13.35  20.1
# 493     19.2  396.90  12.01  21.8
# 494     19.2  396.90  13.59  24.5
# 495     19.2  393.29  17.60  23.1
# 496     19.2  396.90  21.14  19.7
# 497     19.2  396.90  14.10  18.3
# 498     19.2  396.90  12.92  21.2
# 499     19.2  395.77  15.10  17.5
# 500     19.2  396.90  14.33  16.8
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
#scatter matrix 
sns.pairplot(df, vars=['CRIM', 'MEDV'], kind = 'reg', hue='AGE') #variables LOL
# Out:
# C:\Users\baezj\Anaconda3\lib\site-packages\numpy\core\_methods.py:140: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# C:\Users\baezj\Anaconda3\lib\site-packages\numpy\core\_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# #### Scatter plots are correlations of variables with best ft line regressions histograms represent individual variables, kinda like a correlation plot

# %% [markdown]
# ### 8.2.3 Now get creative
# Using one or more of the datasets we have been using, ask two or more research questions, make appropriate model(s), and test your model(s) using regression.
# You might pick one easy and one hard research question. You might start with a simple linear model, but feel free to branch out to a non-linear model, or fancy statistics tests if you feel confident about doing so and can explain them. The point is that you are designing the modeling, not following a tutorial, and that you develop expertise on the methods you are using so you can defend their usage.
#
# Places to look for inspiration:
# - https://scipy-lectures.org/packages/statistics/index.html
# - https://docs.scipy.org/doc/numpy/reference/generated/numpy.polyfit.html
# - https://www.statsmodels.org/dev/examples/index.html
#
# etc...
#
#
# ### Homework
# As before, you will present your analysis to the class. Put a cleaned up version of your code, suitable for presentation, in a new notebook called HW_8_yourname. You will present this next Tuesday afternoon, after Riley's lecture.

# %%
df.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD        float64
# TAX        float64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %% [markdown]
# # How strong is the correlation between RM, MEDV, LSTAT, PTRATIO
# #### 'LSTAT' is the percentage of homeowners in the neighborhood considered "lower class" (working poor).
# #### 'PTRATIO' is the ratio of students to teachers in primary and secondary schools in the neighborhood.

# %% [markdown]
# ## For a higher RM, one would expect to observe a higher MEDV.
# ##### This is because more rooms would imply more space, thereby costing more, taking all other factors constant.

# %% [markdown]
# ## For a higher LSTAT, one would expect to observe a a lower MEDV.
# ##### In an area dominated by "lower class" citizens may not be conducive for young children. It may also be relatively unsafe compared to an area dominated by "upper class" citizens. Hence an area with more "lower class" citizens would lower demand, hence lower prices.

# %%
df.dropna() #are zeros outliers?
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0     0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900   1.0  296.0
# 1     0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671   2.0  242.0
# 2     0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671   2.0  242.0
# 3     0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622   3.0  222.0
# 4     0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622   3.0  222.0
# 5     0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622   3.0  222.0
# 6     0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605   5.0  311.0
# 7     0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505   5.0  311.0
# 8     0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821   5.0  311.0
# 9     0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921   5.0  311.0
# 10    0.22489  12.5   7.87   0.0  0.524  6.377   94.3  6.3
.0  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# 5       18.7  394.12   5.21  28.7
# 6       15.2  395.60  12.43  22.9
# 7       15.2  396.90  19.15  27.1
# 8       15.2  386.63  29.93  16.5
# 9       15.2  386.71  17.10  18.9
# 10      15.2  392.52  20.45  15.0
# 11      15.2  396.90  13.27  18.9
# 12      15.2  390.50  15.71  21.7
# 13      21.0  396.90   8.26  20.4
# 14      21.0  380.02  10.26  18.2
# 15      21.0  395.62   8.47  19.9
# 16      21.0  386.85   6.58  23.1
# 17      21.0  386.75  14.67  17.5
# 18      21.0  288.99  11.69  20.2
# 19      21.0  390.95  11.28  18.2
# 20      21.0  376.57  21.02  13.6
# 21      21.0  392.53  13.83  19.6
# 22      21.0  396.90  18.72  15.2
# 23      21.0  394.54  19.88  14.5
# 24      21.0  394.33  16.30  15.6
# 25      21.0  303.42  16.51  13.9
# 26      21.0  376.88  14.81  16.6
# 27      21.0  306.38  17.28  14.8
# 28      21.0  387.94  12.80  18.4
# 29      21.0  380.23  11.98  21.0
# ..       ...     ...    ...   ...
# 476     20.2  396.21  18.68  16.7
# 477     20.2  349.48  24.91  12.0
# 478     20.2  379.70  18.03  14.6
# 479     20.2  383.32  13.11  21.4
# 480     20.2  396.90  10.74  23.0
# 481     20.2  393.07   7.74  23.7
# 482     20.2  395.28   7.01  25.0
# 483     20.2  392.92  10.42  21.8
# 484     20.2  370.73  13.34  20.6
# 485     20.2  388.62  10.58  21.2
# 486     20.2  392.68  14.98  19.1
# 487     20.2  388.22  11.45  20.6
# 488     20.1  395.09  18.06  15.2
# 489     20.1  344.05  23.97   7.0
# 490     20.1  318.43  29.68   8.1
# 491     20.1  390.11  18.07  13.6
# 492     20.1  396.90  13.35  20.1
# 493     19.2  396.90  12.01  21.8
# 494     19.2  396.90  13.59  24.5
# 495     19.2  393.29  17.60  23.1
# 496     19.2  396.90  21.14  19.7
# 497     19.2  396.90  14.10  18.3
# 498     19.2  396.90  12.92  21.2
# 499     19.2  395.77  15.10  17.5
# 500     19.2  396.90  14.33  16.8
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
df.dropzeros()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-f73fbb143567> in <module>
# ----> 1 df.dropzeros()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'dropzeros'

# %%
df.strip("0")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-0eea8d35c520> in <module>
# ----> 1 df.strip("0")
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'strip'

# %%
name = df['RM']
name2 = df[name < 3.5]#remove outliers
name2.imdb_score.plot(kind='box',color='m')#plot

# %%
plt.figure(figsize=(20, 5))

features = ['LSTAT', 'RM']
target = df['MEDV']

for i, col in enumerate(features):
    plt.subplot(1, len(features) , i+1)
    x = df[col]                      
    y = target
    plt.scatter(x, y, marker='v',color='yellow')
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel('MEDV')
    
    plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)),color='m')#regression line

# %%
plt.figure(figsize=(20, 5))

features = ['PTRATIO']
target = df['LSTAT']

for i, col in enumerate(features):

    x = df[col]                      
    y = target
    plt.scatter(x, y, marker='o',color= 'yellow')
    plt.title(col,fontsize=18)
    plt.xlabel(col,fontsize=15)
    plt.ylabel('LSTAT',fontsize=15)
    
    plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)),color='m')#regression line

# %%
plt.figure(figsize=(20, 5))

features = ['PTRATIO','LSTAT','RM']
target = df['MEDV']

for i, col in enumerate(features):
    plt.subplot(1, 3, i+1)
    x = df[col]                      
    y = target
    plt.scatter(x, y, marker='o',color= 'yellow')
    plt.title(col,fontsize=18)
    plt.xlabel(col,fontsize=15)
    plt.ylabel('MEDV',fontsize=15)
    
    plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)),color='m')#regression line

# %% [markdown]
# ## Non-Linear Polynomial

# %% [markdown]
# df_subset = df[['RM','MEDV']]
# df_subset.head()

# %%
plt.figure(figsize=(20, 5))

features = ['PTRATIO','LSTAT','RM']
target = df['MEDV']

for i, col in enumerate(features):
    plt.subplot(1, 3, i+1)
    x = df[col]                      
    y = target
    plt.scatter(x, y, marker='o',color= 'yellow')
    plt.title(col,fontsize=18)
    plt.xlabel(col,fontsize=15)
    plt.ylabel('MEDV',fontsize=15)
    
    # Fitting Polynomial Regression to the dataset 
from sklearn.preprocessing import PolynomialFeatures 
  
poly = PolynomialFeatures(degree = 4) 
df_poly = poly.fit_transform(df) 
  
poly.fit(df_poly, y) 
lin2 = LinearRegression() 
lin2.fit(df_poly, y)

# %%
plt.figure(figsize=(20, 5))

features = ['PTRATIO','LSTAT','RM']
target = df['MEDV']

for i, col in enumerate(features):
    plt.subplot(1, 3, i+1)
    x = df[col]                      
    y = target
    plt.scatter(x, y, marker='o',color= 'yellow')
    plt.title(col,fontsize=18)
    plt.xlabel(col,fontsize=15)
    plt.ylabel('MEDV',fontsize=15)
    
    # Fitting Polynomial Regression to the dataset 
from sklearn.preprocessing import PolynomialFeatures    

X_plot=np.linspace(0,1,100).reshape(-1,1)
X_plot_poly=poly_features.fit_transform(X_plot)
plt.plot(x,y,"b.")
plt.plot(X_plot_poly,model.predict(X_plot_poly),'-r')
plt.show()

# %%
plt.figure(figsize=(20, 5))
x = df.RM
y = df.MEDV
z = np.polyfit(x, y, 3)
#polynimial function
p = np.poly1d(z)


# plotting
plt.figure(figsize=(8,6))
plt.plot(x, y, '*', label='Data',color='yellow')
plt.plot(xp, p(xp), 'm--', label='Poly',)


plt.ylim(-2, 85)
plt.xlim(3, 10)
plt.title(":D", fontsize=18)
plt.xlabel('RM',fontsize=15)
plt.ylabel('MEDV')
plt.legend()

# %%
features = ['PTRATIO','LSTAT','RM']
target = df['MEDV']

for i, col in enumerate(features):
    plt.subplot(1, 3, i+1)
    x = df[col]                      
    y = target
    z = np.polyfit(x, y, 3)

xp = np.linspace(0, 55, 100)

plt.scatter(x, y, marker='o',color= 'yellow')
plt.title(col,fontsize=18)
plt.xlabel(col,fontsize=15)
plt.ylabel('MEDV',fontsize=15)

plt.ylim(-2, 85)
plt.xlim(3, 10)
plt.legend()

plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 3))(np.unique(x)),color='m')#regression line from linear plots
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(20, 5))

features = ['PTRATIO','LSTAT','RM']
target = df['MEDV']

for i, col in enumerate(features):
    plt.subplot(1, 3, i+1)
    x = df[col]                      
    y = target
    plt.scatter(x, y, marker='o',color= 'yellow')
    plt.title(col,fontsize=18)
    plt.xlabel(col,fontsize=15)
    plt.ylabel('MEDV',fontsize=15)
    
    plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 3))(np.unique(x)),color='m')#regression line

# %% [markdown]
# ## New data frame with pivot plots

# %%
df_subset = df[['RM','MEDV']]
df_subset.head()
# Out:
#       RM  MEDV
# 0  6.575  24.0
# 1  6.421  21.6
# 2  7.185  34.7
# 3  6.998  33.4
# 4  7.147  36.2

# %%
df= df_subset.pivot_table(index=['RM'])
df.head()
# Out:
#         MEDV
# RM
# 3.561  27.50
# 3.863  23.10
# 4.138  12.85
# 4.368   8.80
# 4.519   7.00

# %%
df.plot(color='m',figsize=(10,5))
plt.xlabel('MEDV', fontsize=18)
plt.ylabel('RM',fontsize=18)
plt.title(':D?', Fontsize=20)
plt.show()

# %% [markdown]
# ## Multiple Regressions with ANOVA

# %%
# For 3d plots. This import is necessary to have 3D plotting below
from mpl_toolkits.mplot3d import Axes3D

# For statistics. Requires statsmodels 5.0 or more
from statsmodels.formula.api import ols
# Analysis of Variance (ANOVA) on linear models
from statsmodels.stats.anova import anova_lm

# %%
x = np.linspace(-5, 5, 21)
# We generate a 2D grid
X, Y = np.meshgrid(x, x)



# Z is the elevation of this 2D grid
Z = -5 + 3*X - 0.5*Y + 8 * np.random.normal(size=X.shape)

# Plot the data
df = plt.figure('df')
ax = df.gca(projection='3d')
surf = ax.plot_surface(X, Y, Z, cmap=plt.cm.coolwarm,
                       rstride=1, cstride=1)
ax.view_init(20, -120)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
# Out:
# Text(0.5, 0, 'Z')

# %%
# Convert the data into a Pandas DataFrame to use the formulas framework
# in statsmodels

# First we need to flatten the data: it's 2D layout is not relevent.
X = X.flatten()
Y = Y.flatten()
Z = Z.flatten()

df = pd.DataFrame({'x': X, 'y': Y, 'z': Z})

# Fit the model
model = ols("z ~ x + y", df).fit()

# Print the summary
print(model.summary())

print("\nRetrieving manually the parameter estimates:")
print(model._results.params)
# should be array([-4.99754526,  3.00250049, -0.50514907])

# Peform analysis of variance on fitted linear model
anova_results = anova_lm(model)

print('\nANOVA results')
print(anova_results)

plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      z   R-squared:                       0.600
# Model:                            OLS   Adj. R-squared:                  0.598
# Method:                 Least Squares   F-statistic:                     328.2
# Date:                Wed, 23 Oct 2019   Prob (F-statistic):           7.92e-88
# Time:                        13:31:28   Log-Likelihood:                -1545.0
# No. Observations:                 441   AIC:                             3096.
# Df Residuals:                     438   BIC:                             3108.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -5.1029      0.384    -13.284      0.000      -5.858      -4.348
# x              3.2095      0.127     25.296      0.000       2.960       3.459
# y             -0.5163      0.127     -4.069      0.000      -0.766      -0.267
# ==============================================================================
# Omnibus:                        1.648   Durbin-Watson:                   2.076
# Prob(Omnibus):                  0.439   Jarque-Bera (JB):                1.510
# Skew:                          -0.025   Prob(JB):                        0.470
# Kurtosis:                       2.718   Cond. No.                         3.03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Retrieving manually the parameter estimates:
# [-5.10290336  3.20946793 -0.51631531]
#
# ANOVA results
#              df        sum_sq       mean_sq           F        PR(>F)
# x           1.0  41640.516692  41640.516692  639.893212  1.102199e-87
# y           1.0   1077.655714   1077.655714   16.560423  5.590533e-05
# Residual  438.0  28502.484426     65.074165         NaN           NaN
