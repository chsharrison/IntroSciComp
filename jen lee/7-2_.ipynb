# %% [markdown]
# # Lecure 7.2 Even more data analysis with pandas

# %% [markdown]
# Lots more coding today, with a bit of discussion.
#
# Homework is to do some analysis of the movies dataset and present your results on Tuesday

# %% [markdown]
# # 1. Warm-up

# %% [markdown]
# Learning objectives: modifying plots by looking at the documentation and examples, pandas mastery

# %% [markdown]
# For this exercise we are using the durations data TED Talk database from last time

# %% [markdown]
# ### 1.1
# Create the pandas film_datetime column used previously. Save the resulting pandas dataframe as a new file with a different name. Load this new file into pandas to check that your new column is there.

# %%
import pandas as pd

# %%
    import matplotlib.pyplot as plt

# %%
#load in file
ted=pd.read_csv('\\Users\\baezj\\Documents\\ted.csv')

# %%
#check what is in file
ted.dtypes
# Out:
# comments               int64
# description           object
# duration               int64
# event                 object
# film_date              int64
# languages              int64
# main_speaker          object
# name                  object
# num_speaker            int64
# published_date         int64
# ratings               object
# related_talks         object
# speaker_occupation    object
# tags                  object
# title                 object
# url                   object
# views                  int64
# dtype: object

# %%
# add a mew column with a pandas dateime object
ted['film_datetime'] = pd.to_datetime(ted.film_date, unit = 's')

# %%
#cheking data types to see new coluomn
ted.dtypes
# Out:
# comments                       int64
# description                   object
# duration                       int64
# event                         object
# film_date                      int64
# languages                      int64
# main_speaker                  object
# name                          object
# num_speaker                    int64
# published_date                 int64
# ratings                       object
# related_talks                 object
# speaker_occupation            object
# tags                          object
# title                         object
# url                           object
# views                          int64
# film_datetime         datetime64[ns]
# dtype: object

# %%
ted.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event   film_date  languages   main_speaker  \
# 0  TED2006  1140825600         60   Ken Robinson
# 1  TED2006  1140825600         43        Al Gore
# 2  TED2006  1140739200         26    David Pogue
# 3  TED2006  1140912000         35  Majora Carter
# 4  TED2006  1140566400         48   Hans Rosling
#
#                                             name  num_speaker  published_date  \
# 0      Ken Robinson: Do schools kill creativity?            1      1151367060
# ...

# %%
#saving df as new file 
ted.to_csv('test.csv')

# %%
# double slashes works
ted.to_csv('\\Users\\baezj\\Documents\\test_2.csv')

# %%
#single slashes no go 
ted.to_csv('\Users\baezj\Documents\test_3.csv')
# Out:
#   File "<ipython-input-57-a09f65e9d716>", line 2
#     ted.to_csv('\Users\baezj\Documents\test_3.csv')
#               ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 0-1: truncated \UXXXXXXXX escape

# %%
#cheking to see if new column is there #loading the new file 
ted_2= pd.read_csv('test.csv')

# %%
#cheking for new column in data
ted_2.head()
# Out:
#    Unnamed: 0  comments                                        description  \
# 0           0      4553  Sir Ken Robinson makes an entertaining and pro...
# 1           1       265  With the same humor and humanity he exuded in ...
# 2           2       124  New York Times columnist David Pogue takes aim...
# 3           3       200  In an emotionally charged talk, MacArthur-winn...
# 4           4       593  You've never seen data presented like this. Wi...
#
#    duration    event   film_date  languages   main_speaker  \
# 0      1164  TED2006  1140825600         60   Ken Robinson
# 1       977  TED2006  1140825600         43        Al Gore
# 2      1286  TED2006  1140739200         26    David Pogue
# 3      1116  TED2006  1140912000         35  Majora Carter
# 4      1190  TED2006  1140566400         48   Hans Rosling
#
#                                             name  num_speaker  published_date  \
# ...

# %%
ted.film_datetime.dt.year.value_counts().sort_index()
# Out:
# 1972      1
# 1983      1
# 1984      1
# 1990      1
# 1991      1
# 1994      1
# 1998      6
# 2001      5
# 2002     27
# 2003     33
# 2004     33
# 2005     66
# 2006     50
# 2007    114
# 2008     84
# 2009    232
# 2010    267
# 2011    270
# 2012    267
# 2013    270
# 2014    237
# 2015    239
# 2016    246
# 2017     98
# Name: film_datetime, dtype: int64

# %%
ted.film_datetime.dt.year.value_counts().sort_index().plot(kind='hist',color ='pink', edgecolor='black')
plt.xlabel('Year')
plt.ylabel("Number of Ted Talks")
# Out:
# Text(0, 0.5, 'Number of Ted Talks')

# %%
#defined an empty data frame 
df = pd.DataFrame()

# %%
df.to_csv('\\Users\\baezj\\Desktop\\film_datetime.csv')

# %%
ted=pd.read_csv('\\Users\\baezj\\Desktop\\film_datetime.csv')

# %%
ted.head()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0]
# Index: []

# %%
ted.dtypes
# Out:
# Unnamed: 0    object
# dtype: object

# %% [markdown]
# ### 1.2
# Sort the durations data by month and make a histogram of the number of talks in a given month. Note that the default of 10 bins does not work well for this. How well does using 12 bins work?

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/version/0.25/getting_started/10min.html#getting-data-in-out

# %%
#how does this relate to what we did before?
#name of pandas data frame #film_datetime is a coloumn
ted.film_datetime.dt.year.head()
# Out:
# 0    2006
# 1    2006
# 2    2006
# 3    2006
# 4    2006
# Name: film_datetime, dtype: int64

# %%
help(ted.film_datetime.dt) #this didnt help :(
# Out:
# Help on DatetimeProperties in module pandas.core.indexes.accessors object:
#
# class DatetimeProperties(Properties)
#  |  DatetimeProperties(data, orig)
#  |
#  |  Accessor object for datetimelike properties of the Series values.
#  |
#  |  Examples
#  |  --------
#  |  >>> s.dt.hour
#  |  >>> s.dt.second
#  |  >>> s.dt.quarter
#  |
#  |  Returns a Series indexed like the original Series.
#  |  Raises TypeError if the Series does not contain datetimelike values.
#  |
#  |  Method resolution order:
#  |      DatetimeProperties
#  |      Properties
#  |      pandas.core.accessor.PandasDelegate
#  |      pandas.core.base.PandasObject
#  |      pandas.core.base.StringMixin
#  |      pandas.core.accessor.DirNamesMixin
#  |      pandas.core.base.NoNewAttributesMixin
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  ceil(self, *args, **kwargs)
#  |      Perform ceil operation on the data to the specified `freq`.
#  |
#  |      Parameters
#  |      ----------
# ...

# %%
#
ted.film_datetime.dt?

# %%
ted.film_datetime.dt.year
# Out:
# 0       2006
# 1       2006
# 2       2006
# 3       2006
# 4       2006
# 5       2006
# 6       2006
# 7       2006
# 8       2006
# 9       2006
# 10      2006
# 11      2006
# 12      2006
# 13      2006
# 14      2006
# 15      2006
# 16      2004
# 17      2006
# 18      2005
# 19      2005
# 20      2006
# 21      2004
# 22      2006
# 23      2006
# 24      2004
# 25      2005
# 26      2005
# 27      2004
# 28      2004
# 29      2004
#         ...
# 2520    2017
# 2521    2016
# 2522    2017
# 2523    2016
# 2524    2017
# 2525    2016
# 2526    2017
# 2527    2017
# 2528    2016
# 2529    2015
# 2530    2017
# 2531    2016
# 2532    2017
# 2533    2017
# 2534    2017
# 2535    2017
# 2536    2017
# 2537    2017
# 2538    2016
# 2539    2017
# 2540    2017
# 2541    2017
# 2542    2017
# 2543    2017
# 2544    2017
# 2545    2017
# 2546    2017
# 2547    2017
# 2548    2017
# 2549    2017
# Name: film_datetime, Length: 2550, dtype: int64

# %%
ted.film_datetime.dt.month.head(12)
# Out:
# 0     2
# 1     2
# 2     2
# 3     2
# 4     2
# 5     2
# 6     2
# 7     2
# 8     2
# 9     2
# 10    2
# 11    2
# Name: film_datetime, dtype: int64

# %%
ted.film_datetime.dt.month.value_counts().sort_index().plot(kind='hist',color='green', edgecolor='blue')
plt.xlabel('months')
plt.ylabel("Number of Ted Talks")
# Out:
# Text(0, 0.5, 'Number of Ted Talks')

# %% [markdown]
# ### 1.3
# Look at the documentation for plotting histograms (google it). Define an array that will give the bins you need to make a bin for each month with sensible endpoints, using one of the numpy functions we discussed previously. What should your bin edges be?

# %% [markdown]
# https://stackoverflow.com/questions/46309843/matplotlib-histogram-from-x-y-values-with-datetime-months-as-bins

# %% [markdown]
# https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.xticks.html

# %% [markdown]
# https://numpy.org/devdocs/reference/generated/numpy.histogram_bin_edges.html

# %%
ted.groupby(ted.film_datetime.dt.month).film_datetime.count().plot(kind="bar")
bins = np.arange(1,14)
ax.set_xticks(bins[:-1]) # x ticks are labels 
ax.set_xticklabels([datetime.date(1900,i,1).strftime('%b') for i in bins[:-1]] )
# Out:
# [Text(0.0, 0, 'Jan'),
#  Text(0.2, 0, 'Feb'),
#  Text(0.4, 0, 'Mar'),
#  Text(0.6000000000000001, 0, 'Apr'),
#  Text(0.8, 0, 'May'),
#  Text(1.0, 0, 'Jun'),
#  Text(0, 0, 'Jul'),
#  Text(0, 0, 'Aug'),
#  Text(0, 0, 'Sep'),
#  Text(0, 0, 'Oct'),
#  Text(0, 0, 'Nov'),
#  Text(0, 0, 'Dec')]

# %%
#bin edges are the color of bin outline and bin width

# %%
#google it 
ted.groupby(ted.film_datetime.dt.month).film_datetime.count().plot(kind="bar")# dataetime data sorted grouped by months, and count
np.histogram_bin_edges(arr, bins='auto', range=(0, 1))
plt.xlabel('Months')
plt.xticks(np.arange(12), calendar.month_name[1:13], rotation=20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-3dcb7089e093> in <module>
#       1 #google it
#       2 ted.groupby(ted.film_datetime.dt.month).film_datetime.count().plot(kind="bar")# dataetime data sorted grouped by months, and count
# ----> 3 np.histogram_bin_edges(arr, bins='auto', range=(0, 1))
#       4 plt.xlabel('Months')
#       5 plt.xticks(np.arange(12), calendar.month_name[1:13], rotation=20)
#
# NameError: name 'arr' is not defined

# %% [markdown]
# fig, ax = plt.subplots()
# bins = np.arange(1,14)
# ax.hist( bins = bins, edgecolor="k", align='left')
# ax.set_xticks(bins[:-1])
# ax.set_xticklabels([datetime.date(1900,i,1).strftime('%b') for i in bins[:-1]] )
# plt.title("Talks by month", fontsize=18)
# plt.show()
# bins

# %%
#example

import datetime
# %matplotlib inline

x = np.array([datetime.datetime(2014, 2, 1, 0, 0), 
              datetime.datetime(2014, 2, 13, 0, 0),
              datetime.datetime(2014, 3, 4, 0, 0), 
              datetime.datetime(2014, 3, 6, 0, 0)])

y = np.array([4,3,2,6])

frame = pd.DataFrame({'x':x,'y':y})
(frame.set_index('x'). # use date-time as index
 assign(month=lambda x: x.index.month). # add new column with month
 groupby('month'). # group by that column
 sum(). # find a sum of the only column 'y'
 plot.bar()) # make a barplot

# %% [markdown]
# ### 1.4
# Label your x-axis with month labels

# %%
ted.month.plot(kind="bar")#access months
plt.xlabel('Months')
plt.xticks(months, labels = ('Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'));
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-671b2ab4277e> in <module>
# ----> 1 ted.month.plot(kind="bar")#access months
#       2 plt.xlabel('Months')
#       3 plt.xticks(months, labels = ('Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'));
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'month'

# %% [markdown]
# # 2. Discussion
#
# ## 2.1 Semiar homework from last week
# Some potential questions for discussion:
# - What makes a good talk?
# - Does the rubric capture what makes a good talk?
# - How were the figures in the talk formatted?
# - How was this different than the figures in the paper?
#
# ## 2.2 Pandas analysis by students

# %%
#Tuesday too

# %% [markdown]
# # 3. Exercises

# %% [markdown]
# Learning objectives: pandas mastery, writing data files with pandas, data analysis: asking research questions, doing the analysis, and presenting your results

# %% [markdown]
# ### 3.1
# From the movies spreadsheet you used last week (Lec 6.2), make a histogram of all the years movies were made, combining the data in three sheets. In one plot, make two subplots, one with bins (bars) of 10 years width, and one with bins of 20 years width. Note this does not mean 10 and 20 bins!

# %%
#import the file
excel_file = 'movies.xls'
movies = pd.read_excel(excel_file)#pandas reads file
# deal with the separate sheets
movies_sheet1 = pd.read_excel(excel_file, sheet_name = 0, index_col = 0)
movies_sheet1.head()# fisrt spreadsheet
movies_sheet2 = pd.read_excel(excel_file, sheetname=1, index_col=0)
movies_sheet2.head()#second
movies_sheet3 = pd.read_excel(excel_file, sheetname=2, index_col=0)
movies_sheet3.head()#third
movies = pd.concat([movies_sheet1, movies_sheet2, movies_sheet3])#all together now
#combine the sheets into one df
xlsx = pd.ExcelFile(excel_file)
movies_sheets = []
for sheet in xlsx.sheet_names:
    movies_sheets.append(xlsx.parse(sheet))
    movies = pd.concat(movies_sheets)
# Out:
# C:\Users\baezj\Anaconda3\lib\site-packages\pandas\util\_decorators.py:188: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)

# %%
movies.Year.plot(kind = 'hist', bins = 50)

# %%
import numpy as np

# %%
bins10 = np.arange(1916,2020,10)
bins20 = np.arange(1916,2020,20)

plt.subplot(2, 1, 1)
movies.Year.plot(kind = 'hist', bins=bins10,color='blue', edgecolor='green')#outlines can be changed colors just like the color of the bars
plt.xlabel('10 Bins')
plt.ylabel('10  Bins')

plt.subplot(2, 1, 2)
movies.Year.plot(kind = 'hist', bins = bins20,color='red', edgecolor='green')
plt.ylabel('20 Bins')
# Out:
# Text(0, 0.5, '20 Bins')

# %% [markdown]
# ### 3.2
# Label your axes and change the color of the bars in each plot. Make the bars have black outlines.

# %% [markdown]
# ### 3.3
# Interpret your results. How does changing the number of bins give you a different perspective on the data? Is the dropoff over time an artifact of the dataset or is it realistic?

# %% [markdown]
# The number of bins makes the data have more points and can be too busy with a lot of bins or vice versa

# %% [markdown]
# ### 3.4
# What is the lowest IMDB score?

# %%
IMDB = movies['IMDB Score'] #defined and returned min
IMDB.min()
# Out:
# 1.6

# %% [markdown]
# ### 3.5
# Find the names of all the movies with an IMDB score below 5, put these in a new pandas dataframe along with their IMDB scores. Write this dataframe to a new file. Check that your file works by loading it back in again.

# %%
movies[IMDB < 5] #score less than 5, check score column
# Out:
#                                         Title    Year  \
# 1             Over the Hill to the Poorhouse   1920.0
# 86               The Brain That Wouldn't Die   1962.0
# 144                         The Stewardesses   1969.0
# 219                 Exorcist II: The Heretic   1977.0
# 229                               Alien Zone   1978.0
# 251                                   Meteor   1979.0
# 263                     Can't Stop the Music   1980.0
# 267                                 Galaxina   1980.0
# 274                        Raise the Titanic   1980.0
# 292                           Graduation Day   1981.0
# 293                               Heartbeeps   1981.0
# 297                                   Inchon   1981.0
# 319                                Butterfly   1982.0
# 335       Halloween III: Season of the Witch   1982.0
# 337                                Megaforce   1982.0
# 353                                Losin' It   1983.0
# ...

# %%
Scores=movies[IMDB < 5] #making a data frame

# %%
Scores
# Out:
#                                         Title    Year  \
# 1             Over the Hill to the Poorhouse   1920.0
# 86               The Brain That Wouldn't Die   1962.0
# 144                         The Stewardesses   1969.0
# 219                 Exorcist II: The Heretic   1977.0
# 229                               Alien Zone   1978.0
# 251                                   Meteor   1979.0
# 263                     Can't Stop the Music   1980.0
# 267                                 Galaxina   1980.0
# 274                        Raise the Titanic   1980.0
# 292                           Graduation Day   1981.0
# 293                               Heartbeeps   1981.0
# 297                                   Inchon   1981.0
# 319                                Butterfly   1982.0
# 335       Halloween III: Season of the Witch   1982.0
# 337                                Megaforce   1982.0
# 353                                Losin' It   1983.0
# ...

# %%
lessthn =Scores[['Title', 'IMDB Score']] #exclude other coloumns

# %%
lessthn #cheking
# Out:
#                                         Title  IMDB Score
# 1             Over the Hill to the Poorhouse          4.8
# 86               The Brain That Wouldn't Die          4.1
# 144                         The Stewardesses          4.0
# 219                 Exorcist II: The Heretic          3.7
# 229                               Alien Zone          4.1
# 251                                   Meteor          4.9
# 263                     Can't Stop the Music          4.5
# 267                                 Galaxina          3.4
# 274                        Raise the Titanic          4.7
# 292                           Graduation Day          4.5
# 293                               Heartbeeps          4.2
# 297                                   Inchon          2.7
# 319                                Butterfly          4.5
# 335       Halloween III: Season of the Witch          4.6
# 337                                Megaforce          3.5
# ...

# %%
lessthn.to_csv('\\Users\\baezj\\Documents\\Scores_Below_5.csv') #creating file in Documents by the name of "scores_below_5"

# %%
Scores_Below_5 = pd.read_csv('Scores_below_5.csv') #Pandas reads file

# %%
#check it
Scores_Below_5
# Out:
#      Unnamed: 0                                    Title  IMDB Score
# 0             1          Over the Hill to the Poorhouse          4.8
# 1            86             The Brain That Wouldn't Die          4.1
# 2           144                        The Stewardesses          4.0
# 3           219                Exorcist II: The Heretic          3.7
# 4           229                              Alien Zone          4.1
# 5           251                                  Meteor          4.9
# 6           263                    Can't Stop the Music          4.5
# 7           267                                Galaxina          3.4
# 8           274                       Raise the Titanic          4.7
# 9           292                          Graduation Day          4.5
# 10          293                              Heartbeeps          4.2
# 11          297                                  Inchon          2.7
# 12          319                               Butterfly          4.5
# ...

# %% [markdown]
# ### 3.6-9 (and homework)
#
# Now get creative. Define three research questions for this movies data set and do analysis to answer those quesitons. You will present this analysis, along with your data analysis methods, to the class on Tuesday. Showing this analysis in a notebook is fine, but make sure your plots are formatted for presentation.

# %%
movies.head()
# Out:
#                                                Title    Year  \
# 0  Intolerance: Love's Struggle Throughout the Ages   1916.0
# 1                    Over the Hill to the Poorhouse   1920.0
# 2                                    The Big Parade   1925.0
# 3                                        Metropolis   1927.0
# 4                                     Pandora's Box   1929.0
#
#                 Genres Language  Country Content Rating  Duration  \
# 0    Drama|History|War      NaN      USA      Not Rated     123.0
# 1          Crime|Drama      NaN      USA            NaN     110.0
# 2    Drama|Romance|War      NaN      USA      Not Rated     151.0
# 3         Drama|Sci-Fi   German  Germany      Not Rated     145.0
# 4  Crime|Drama|Romance   German  Germany      Not Rated     110.0
#
#    Aspect Ratio     Budget  Gross Earnings  ... Facebook Likes - Actor 1  \
# 0          1.33   385907.0             NaN  ...                    436.0
# ...

# %% [markdown]
# # 1) IMDB score in relation to budget, does the score increase with a higher budget?

# %%
IMDB = movies['IMDB Score']

# %%
IMDB
# Out:
# 0       8.0
# 1       4.8
# 2       8.3
# 3       8.3
# 4       8.0
# 5       6.3
# 6       7.8
# 7       6.6
# 8       7.7
# 9       6.5
# 10      8.2
# 11      7.8
# 12      8.6
# 13      7.1
# 14      7.7
# 15      7.8
# 16      7.0
# 17      8.0
# 18      8.2
# 19      8.2
# 20      8.1
# 21      7.1
# 22      7.8
# 23      7.5
# 24      8.2
# 25      6.5
# 26      7.8
# 27      7.4
# 28      8.6
# 29      7.0
#        ...
# 1574    3.5
# 1575    7.4
# 1576    7.9
# 1577    7.5
# 1578    7.2
# 1579    7.5
# 1580    7.5
# 1581    7.3
# 1582    7.6
# 1583    8.7
# 1584    8.4
# 1585    6.6
# 1586    8.1
# 1587    7.5
# 1588    7.1
# 1589    7.2
# 1590    8.3
# 1591    7.3
# 1592    7.3
# 1593    9.5
# 1594    8.2
# 1595    7.5
# 1596    6.7
# 1597    7.9
# 1598    8.4
# 1599    8.2
# 1600    7.3
# 1601    7.1
# 1602    7.7
# 1603    7.0
# Name: IMDB Score, Length: 5042, dtype: float64

# %% [markdown]
# sorted_by_score = movies.sort_values(['IMDB']),ascending=False

# %%
sorted_by_budget = movies.sort_values(['Budget'], ascending=False)

# %%
sorted_by_budget["Budget"] #10 highest budgets?
# Out:
# 1367    1.221550e+10
# 1039    4.200000e+09
# 999     2.500000e+09
# 986     2.400000e+09
# 885     2.127520e+09
# 490     1.100000e+09
# 1236    1.000000e+09
# 1129    7.000000e+08
# 1272    7.000000e+08
# 90      6.000000e+08
# 1730    5.536320e+08
# 328     4.000000e+08
# 1311    3.900000e+08
# 1524    3.000000e+08
# 1717    3.000000e+08
# 534     2.637000e+08
# 163     2.600000e+08
# 1547    2.580000e+08
# 1548    2.580000e+08
# 351     2.500000e+08
# 1183    2.500000e+08
# 1406    2.500000e+08
# 1937    2.500000e+08
# 618     2.500000e+08
# 1401    2.500000e+08
# 1110    2.500000e+08
# 1314    2.450000e+08
# 1867    2.370000e+08
# 608     2.300000e+08
# 1770    2.250000e+08
#             ...
# 1574             NaN
# 1575             NaN
# 1576             NaN
# 1577             NaN
# 1578             NaN
# 1579             NaN
# 1580             NaN
# 1581             NaN
# 1582             NaN
# 1583             NaN
# 1584             NaN
# 1585             NaN
# ...

# %%
sorted_by_budget["Budget"].head(10).plot(kind="barh")
plt.xlabel('Score',fontsize=18)
plt.ylabel('Budget',fontsize=18)
plt.show()

# %% [markdown]
# sorted_by_budget["IMDB"].head(10).plot(kind="barh")
# plt.show()

# %% [markdown]
# movies_subset = movies[['IMDB', 'Budget']]
# movies_subset.head()

# %%
movies_subset = movies[['IMDB Score','Budget']]
movies_subset.head()
# Out:
#    IMDB Score     Budget
# 0         8.0   385907.0
# 1         4.8   100000.0
# 2         8.3   245000.0
# 3         8.3  6000000.0
# 4         8.0        NaN

# %%
Budget= movies_subset.pivot_table(index=['Budget'])
Budget.head()
# Out:
#         IMDB Score
# Budget
# 218.0          7.2
# 1100.0         6.6
# 1400.0         6.3
# 3250.0         7.8
# 4500.0         6.9

# %%
movies.plot('Budget','IMDB Score', kind = 'hist',color='orange',edgecolor='k',bins=50, figsize=(10,5))
plt.xlabel('Score',fontsize=18)
plt.ylabel('Budget',fontsize=18)
plt.title ('Does budget affect score?',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Does budget affect score?')

# %%
movies["Budget"].mean()
# Out:
# 39752620.436387606

# %%
movies["IMDB Score"].mean()
# Out:
# 6.442007140023794

# %% [markdown]
# ### Results : Very few movies with a low budget recieve a high IMDB score, A high budget does correlate to a higher score.

# %% [markdown]
# # 2) Content rating in relation to IMDB scores, does a 'mature' rating increase or decrease score?

# %%
Rating=movies['Content Rating']

# %%
Rating
# Out:
# 0       Not Rated
# 1             NaN
# 2       Not Rated
# 3       Not Rated
# 4       Not Rated
# 5          Passed
# 6          Passed
# 7         Unrated
# 8         Unrated
# 9        Approved
# 10        Unrated
# 11       Approved
# 12              G
# 13       Approved
# 14       Approved
# 15       Approved
# 16       Approved
# 17       Approved
# 18              G
# 19      Not Rated
# 20         Passed
# 21         Passed
# 22              G
# 23       Approved
# 24      Not Rated
# 25       Approved
# 26       Approved
# 27       Approved
# 28             PG
# 29         Passed
#           ...
# 1574        TV-14
# 1575          NaN
# 1576          NaN
# 1577        TV-14
# 1578          NaN
# 1579        TV-PG
# 1580        TV-14
# 1581        TV-MA
# 1582          NaN
# 1583          NaN
# 1584        TV-14
# 1585          NaN
# 1586          NaN
# 1587        TV-PG
# 1588        TV-14
# 1589        TV-Y7
# 1590        TV-MA
# 1591          NaN
# 1592          NaN
# ...

# %%
movies_subset = movies[['IMDB Score','Content Rating']]
movies_subset.head()
# Out:
#    IMDB Score Content Rating
# 0         8.0      Not Rated
# 1         4.8            NaN
# 2         8.3      Not Rated
# 3         8.3      Not Rated
# 4         8.0      Not Rated

# %%
Score= movies_subset.pivot_table(index=['Content Rating'])
Score.head()
# Out:
#                 IMDB Score
# Content Rating
# Approved          7.325455
# G                 6.529464
# GP                6.916667
# M                 6.840000
# NC-17             6.542857

# %%
movies.plot('Content Rating', 'IMDB Score', kind = 'hist',color='orange',bins=50,edgecolor='blue')
plt.ylabel('Rating',fontsize=18)
plt.xlabel('IMDB score',fontsize=18)
plt.title ('Does rating affect score?',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Does rating affect score?')

# %%
Score.plot(color='m',figsize=(10,5))
plt.xlabel('Score', fontsize=18)
plt.ylabel('Content Rating',fontsize=18)
plt.title('Does rating affect score?', Fontsize=20)
plt.show()

# %% [markdown]
# ### Results : Rated mature movies have a higher IMDB score, rated PG movies have a significant lower score.

# %% [markdown]
# # 3) Year movie was released in relation to IMDB score: Does age of film affect IMDB score?

# %%
movies.sort_values('Year').tail()
# Out:
#                                      Title  Year  \
# 1599              War & Peace                NaN
# 1600                    Wings                NaN
# 1601               Wolf Creek                NaN
# 1602        Wuthering Heights                NaN
# 1603  Yu-Gi-Oh! Duel Monsters                NaN
#
#                                          Genres  Language    Country  \
# 1599                  Drama|History|Romance|War   English         UK
# 1600                               Comedy|Drama   English        USA
# 1601                      Drama|Horror|Thriller   English  Australia
# 1602                              Drama|Romance   English         UK
# 1603  Action|Adventure|Animation|Family|Fantasy  Japanese      Japan
#
#      Content Rating  Duration  Aspect Ratio  Budget  Gross Earnings  ...  \
# 1599          TV-14       NaN         16.00     NaN             NaN  ...
# 1600            NaN      30.0          1.33     NaN             NaN  ...
# ...

# %%
Year=movies['Year']

# %%
Year
# Out:
# 0       1916.0
# 1       1920.0
# 2       1925.0
# 3       1927.0
# 4       1929.0
# 5       1929.0
# 6       1930.0
# 7       1932.0
# 8       1933.0
# 9       1933.0
# 10      1934.0
# 11      1935.0
# 12      1936.0
# 13      1936.0
# 14      1937.0
# 15      1937.0
# 16      1938.0
# 17      1938.0
# 18      1939.0
# 19      1939.0
# 20      1939.0
# 21      1940.0
# 22      1940.0
# 23      1940.0
# 24      1940.0
# 25      1940.0
# 26      1941.0
# 27      1942.0
# 28      1942.0
# 29      1943.0
#          ...
# 1574       NaN
# 1575       NaN
# 1576       NaN
# 1577       NaN
# 1578       NaN
# 1579       NaN
# 1580       NaN
# 1581       NaN
# 1582       NaN
# 1583       NaN
# 1584       NaN
# 1585       NaN
# 1586       NaN
# 1587       NaN
# 1588       NaN
# 1589       NaN
# 1590       NaN
# 1591       NaN
# 1592       NaN
# 1593       NaN
# 1594       NaN
# 1595       NaN
# 1596       NaN
# 1597       NaN
# 1598       NaN
# 1599       NaN
# 1600       NaN
# ...

# %% [markdown]
# movies['IMDB_Scores_per_year'] = movies.Year / movies.IMDB Scores

# %%
movies.Year.plot(kind='hist', color='y', edgecolor='k')
plt.xlabel('Year',fontsize=18)
plt.ylabel('# of Movies', fontsize=18)
plt.title('Movies each Year')
# Out:
# Text(0.5, 1.0, 'Movies each Year')

# %%
movies.film_datetime.dt.year.value_counts().sort_index().plot()

# %%
movies.plot('Year','IMDB Score',kind = 'hist',color='pink',bins=100, edgecolor='k')
plt.ylabel('Year',fontsize=18)
plt.xlabel('IMDB sore',fontsize=18)
plt.title ('Does age affect score?',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Does age affect score?')

# %%
movies_subset = movies[['Year', 'IMDB Score']]
movies_subset.head()
# Out:
#      Year  IMDB Score
# 0  1916.0         8.0
# 1  1920.0         4.8
# 2  1925.0         8.3
# 3  1927.0         8.3
# 4  1929.0         8.0

# %%
Score_by_year = movies_subset.pivot_table(index=['Year'])
Score_by_year.head()
# Out:
#         IMDB Score
# Year
# 1916.0        8.00
# 1920.0        4.80
# 1925.0        8.30
# 1927.0        8.30
# 1929.0        7.15

# %%
Score_by_year.plot(color='m',figsize=(10,5))
plt.xlabel('Year', fontsize=18)
plt.ylabel('IMDB Score',fontsize=18)
plt.title('Does age affect score?', Fontsize=20)
plt.show()

# %% [markdown]
# ### Results: IMDB scores have been declining as films are released, older films have a higher Score

# %%
Score_by_year.head(35).plot(kind='bar', figsize=(10,5))
