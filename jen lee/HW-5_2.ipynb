# %% [markdown]
# My disapointment is imesurable and my day is ruined

# %% [markdown]
# # HW_5-2

# %%
import xarray as xr

# %%
bathy = xr.open_dataset('/Users/baezj>/Documents/Gulf of mex.nc')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\xarray\backends\file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     194             try:
# --> 195                 file = self._cache[self._key]
#     196             except KeyError:
#
# ~\Anaconda3\lib\site-packages\xarray\backends\lru_cache.py in __getitem__(self, key)
#      42         with self._lock:
# ---> 43             value = self._cache[key]
#      44             self._cache.move_to_end(key)
#
# KeyError: [<function _open_scipy_netcdf at 0x000002AE6876A268>, ('C:\\Users\\baezj>\\Documents\\Gulf of mex.nc',), 'r', (('mmap', None), ('version', 2))]
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-92dd75cbd7fa> in <module>
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
from matplotlib import cm

# %%
seed = xr.read_csv('/Users/baezj/Desktop/drew buckets 190625.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-75c3bf6f4df3> in <module>
# ----> 1 seed = xr.read_csv('/Users/baezj/Desktop/drew buckets 190625.csv')
#
# AttributeError: module 'xarray' has no attribute 'read_csv'

# %%
data = xr.loadcsv('/Users/baezj/Desktop/drew buckets 190625.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-99040756f8e0> in <module>
# ----> 1 data = xr.loadcsv('/Users/baezj/Desktop/drew buckets 190625.csv')
#
# AttributeError: module 'xarray' has no attribute 'loadcsv'

# %%
data = np.load_csv('/Users/baezj/Desktop/drew buckets 190625.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-0596a462d3c3> in <module>
# ----> 1 data = np.load_csv('/Users/baezj/Desktop/drew buckets 190625.csv')
#
# AttributeError: module 'numpy' has no attribute 'load_csv'

# %%
length e1= pd.read_csv('drew buckets 190625.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-276f667aae1c> in <module>
# ----> 1 length = pd.read_csv('drew buckets 190625.csv')
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# ...

# %%
CSV = pd.read_csv('/Users/baezj/Desktop/Germination data with calculated parameters.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-21-aea43f7418cf> in <module>
# ----> 1 CSV = pd.read_csv('/Users/baezj/Desktop/Germination data with calculated parameters.xlsx')
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
data = xr.open_dataset('/Users/baezj/Desktop/Germination data with calculated parameters.xlsx')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\xarray\backends\file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     194             try:
# --> 195                 file = self._cache[self._key]
#     196             except KeyError:
#
# ~\Anaconda3\lib\site-packages\xarray\backends\lru_cache.py in __getitem__(self, key)
#      42         with self._lock:
# ---> 43             value = self._cache[key]
#      44             self._cache.move_to_end(key)
#
# KeyError: [<function _open_scipy_netcdf at 0x00000178A811B598>, ('C:\\Users\\baezj\\Desktop\\Germination data with calculated parameters.xlsx',), 'r', (('mmap', None), ('version', 2))]
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import xarray as xr

# %%
treatment = xr.open_dataset('/Users/baezj/Downloads/Germination data with calculated parameters.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\xarray\backends\file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     194             try:
# --> 195                 file = self._cache[self._key]
#     196             except KeyError:
#
# ~\Anaconda3\lib\site-packages\xarray\backends\lru_cache.py in __getitem__(self, key)
#      42         with self._lock:
# ---> 43             value = self._cache[key]
#      44             self._cache.move_to_end(key)
#
# KeyError: [<function _open_scipy_netcdf at 0x000002AE6876A268>, ('C:\\Users\\baezj\\Downloads\\Germination data with calculated parameters.csv',), 'r', (('mmap', None), ('version', 2))]
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ...

# %% [markdown]
# Tried to intsall Netcdf through the environments tab and it would not apply.

# %% [markdown]
# Same problem as class lecture 5-2
