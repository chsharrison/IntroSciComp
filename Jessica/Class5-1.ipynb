# %% [markdown]
# For Class 4_2 where we covered scipy 1.4, I've included it at the bottom of this journal

# %% [markdown]
# # Lecture 5.1 More plotting and statistics

# %% [markdown]
# Sep 24, 2019

# %% [markdown]
# ## Announcements

# %% [markdown]
# ### 1. Bring headphones next time!
#
# We are doing a pandas tutorial:
#
# https://github.com/justmarkham/pycon-2019-tutorial
#
# ### 2. New: grading warm-up exercises as assignments
# If you don’t finish, go back and correct your work.
# Grades will be up on blackboard in the next week

# %% [markdown]
# ## Warm-up

# %% [markdown]
# Using the hares/carrots/lynxes data set we used last week, plot the data in one plot with three different subplots, each with a different linestyle or color. Label your subplots appropriately.

# %%
import numpy as np
import matplotlib.pyplot as plt #for plots
# %matplotlib inline 
from matplotlib import cm

# %%
data = np.loadtxt('/Users/xfm684/Desktop/Python_notebooks/populations.txt')

# %%
#should look at what you just loaded
data
# Out:
# array([[ 1900., 30000.,  4000., 48300.],
#        [ 1901., 47200.,  6100., 48200.],
#        [ 1902., 70200.,  9800., 41500.],
#        [ 1903., 77400., 35200., 38200.],
#        [ 1904., 36300., 59400., 40600.],
#        [ 1905., 20600., 41700., 39800.],
#        [ 1906., 18100., 19000., 38600.],
#        [ 1907., 21400., 13000., 42300.],
#        [ 1908., 22000.,  8300., 44500.],
#        [ 1909., 25400.,  9100., 42100.],
#        [ 1910., 27100.,  7400., 46000.],
#        [ 1911., 40300.,  8000., 46800.],
#        [ 1912., 57000., 12300., 43800.],
#        [ 1913., 76600., 19500., 40900.],
#        [ 1914., 52300., 45700., 39400.],
#        [ 1915., 19500., 51100., 39000.],
#        [ 1916., 11200., 29700., 36700.],
#        [ 1917.,  7600., 15800., 41800.],
#        [ 1918., 14600.,  9700., 43300.],
#        [ 1919., 16200., 10100., 41300.],
#        [ 1920., 24700.,  8600., 47300.]])

# %%
year, hares, lynxes, carrots = data.T
#trick: columns to variables
##could do year = data[:,0]; hares = data[:1]; etc. data.T(ranspose)

# %%
from matplotlib import pyplot as plt

# %%
plt.axes([0.2,0.1,0.5,0.8])
plt.plot(year,hares,year,lynxes,year,carrots)
plt.legend(('Hare', 'Lynx', 'Carrot'), loc=(1.05,0.5))

# %%
#to change settings
import matplotlib as mpl
mpl.rcParams['font.size'] = 12
mpl.rcParams['lines.linewidth'] = 2.0

# %%
plt.figure(figsize = (10,4))
plt.axes([0.2,0.1,0.5,0.8])
plt.plot(year, hares, 'k:', label = 'Hares')
plt.plot(year, lynxes, 'r-', label = 'Lynxes')
plt.plot(year, carrots, 'b--', label = 'Carrots')
plt.legend()
plt.ylabel('Population')
plt.xlabel('Years')
plt.xticks([1900,1905,1910,1915,1920])
#plt.legend(('Hare', 'Lynx', 'Carrot'))
# Out:
# ([<matplotlib.axis.XTick at 0x117643fd0>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %%
#correct way to subplot
plt.figure(figsize = (15,4))

plt.subplot(1,3,1) #(rows, colums, which to plot in) #/1000 to reduce y axis
plt.plot(year, hares/1000, 'k')
plt.xlabel('Years', fontsize = 18)
plt.ylabel('Population (thousands)', fontsize = 18)
plt.title('Hares', fontsize = 18)
plt.ylim([0,80]) #for even comparison

plt.subplot(1,3,2) #second plot
plt.plot(year, lynxes/1000, 'b')
plt.xlabel('Years', fontsize = 18)
plt.title('Lynxes', fontsize = 18)
plt.ylim([0,80])

plt.subplot(1,3,3)
plt.plot(year, carrots/1000, 'g')
plt.xlabel('Years', fontsize = 18)
plt.title('Carrots', fontsize = 18)
plt.ylim([0,80])
# Out:
# (0, 80)

# %%
fig = plt.figure(figsize = (15,4))
#puts all these plots into one figure

plt.subplot(1,3,1) #(rows, colums, which to plot in) #/1000 to reduce y axis
plt.plot(year, hares/1000, 'k', label = 'Hare')
#plt.xlabel('Years', fontsize = 18)
plt.ylabel('Population (thousands)', fontsize = 18)
plt.title('Hares', fontsize = 18)
plt.ylim([0,80]) #for even comparison

plt.subplot(1,3,2) #second plot
plt.plot(year, lynxes/1000, 'b', label = 'Lynx')
plt.xlabel('Years', fontsize = 18)
plt.title('Lynxes', fontsize = 18)
plt.ylim([0,80])

plt.subplot(1,3,3)
plt.plot(year, carrots/1000, 'g', label = 'Carrots')
#plt.xlabel('Years', fontsize = 18)
plt.title('Carrots', fontsize = 18)
plt.ylim([0,80])

plt.suptitle('Title for whole plot', fontsize = 20)
fig.legend()

# %% [markdown]
# ##### How I did it

# %%
plt.axes([0.2,0.1,0.5,0.8])
plt.plot(year, hares, 'k:')
plt.title('Hares')
# Out:
# Text(0.5, 1.0, 'Hares')

# %%
plt.axes([0.2,0.1,0.5,0.8])
plt.plot(year, lynxes, 'r-')
plt.title('Lynx')
# Out:
# Text(0.5, 1.0, 'Lynx')

# %%
plt.axes([0.2,0.1,0.5,0.8])
plt.plot(year, carrots, 'b--')
plt.title('Carrots')
# Out:
# Text(0.5, 1.0, 'Carrots')

# %% [markdown]
# ## Lecture Examples

# %% [markdown]
# * Go over hares/carrots/lynxes homework problem (scipy 1.3.15.3)
# * Plot y = sin(x) on -pi to pi
#     * Go over linespace
#     * Turn the grid on
# * Create a color plot of z = sin(x)sin(y) on the interval [−π,π]×[−π,π][−π,π]×[−π,π].
# * Plot an Archimedean spiral (https://en.wikipedia.org/wiki/Archimedean_spiral)
# *     Note this involves translating some r code into python

# %%
year, hares, lynxes, carrots = data.T
populations = data[:,1:] #getting rid of first column of year data

# %%
data
# Out:
# array([[ 1900., 30000.,  4000., 48300.],
#        [ 1901., 47200.,  6100., 48200.],
#        [ 1902., 70200.,  9800., 41500.],
#        [ 1903., 77400., 35200., 38200.],
#        [ 1904., 36300., 59400., 40600.],
#        [ 1905., 20600., 41700., 39800.],
#        [ 1906., 18100., 19000., 38600.],
#        [ 1907., 21400., 13000., 42300.],
#        [ 1908., 22000.,  8300., 44500.],
#        [ 1909., 25400.,  9100., 42100.],
#        [ 1910., 27100.,  7400., 46000.],
#        [ 1911., 40300.,  8000., 46800.],
#        [ 1912., 57000., 12300., 43800.],
#        [ 1913., 76600., 19500., 40900.],
#        [ 1914., 52300., 45700., 39400.],
#        [ 1915., 19500., 51100., 39000.],
#        [ 1916., 11200., 29700., 36700.],
#        [ 1917.,  7600., 15800., 41800.],
#        [ 1918., 14600.,  9700., 43300.],
#        [ 1919., 16200., 10100., 41300.],
#        [ 1920., 24700.,  8600., 47300.]])

# %%
populations
# Out:
# array([[30000.,  4000., 48300.],
#        [47200.,  6100., 48200.],
#        [70200.,  9800., 41500.],
#        [77400., 35200., 38200.],
#        [36300., 59400., 40600.],
#        [20600., 41700., 39800.],
#        [18100., 19000., 38600.],
#        [21400., 13000., 42300.],
#        [22000.,  8300., 44500.],
#        [25400.,  9100., 42100.],
#        [27100.,  7400., 46000.],
#        [40300.,  8000., 46800.],
#        [57000., 12300., 43800.],
#        [76600., 19500., 40900.],
#        [52300., 45700., 39400.],
#        [19500., 51100., 39000.],
#        [11200., 29700., 36700.],
#        [ 7600., 15800., 41800.],
#        [14600.,  9700., 43300.],
#        [16200., 10100., 41300.],
#        [24700.,  8600., 47300.]])

# %% [markdown]
# 1. Print the mean and std of the populations of each species for the years in the period

# %%
print("           Hares,        Lynxes,    Carrots")
print("Mean:", populations.mean(axis=0))
print("Std:", populations.std(axis=0))
# Out:
#            Hares,        Lynxes,    Carrots
# Mean: [34080.95238095 20166.66666667 42400.        ]
# Std: [20897.90645809 16254.59153691  3322.50622558]

# %%
np.mean(populations, axis=0) #first axis is time
# Out:
# array([34080.95238095, 20166.66666667, 42400.        ])

# %%
np.mean(hares)
# Out:
# 34080.95238095238

# %%
np.mean(lynxes)
# Out:
# 20166.666666666668

# %% [markdown]
# 2. Which year did each species have the largest population?

# %%
j_max_years = np.argmax(populations, axis=0)
print("           Hares,Lynxes,Carrots")
print("Max. year:", year[j_max_years])
# Out:
#            Hares,Lynxes,Carrots
# Max. year: [1903. 1904. 1900.]

# %% [raw]
# ####### Scratch #######

# %%
np.argmax(hares)
# Out:
# 3

# %%
hares #index 3 is the largest value 77400
# Out:
# array([30000., 47200., 70200., 77400., 36300., 20600., 18100., 21400.,
#        22000., 25400., 27100., 40300., 57000., 76600., 52300., 19500.,
#        11200.,  7600., 14600., 16200., 24700.])

# %%
hares[3]
# Out:
# 77400.0

# %%
#to find the year of that max
#year[3]
year[np.argmax(hares)]
# Out:
# 1903.0

# %%
np.argmax(populations, axis = 0) #this gives us the index of the maximum
# Out:
# array([3, 4, 0])

# %%
max_ind = np.argmax(populations, axis = 0)

# %%
#pass this index into years array
year[max_ind]
# Out:
# array([1903., 1904., 1900.])

# %% [markdown]
# 3. Which species has the largest population for each year. (Hint: argsort and fancy indexing of np.array((['H','L','C'])))

# %%
populations
# Out:
# array([[30000.,  4000., 48300.],
#        [47200.,  6100., 48200.],
#        [70200.,  9800., 41500.],
#        [77400., 35200., 38200.],
#        [36300., 59400., 40600.],
#        [20600., 41700., 39800.],
#        [18100., 19000., 38600.],
#        [21400., 13000., 42300.],
#        [22000.,  8300., 44500.],
#        [25400.,  9100., 42100.],
#        [27100.,  7400., 46000.],
#        [40300.,  8000., 46800.],
#        [57000., 12300., 43800.],
#        [76600., 19500., 40900.],
#        [52300., 45700., 39400.],
#        [19500., 51100., 39000.],
#        [11200., 29700., 36700.],
#        [ 7600., 15800., 41800.],
#        [14600.,  9700., 43300.],
#        [16200., 10100., 41300.],
#        [24700.,  8600., 47300.]])

# %%
max_species_index = np.argmax(populations, axis = 1) #axis 1 takes us through each row
#0=hares, 1=lynx, 2=carrots

# %%
#make an array of names
species = np.array(['Hare', 'Lynx', 'Carrot'])

# %%
print('Max Species:')
print(year)
print(species[max_species_index])
# Out:
# Max Species:
# [1900. 1901. 1902. 1903. 1904. 1905. 1906. 1907. 1908. 1909. 1910. 1911.
#  1912. 1913. 1914. 1915. 1916. 1917. 1918. 1919. 1920.]
# ['Carrot' 'Carrot' 'Hare' 'Hare' 'Lynx' 'Lynx' 'Carrot' 'Carrot' 'Carrot'
#  'Carrot' 'Carrot' 'Carrot' 'Hare' 'Hare' 'Hare' 'Lynx' 'Carrot' 'Carrot'
#  'Carrot' 'Carrot' 'Carrot']

# %% [markdown]
# 4. Which years are any of the populations above 50000? (Hint: comparisons and np.any)

# %%
print(year(populations>50000))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-b0fb430110fa> in <module>
# ----> 1 print(year(populations>50000))
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
int(populations)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-7c679452c0ce> in <module>
# ----> 1 int(populations)
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %%
populations
# Out:
# array([[30000.,  4000., 48300.],
#        [47200.,  6100., 48200.],
#        [70200.,  9800., 41500.],
#        [77400., 35200., 38200.],
#        [36300., 59400., 40600.],
#        [20600., 41700., 39800.],
#        [18100., 19000., 38600.],
#        [21400., 13000., 42300.],
#        [22000.,  8300., 44500.],
#        [25400.,  9100., 42100.],
#        [27100.,  7400., 46000.],
#        [40300.,  8000., 46800.],
#        [57000., 12300., 43800.],
#        [76600., 19500., 40900.],
#        [52300., 45700., 39400.],
#        [19500., 51100., 39000.],
#        [11200., 29700., 36700.],
#        [ 7600., 15800., 41800.],
#        [14600.,  9700., 43300.],
#        [16200., 10100., 41300.],
#        [24700.,  8600., 47300.]])

# %%
populations>50000
# Out:
# array([[False, False, False],
#        [False, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [False,  True, False],
#        [False, False, False],
#        [False, False, False],
#        [False, False, False],
#        [False, False, False],
#        [False, False, False],
#        [False, False, False],
#        [False, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [False,  True, False],
#        [False, False, False],
#        [False, False, False],
#        [False, False, False],
#        [False, False, False],
#        [False, False, False]])

# %%
np.any(populations>50000, axis=0)
# Out:
# array([ True,  True, False])

# %%
if np.any(populations>500000, axis = 1):
        print (year)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-15f79bea4aa6> in <module>
# ----> 1 if np.any(populations>500000, axis = 1):
#       2         print (year)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
above_50000 = np.any(populations > 50000, axis=1)
print("Any above 50000:", year[above_50000])
#I WAS SO CLOSE!!
# Out:
# Any above 50000: [1902. 1903. 1904. 1912. 1913. 1914. 1915.]

# %% [markdown]
# 5. The top 2 years for each species when they had the lowest populations. (Hint: argsort, fancy indexing)

# %%
np.argsort(populations, axis=0, kind='quicksort')
# Out:
# array([[17,  0, 16],
#        [16,  1,  3],
#        [18, 10,  6],
#        [19, 11, 15],
#        [ 6,  8, 14],
#        [15, 20,  5],
#        [ 5,  9,  4],
#        [ 7, 18, 13],
#        [ 8,  2, 19],
#        [20, 19,  2],
#        [ 9, 12, 17],
#        [10,  7,  9],
#        [ 0, 17,  7],
#        [ 4,  6, 18],
#        [11, 13, 12],
#        [ 1, 16,  8],
#        [14,  3, 10],
#        [12,  5, 11],
#        [ 2, 14, 20],
#        [13, 15,  1],
#        [ 3,  4,  0]])

# %%
if (np.argsort(populations, axis=0, kind='quicksort') == 0):
    print()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-cfb690143b83> in <module>
# ----> 1 if (np.argsort(populations, axis=0, kind='quicksort') == 0):
#       2     print()
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
np.argsort(populations, axis=0, kind='quicksort') == 0
# Out:
# array([[False,  True, False],
#        [False, False, False],
#        [False, False, False],
#        [False, False, False],
#        [False, False, False],
#        [False, False, False],
#        [False, False, False],
#        [False, False, False],
#        [False, False, False],
#        [False, False, False],
#        [False, False, False],
#        [False, False, False],
#        [ True, False, False],
#        [False, False, False],
#        [False, False, False],
#        [False, False, False],
#        [False, False, False],
#        [False, False, False],
#        [False, False, False],
#        [False, False, False],
#        [False, False,  True]])

# %%
######IMPORTANT INDEXING TRICK HERE
j_top_2 = np.argsort(populations, axis=0)[:2] #:2 to get the 0 and 1 lowest numbers
print("Top 2 years with lowest populations for each:")
print(year[j_top_2]) #idk why I can't remember that this is how the print the years for it
# Out:
# Top 2 years with lowest populations for each:
# [[1917. 1900. 1916.]
#  [1916. 1901. 1903.]]

# %% [markdown]
# 6. Compare (plot) the change in hare population (see help(np.gradient)) and the number of lynxes. Check correlation (see help(np.corrcoef)).

# %%
np.gradient(hares)
# Out:
# array([ 17200.,  20100.,  15100., -16950., -28400.,  -9100.,    400.,
#          1950.,   2000.,   2550.,   7450.,  14950.,  18150.,  -2350.,
#        -28550., -20550.,  -5950.,   1700.,   4300.,   5050.,   8500.])

# %%
plt.plot(np.gradient(hares), label = 'Hares')
plt.plot(np.gradient(lynxes), label = 'Lynxes')
plt.legend()

# %%
#Their solution: I misunderstood the order they wanted this done in.
hare_grad = np.gradient(hares, 1.0)
print("diff(Hares) vs. Lynxes correlation", np.corrcoef(hare_grad, lynxes)[0,1])
# Out:
# diff(Hares) vs. Lynxes correlation -0.9179248480315341

# %%
np.gradient(hares, 1.0)
# Out:
# array([ 17200.,  20100.,  15100., -16950., -28400.,  -9100.,    400.,
#          1950.,   2000.,   2550.,   7450.,  14950.,  18150.,  -2350.,
#        -28550., -20550.,  -5950.,   1700.,   4300.,   5050.,   8500.])

# %%
np.corrcoef(hare_grad, lynxes)[0,1]
# Out:
# -0.9179248480315341

# %%
plt.plot(year, hare_grad)

# %%
plt.plot(year, -lynxes)

# %%
-lynxes
# Out:
# array([ -4000.,  -6100.,  -9800., -35200., -59400., -41700., -19000.,
#        -13000.,  -8300.,  -9100.,  -7400.,  -8000., -12300., -19500.,
#        -45700., -51100., -29700., -15800.,  -9700., -10100.,  -8600.])

# %%
lynxes
# Out:
# array([ 4000.,  6100.,  9800., 35200., 59400., 41700., 19000., 13000.,
#         8300.,  9100.,  7400.,  8000., 12300., 19500., 45700., 51100.,
#        29700., 15800.,  9700., 10100.,  8600.])

# %%
plt.plot(year, hare_grad, year, -lynxes)
#plt.savefig('plot.png')

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# Plot a logarithmic spiral (google it)

# %%
#skipping this class time

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# Plot the hares/carrots/lynxes data as three scatterplots as subplots in one plot, comparing hares and lynxes, hares and carrots, and carrots and lynxes. Do a (Pearson) correlation analysis for each plot/data pairs(?) (google correlation). Display your correlation coefficient on each graph.

# %%
##I don't know how to incorporate this into the graphs
np.corrcoef(hares, lynxes)[0, 1]
# Out:
# 0.07189206073535571

# %%
Hare_Carrot_CorrCoef = np.corrcoef(hares, carrots)[0, 1]

# %%
Lynx_Carrot_CorrCoef = np.corrcoef(lynxes, carrots)[0, 1]

# %%
fig = plt.figure(figsize = (15,4))
#puts all these plots into one figure

plt.subplot(1,3,1) #(rows, colums, which to plot in) #/1000 to reduce y axis
plt.title('Correlation Coeffiecient = \n' + str(np.corrcoef(hares, lynxes)[0, 1]))
plt.plot(year, hares/1000, 'k', label = 'Hare')
plt.plot(year, lynxes/1000, 'b')
#plt.xlabel('Years', fontsize = 18)
plt.ylabel('Population (thousands)', fontsize = 18)
plt.ylim([0,80]) #for even comparison


plt.subplot(1,3,2)
plt.title('Correlation Coeffiecient = \n' + str(np.corrcoef(hares, carrots)[0, 1]))
plt.plot(year, hares/1000, 'k')
plt.plot(year, carrots/1000, 'g')
#plt.xlabel('Years', fontsize = 18)
plt.ylim([0,80])

plt.subplot(1,3,3)
plt.title('Correlation Coeffiecient = \n' + str(np.corrcoef(lynxes, carrots)[0, 1]))
plt.plot(year, lynxes/1000, 'b', label = 'Lynx')
plt.plot(year, carrots/1000, 'g', label = 'Carrots')
plt.xlabel('Years', fontsize = 18)
plt.ylim([0,80])


ttl = plt.suptitle('Population Comparison', fontsize = 20)
ttl.set_position([.5, 1.05])

fig.legend()

# %% [markdown]
# ## Exercise 3

# %% [markdown]
# More lab work (if time):
# Work more from the spicy 1.4 plotting examples, or play with the extras below

# %%
plt.figure(figsize=(8,6), dpi=80)

x = np.linspace(-np.pi, np.pi, 256, endpoint=True)
c, s = np.cos(x), np.sin(x)

plt.plot(x,c, color='blue', linewidth = 1.0, linestyle='-')
plt.plot(x,s, color = 'green', linewidth = 1.0, linestyle = '-')

plt.xlim(-4.0, 4.0)
plt.xticks(np.linspace(-4,4,9, endpoint = True))

plt.ylim(-1,1)
plt.yticks(np.linspace(-1,1,5, endpoint=True))

# %%
plt.figure(figsize=(10,6), dpi=80)

x = np.linspace(-np.pi, np.pi, 256, endpoint=True)
c, s = np.cos(x), np.sin(x)

plt.plot(x,c, color='blue', linewidth = 2.5, linestyle='-')
plt.plot(x,s, color = 'red', linewidth = 2.5, linestyle = '-')

plt.xlim(x.min() * 1.1, x.max() * 1.1)
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
          [r'$-\pi$',r'$-\pi/2$',r'$0$',r'$\pi/2$',r'$\pi$'])

plt.ylim(c.min() * 1.1, c.max() * 1.1)
plt.yticks([-1,0,+1])

# %%
plt.figure(figsize=(10,6), dpi=80)

x = np.linspace(-np.pi, np.pi, 256, endpoint=True)
c, s = np.cos(x), np.sin(x)

plt.plot(x,c, color='blue', linewidth = 2.5, linestyle='-')
plt.plot(x,s, color = 'red', linewidth = 2.5, linestyle = '-')

plt.xlim(x.min() * 1.1, x.max() * 1.1)
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
          [r'$-\pi$',r'$-\pi/2$',r'$0$',r'$\pi/2$',r'$\pi$'])

plt.ylim(c.min() * 1.1, c.max() * 1.1)
plt.yticks([-1,0,+1])

#Moving Spines
ax = plt.gca() #gca stands for 'get current axis'
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_positions('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

# %% [markdown]
# ## Extras:
#
# * More advanced spiral plotting: https://blog.anvetsu.com/posts/fibonacci-golden-spiral-matplotlib-python/
# * Also, a turtle package! https://trinket.io/python/43bc79b582
