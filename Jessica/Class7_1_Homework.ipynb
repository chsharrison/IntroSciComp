# %% [markdown]
# # Lecure 7.1 More data analysis with pandas

# %% [markdown]
# We are focusing on coding today. Make sure you ask for help when you get stuck, either from the intructor or your colleagues. A little bit of struggle is good, but don't bang your head against the wall!

# %% [markdown]
# Data analysis is a proccess of interaction with data, getting to know it, using descriptive statistics, seeing how variables are related. Once you get to know the data, then creative and interesting things can happen that bring new insight and help you develop a narrative about the data you are analysing

# %% [markdown]
# ## 1. Warm up
#
# ### 1.1
# Code a function that given the area of a circle, returns both the radius and the circumference
# ### 1.2
# Add in an error statement if a negative area is passed to the function
# ### 1.3
# Use your function to plot radus and circumference for areas between 0 and 1000, counting by 20. Put both lines on one plot. Label your plot, and include a legend.

# %%
import numpy as np
import matplotlib.pyplot as plt #for plots
# %matplotlib inline 
from matplotlib import cm
import matplotlib as mpl

# %%
#1.1
#area = pi r^2
#circumference = 2 pi r
def circle_circ(a):
    r = np.sqrt(a/np.pi)
    print('radius = ', r)
    c = 2*np.pi*r
    print('circumference = ', c)

# %%
circle_circ(50)
# Out:
# radius =  3.989422804014327
# circumference =  25.066282746310005

# %%
#1.2
for a in circle_circ:
    if a < 0:
        print('error: negative area')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-28910e951246> in <module>
#       1 #1.2
# ----> 2 for a in circle_circ:
#       3     if a < 0:
#       4         print('error: negative area')
#
# TypeError: 'function' object is not iterable

# %%
def circle_circ1(a):
    if a < 0:
        print('error: negative area')
    else:
        r = np.sqrt(a/np.pi)
        print('radius = ', r)
        c = 2*np.pi*r
        print('circumference = ', c)

# %%
circle_circ(-50)
# Out:
# radius =  nan
# circumference =  nan
# /Users/xfm684/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in sqrt
#   """

# %%
#1.3: Use your function to plot radus and circumference for areas between 0 and 1000, counting by 20. Put both lines on one plot. Label your plot, and include a legend.
num = np.arange(0,1000,20)

# %%
circle_circ(num)
# Out:
# radius =  [ 0.          2.52313252  3.56824823  4.37019372  5.04626504  5.64189584
#   6.18038723  6.67558118  7.13649646  7.56939757  7.97884561  8.36828387
#   8.74038744  9.09728368  9.44069744  9.77205024 10.09253009 10.4031419
#  10.7047447  10.99807968 11.28379167 11.56244577 11.83454055 12.10051849
#  12.36077446 12.61566261 12.86550197 13.11058117 13.35116236 13.58748446
#  13.81976598 14.04820734 14.27299293 14.49429284 14.71226436 14.9270533
#  15.13879513 15.34761596 15.55363345 15.75695755 15.95769122 16.15593101
#  16.35176762 16.5452864  16.73656774 16.92568751 17.11271736 17.29772508
#  17.48077489 17.66192765]
# circumference =  [  0.          15.85330919  22.41996487  27.45873699  31.70661838
#   35.44907702  38.83251825  41.94391358  44.83992973  47.55992757
#   50.13256549  52.57947827  54.91747397  57.15991917  59.31765144
#   61.39960248  63.41323676  65.36486831  67.2598946   69.10297268
#   70.89815404  72.64898938  74.35861127  76.02979996  77.6650365
#   79.26654595  80.83633292  82.37621096  83.88782715  85.37268273
#   86.83215055  88.26748994  89.67985946  91.0703278   92.43988326
#   93.789442    95.11985514  96.43191512  97.72636117  99.00388416
#  100.26513099 101.51070832 102.74118607 103.95710042 105.15895654
#  106.34723105 107.52237425 108.68481208 109.83494794 110.97316433]

# %%
circle_circ(num(r))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-76abefa31bb9> in <module>
# ----> 1 circle_circ(num(r))
#
# NameError: name 'r' is not defined

# %%
np.meshgrid(circle_circ(num))
# Out:
# radius =  [ 0.          2.52313252  3.56824823  4.37019372  5.04626504  5.64189584
#   6.18038723  6.67558118  7.13649646  7.56939757  7.97884561  8.36828387
#   8.74038744  9.09728368  9.44069744  9.77205024 10.09253009 10.4031419
#  10.7047447  10.99807968 11.28379167 11.56244577 11.83454055 12.10051849
#  12.36077446 12.61566261 12.86550197 13.11058117 13.35116236 13.58748446
#  13.81976598 14.04820734 14.27299293 14.49429284 14.71226436 14.9270533
#  15.13879513 15.34761596 15.55363345 15.75695755 15.95769122 16.15593101
#  16.35176762 16.5452864  16.73656774 16.92568751 17.11271736 17.29772508
#  17.48077489 17.66192765]
# circumference =  [  0.          15.85330919  22.41996487  27.45873699  31.70661838
#   35.44907702  38.83251825  41.94391358  44.83992973  47.55992757
#   50.13256549  52.57947827  54.91747397  57.15991917  59.31765144
#   61.39960248  63.41323676  65.36486831  67.2598946   69.10297268
#   70.89815404  72.64898938  74.35861127  76.02979996  77.6650365
#   79.26654595  80.83633292  82.37621096  83.88782715  85.37268273
#   86.83215055  88.26748994  89.67985946  91.0703278   92.43988326
#   93.789442    95.11985514  96.43191512  97.72636117  99.00388416
#  100.26513099 101.51070832 102.74118607 103.95710042 105.15895654
#  106.34723105 107.52237425 108.68481208 109.83494794 110.97316433]
# [array([None], dtype=object)]

# %% [markdown]
# ## 2. TED Talk exercises

# %% [markdown]
# For the following, use the TED Talk dataset we used in week 5

# %% [markdown]
# ### 2.1 Basics
# How do you display all of the data types in a pandas data set? Demonstrate.

# %%
import pandas as pd
ted = pd.read_csv('ted.txt')

# %%
ted.dtypes
# Out:
# comments               int64
# description           object
# duration               int64
# event                 object
# film_date              int64
# languages              int64
# main_speaker          object
# name                  object
# num_speaker            int64
# published_date         int64
# ratings               object
# related_talks         object
# speaker_occupation    object
# tags                  object
# title                 object
# url                   object
# views                  int64
# dtype: object

# %%
ted.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event   film_date  languages   main_speaker  \
# 0  TED2006  1140825600         60   Ken Robinson
# 1  TED2006  1140825600         43        Al Gore
# 2  TED2006  1140739200         26    David Pogue
# 3  TED2006  1140912000         35  Majora Carter
# 4  TED2006  1140566400         48   Hans Rosling
#
#                                             name  num_speaker  published_date  \
# 0      Ken Robinson: Do schools kill creativity?            1      1151367060
# 1           Al Gore: Averting the climate crisis            1      1151367060
# 2                  David Pogue: Simplicity sells            1      1151367060
# 3             Majora Carter: Greening the ghetto            1      1151367060
# 4  Hans Rosling: The best stats you've ever seen            1      1151440680
#
#                                              ratings  \
# 0  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1  [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 2  [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
# 3  [{'id': 3, 'name': 'Courageous', 'count': 760}...
# 4  [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
#
#                                        related_talks  \
# 0  [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...
# 1  [{'id': 243, 'hero': 'https://pe.tedcdn.com/im...
# 2  [{'id': 1725, 'hero': 'https://pe.tedcdn.com/i...
# 3  [{'id': 1041, 'hero': 'https://pe.tedcdn.com/i...
# 4  [{'id': 2056, 'hero': 'https://pe.tedcdn.com/i...
#
#                      speaker_occupation  \
# 0                       Author/educator
# 1                      Climate advocate
# 2                  Technology columnist
# 3    Activist for environmental justice
# 4  Global health expert; data visionary
#
#                                                 tags  \
# 0  ['children', 'creativity', 'culture', 'dance',...
# 1  ['alternative energy', 'cars', 'climate change...
# 2  ['computers', 'entertainment', 'interface desi...
# 3  ['MacArthur grant', 'activism', 'business', 'c...
# 4  ['Africa', 'Asia', 'Google', 'demo', 'economic...
#
#                              title  \
# 0      Do schools kill creativity?
# 1      Averting the climate crisis
# 2                 Simplicity sells
# 3              Greening the ghetto
# 4  The best stats you've ever seen
#
#                                                  url     views
# 0  https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 1  https://www.ted.com/talks/al_gore_on_averting_...   3200520
# 2  https://www.ted.com/talks/david_pogue_says_sim...   1636292
# 3  https://www.ted.com/talks/majora_carter_s_tale...   1697550
# 4  https://www.ted.com/talks/hans_rosling_shows_t...  12005869

# %%
ted.isna().sum()
# Out:
# comments              0
# description           0
# duration              0
# event                 0
# film_date             0
# languages             0
# main_speaker          0
# name                  0
# num_speaker           0
# published_date        0
# ratings               0
# related_talks         0
# speaker_occupation    6
# tags                  0
# title                 0
# url                   0
# views                 0
# dtype: int64

# %% [markdown]
# ### 2.2 Working with data in pandas: sorting and plotting
# #### 2.2.1
# Display just the name and duration of the talks.

# %%
ted[['title', 'duration']]
# Out:
#                                                   title  duration
# 0                           Do schools kill creativity?      1164
# 1                           Averting the climate crisis       977
# 2                                      Simplicity sells      1286
# 3                                   Greening the ghetto      1116
# 4                       The best stats you've ever seen      1190
# 5                                  Why we do what we do      1305
# 6                                     Letting go of God       992
# 7                Behind the design of Seattle's library      1198
# 8     Let's teach religion -- all religion -- in sch...      1485
# 9                                     A life of purpose      1262
# 10         My wish: A call for open-source architecture      1414
# 11                        My wish: A global day of film      1538
# 12                      My wish: Help me stop pandemics      1550
# 13     The radical promise of the multi-touch interface       527
# 14                                 One Laptop per Child      1057
# 15                      An 11-year-old's magical violin      1481
# 16                        Improvising on piano, aged 14      1445
# 17                        Simple designs to save a life       906
# 18                   Organic design, inspired by nature      1170
# 19                               The birth of Wikipedia      1201
# 20     The birth of the open-source learning revolution      1114
# 21                                      Nerdcore comedy      1136
# 22              Meet the founder of the blog revolution      1006
# 23                            Why we love, why we cheat      1407
# 24                           Happiness in body and soul      1225
# 25          Chemical scum that dream of distant quasars      1140
# 26                    Why the universe seems so strange      1316
# 27                    The freakonomics of crack dealing      1275
# 28                Choice, happiness and spaghetti sauce      1050
# 29                  The surprising science of happiness      1276
# ...                                                 ...       ...
# 2520  What would happen if we upload our brains to c...       736
# 2521  What the sugar coating on your cells is trying...       685
# 2522                        "The Sacred Art of the Ori"       530
# 2523  When workers own companies, the economy is mor...       747
# 2524            Fun, fierce and fantastical African art       310
# 2525           Why we need to end the era of orphanages       791
# 2526       Can a robot pass a university entrance exam?       817
# 2527  How the US government spies on people who prot...       865
# 2528    How your pictures can help reclaim lost history       717
# 2529  Dare to refuse the origin myths that claim who...      1156
# 2530  A smog vacuum cleaner and other magical city d...       738
# 2531  How young people join violent extremist groups...       698
# 2532    How to build a company where the best ideas win       993
# 2533      Would you live in a floating city in the sky?       663
# 2534         What it feels like to see Earth from space       725
# 2535                             Who belongs in a city?       723
# 2536  How our friendship survives our opposing politics       865
# 2537              There's more to life than being happy       738
# 2538  What really motivates people to be honest in b...       808
# 2539  A forgotten ancient grain that could help Afri...       934
# 2540  The real reason manufacturing jobs are disappe...       722
# 2541           The fascinating physics of everyday life       957
# 2542  Living sculptures that stand for history's truths       795
# 2543  How digital DNA could help you make better hea...       894
# 2544  Why Africa must become a center of knowledge a...       810
# 2545  What we're missing in the debate about immigra...       476
# 2546                    The most Martian place on Earth       290
# 2547  What intelligent machines can learn from a sch...       651
# 2548       A black man goes undercover in the alt-right      1100
# 2549  How a video game might help us build better ci...       519
#
# [2550 rows x 2 columns]

# %% [markdown]
# #### 2.2.2
# Now sort by duration. Display 1) the 10 shortest and 2) the 10 longest talks

# %%
ted[['title', 'duration']].sort_values('duration')
# Out:
#                                                   title  duration
# 239                            The ancestor of language       135
# 248                                            "Clonie"       140
# 547                                The modern euphonium       141
# 454                    A supercharged motorcycle design       143
# 264                         The wonder of Zulu wire art       153
# 606                           Weird, or just different?       162
# 86    Global warming's theme song, "Manhattan in Jan...       163
# 1390               Forget multitasking, try monotasking       172
# 593      Making maps to fight disaster, build economies       174
# 722                     Don't build your home, grow it!       176
# 479                   Teach statistics before calculus!       178
# 272                         Blindfold origami and cello       178
# 940                               How to tie your shoes       179
# 1499                      "High School Training Ground"       180
# 1254                      Mining minerals from seawater       181
# 601                                  What teachers make       182
# 625                     Watch me play ... the audience!       184
# 549                       The refugees of boom-and-bust       185
# 474                   An electrifying organ performance       185
# 105                   What squatter cities can teach us       185
# 1431                            Print your own medicine       186
# 249           A performance with breath, music, passion       186
# 653                             How to start a movement       189
# 1444                                Dance, tiny robots!       189
# 242                        Your genes are not your fate       192
# 758                         Keep your goals to yourself       195
# 796         "(Nothing But) Flowers" with string quartet       195
# 785                       The best gift I ever survived       197
# 320                          A story of mixed emoticons       197
# 49    The killer American diet that's sweeping the p...       198
# ...                                                 ...       ...
# 347                                 Life in Second Life      1711
# 96                                     Militant atheism      1750
# 660                           Singing old poems to life      1758
# 1646                    Depression, the secret we share      1761
# 2430                         We should all be feminists      1768
# 360                         Play! Experiment! Discover!      1772
# 146                         10 ways the world could end      1782
# 150                                 Life at 30,000 feet      1791
# 276                    Close-up card magic with a twist      1868
# 285                    The web is more than "better TV"      1899
# 206                    My green agenda for architecture      1917
# 89                                  How to truly listen      1929
# 1704      The NSA responds to Edward Snowden's TED Talk      2010
# 354                           Why we make bad decisions      2018
# 40    My wish: Manufactured landscapes and green edu...      2065
# 1701               Here's how we take back the Internet      2102
# 180   Rebuilding a neighborhood with beauty, dignity...      2128
# 226                     Juggling as art ... and science      2222
# 589                            The uniqueness of humans      2246
# 2441            The future we're building -- and boring      2450
# 202                            My days as a young rebel      2678
# 947            Authentic creativity vs. karaoke culture      2761
# 2421  Political common ground in a polarized United ...      2853
# 580                       What's the right thing to do?      3296
# 600                          Growing up in the universe      3475
# 594                                    Stories of Haiti      3573
# 2387  Nationalism vs. globalism: the new political d...      3608
# 629                           Physics is fun to imagine      3955
# 588              Really achieving your childhood dreams      4587
# 640                Parrots, the universe and everything      5256
#
# [2550 rows x 2 columns]

# %% [markdown]
# #### 2.2.3
# What is the 10th longest talk?

# %%
ted[['title', 'duration']].sort_values('duration').tail(10)
#Answer is My days as a young rebel
# Out:
#                                                   title  duration
# 202                            My days as a young rebel      2678
# 947            Authentic creativity vs. karaoke culture      2761
# 2421  Political common ground in a polarized United ...      2853
# 580                       What's the right thing to do?      3296
# 600                          Growing up in the universe      3475
# 594                                    Stories of Haiti      3573
# 2387  Nationalism vs. globalism: the new political d...      3608
# 629                           Physics is fun to imagine      3955
# 588              Really achieving your childhood dreams      4587
# 640                Parrots, the universe and everything      5256

# %% [markdown]
# #### 2.2.4
# What unit of time is the duration in? How do you know?

# %%
#parrots the universe and everything is 1 hr 27 min 37 s
#5256 = 3600 + 1620 + 37
#seconds

# %% [markdown]
# #### 2.2.5
# Plot the durations as a histogram, using a sensible number of bins. Label your axes. How did you decide how many bins to use?

# %%
ted.duration.plot(kind = 'hist') 
plt.xlabel('Duration (s)')
# Out:
# Text(0.5, 0, 'Duration (s)')

# %%
ted.duration.plot(kind = 'hist', bins=100) 
plt.xlabel('Duration (s)')
#I feel like this one is the more reasonable histogram. Obviously there's a lot of shorter talks, but there are some longer ones and this one shows that population a little better.
# Out:
# Text(0.5, 0, 'Duration (s)')

# %%
ted.duration.plot(kind = 'hist', bins=1000) 
plt.xlabel('Duration (s)')
# Out:
# Text(0.5, 0, 'Duration (s)')

# %% [markdown]
# #### 2.2.6
# Now plot as a box plot. Explain what the box plot is showing: what is the box, what is the line in the middle, what are the dots?

# %%
ted.duration.plot(kind = 'box') 
#the box is the majority duration of videos. the circles are the outliers. error bars are showing where some also lie.

# %% [markdown]
# #### 2.2.7
# Find the median, mean, mode and standard deviation of the durations. Are these consistent with your plots above? Explain.

# %%
ted.duration.mean()
#this is within the box
# Out:
# 826.5101960784314

# %%
ted.duration.median()
#I think this is the green line
# Out:
# 848.0

# %%
ted.duration.mode()
#1 looks like the top of the box
# Out:
# 0     848
# 1    1099
# dtype: int64

# %%
ted.duration.std()
#would appear to be the extend of the error bars?
# Out:
# 374.0091380189218

# %% [markdown]
# #### 2.2.8
# Is this a normal distribution? Explain. How does this affect your analysis above?

# %% [markdown]
# It seems normal to me? the majority of the videos are shorter and in that boxed area, but the outliers exist. I think the analysis is fairly accurate.

# %% [markdown]
# #### 2.3.1-4
#
# Going back to the tutorial, make sure you have created the film_datetime variable
#
# In the command:
#
# ted.film_datetime.dt.year.value_counts().sort_index()
#
# What do the dt, year, value_counts and sort_index commands do? Explain each one and demonstrate

# %%
ted['film_datetime'] = pd.to_datetime(ted.film_date, unit='s')

# %%
ted.film_datetime.dt.year.value_counts().sort_index()
# Out:
# 1972      1
# 1983      1
# 1984      1
# 1990      1
# 1991      1
# 1994      1
# 1998      6
# 2001      5
# 2002     27
# 2003     33
# 2004     33
# 2005     66
# 2006     50
# 2007    114
# 2008     84
# 2009    232
# 2010    267
# 2011    270
# 2012    267
# 2013    270
# 2014    237
# 2015    239
# 2016    246
# 2017     98
# Name: film_datetime, dtype: int64

# %%
ted.film_datetime.dt
#dt accesses the pandas datetime package

# %%
ted.film_datetime.dt.year
#year gives us the years (as apposed to days or months)
# Out:
# 0       2006
# 1       2006
# 2       2006
# 3       2006
# 4       2006
# 5       2006
# 6       2006
# 7       2006
# 8       2006
# 9       2006
# 10      2006
# 11      2006
# 12      2006
# 13      2006
# 14      2006
# 15      2006
# 16      2004
# 17      2006
# 18      2005
# 19      2005
# 20      2006
# 21      2004
# 22      2006
# 23      2006
# 24      2004
# 25      2005
# 26      2005
# 27      2004
# 28      2004
# 29      2004
#         ...
# 2520    2017
# 2521    2016
# 2522    2017
# 2523    2016
# 2524    2017
# 2525    2016
# 2526    2017
# 2527    2017
# 2528    2016
# 2529    2015
# 2530    2017
# 2531    2016
# 2532    2017
# 2533    2017
# 2534    2017
# 2535    2017
# 2536    2017
# 2537    2017
# 2538    2016
# 2539    2017
# 2540    2017
# 2541    2017
# 2542    2017
# 2543    2017
# 2544    2017
# 2545    2017
# 2546    2017
# 2547    2017
# 2548    2017
# 2549    2017
# Name: film_datetime, Length: 2550, dtype: int64

# %%
ted.film_datetime.dt.year.value_counts()
#this gives us how many films are within that year
# Out:
# 2013    270
# 2011    270
# 2010    267
# 2012    267
# 2016    246
# 2015    239
# 2014    237
# 2009    232
# 2007    114
# 2017     98
# 2008     84
# 2005     66
# 2006     50
# 2003     33
# 2004     33
# 2002     27
# 1998      6
# 2001      5
# 1983      1
# 1991      1
# 1994      1
# 1990      1
# 1984      1
# 1972      1
# Name: film_datetime, dtype: int64

# %%
ted.film_datetime.dt.year.value_counts().sort_index()
#this sorts by the index? It's not by year or the amount of films in that year
# Out:
# 1972      1
# 1983      1
# 1984      1
# 1990      1
# 1991      1
# 1994      1
# 1998      6
# 2001      5
# 2002     27
# 2003     33
# 2004     33
# 2005     66
# 2006     50
# 2007    114
# 2008     84
# 2009    232
# 2010    267
# 2011    270
# 2012    267
# 2013    270
# 2014    237
# 2015    239
# 2016    246
# 2017     98
# Name: film_datetime, dtype: int64

# %% [markdown]
# #### 2.3.5
# Why does the data need to be manipulated this way to plot it?
# What was the research question?

# %% [markdown]
# The data would need to be manipulated this way to check that the plot is categorizing the data correctly and not being affected too much by outliers.
#
# The research questions would've been something along the lines of, "what is the more common duration of TedTalks?"
#
# I got confused as to which plot you're referring. The more recent bit would've been

# %% [markdown]
# #### 2.3.6
# (Re)Make the plot and label your axes.

# %%
ted.duration.plot(kind = 'box') 
plt.xlabel('Occurance')
plt.ylabel('Duration (s)')
# Out:
# Text(0, 0.5, 'Duration (s)')

# %%
ted.film_datetime.dt.year.value_counts().sort_index().plot()
plt.xlabel('Years')
plt.ylabel("Number of TedTalks?")
# Out:
# Text(0, 0.5, 'Number of TedTalks?')

# %% [markdown]
# #### Bonus
# Could you make a similar plot, say a histogram, and get the same information?

# %%
ted.film_datetime.dt.year.value_counts().sort_index().plot(kind = 'hist')
#doesn't look right.  I can't quite figure out what's being plotted

# %% [markdown]
# #### 2.3.2
# Research another way to use the pandas datatime data to analyse the Ted Talks. Explain your methods

# %%
ted.head()
#I would try to see what occupations were popular for tedtalks during certain years, what topics were popular during what years using the tags.
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event   film_date  languages   main_speaker  \
# 0  TED2006  1140825600         60   Ken Robinson
# 1  TED2006  1140825600         43        Al Gore
# 2  TED2006  1140739200         26    David Pogue
# 3  TED2006  1140912000         35  Majora Carter
# 4  TED2006  1140566400         48   Hans Rosling
#
#                                             name  num_speaker  published_date  \
# 0      Ken Robinson: Do schools kill creativity?            1      1151367060
# 1           Al Gore: Averting the climate crisis            1      1151367060
# 2                  David Pogue: Simplicity sells            1      1151367060
# 3             Majora Carter: Greening the ghetto            1      1151367060
# 4  Hans Rosling: The best stats you've ever seen            1      1151440680
#
#                                              ratings  \
# 0  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1  [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 2  [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
# 3  [{'id': 3, 'name': 'Courageous', 'count': 760}...
# 4  [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
#
#                                        related_talks  \
# 0  [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...
# 1  [{'id': 243, 'hero': 'https://pe.tedcdn.com/im...
# 2  [{'id': 1725, 'hero': 'https://pe.tedcdn.com/i...
# 3  [{'id': 1041, 'hero': 'https://pe.tedcdn.com/i...
# 4  [{'id': 2056, 'hero': 'https://pe.tedcdn.com/i...
#
#                      speaker_occupation  \
# 0                       Author/educator
# 1                      Climate advocate
# 2                  Technology columnist
# 3    Activist for environmental justice
# 4  Global health expert; data visionary
#
#                                                 tags  \
# 0  ['children', 'creativity', 'culture', 'dance',...
# 1  ['alternative energy', 'cars', 'climate change...
# 2  ['computers', 'entertainment', 'interface desi...
# 3  ['MacArthur grant', 'activism', 'business', 'c...
# 4  ['Africa', 'Asia', 'Google', 'demo', 'economic...
#
#                              title  \
# 0      Do schools kill creativity?
# 1      Averting the climate crisis
# 2                 Simplicity sells
# 3              Greening the ghetto
# 4  The best stats you've ever seen
#
#                                                  url     views film_datetime
# 0  https://www.ted.com/talks/ken_robinson_says_sc...  47227110    2006-02-25
# 1  https://www.ted.com/talks/al_gore_on_averting_...   3200520    2006-02-25
# 2  https://www.ted.com/talks/david_pogue_says_sim...   1636292    2006-02-24
# 3  https://www.ted.com/talks/majora_carter_s_tale...   1697550    2006-02-26
# 4  https://www.ted.com/talks/hans_rosling_shows_t...  12005869    2006-02-22

# %% [markdown]
# #### 2.3.3
# Get creative! Now it is time for you to do some analysis on your own using the TED Talks dataset. Find a few ineresting ways to analyse this data set, which you will present to the class on Thursday.
#
# Note: I don't think people got here. I got here and couldn't get anything new to work.

# %%
ted[['tags','film_datetime']]
# Out:
#                                                    tags film_datetime
# 0     ['children', 'creativity', 'culture', 'dance',...    2006-02-25
# 1     ['alternative energy', 'cars', 'climate change...    2006-02-25
# 2     ['computers', 'entertainment', 'interface desi...    2006-02-24
# 3     ['MacArthur grant', 'activism', 'business', 'c...    2006-02-26
# 4     ['Africa', 'Asia', 'Google', 'demo', 'economic...    2006-02-22
# 5     ['business', 'culture', 'entertainment', 'goal...    2006-02-02
# 6     ['Christianity', 'God', 'atheism', 'comedy', '...    2006-02-24
# 7     ['architecture', 'collaboration', 'culture', '...    2006-02-23
# 8     ['God', 'TED Brain Trust', 'atheism', 'brain',...    2006-02-02
# 9     ['Christianity', 'God', 'culture', 'happiness'...    2006-02-25
# 10    ['activism', 'architecture', 'collaboration', ...    2006-02-26
# 11    ['TED Prize', 'art', 'culture', 'entertainment...    2006-02-26
# 12    ['TED Prize', 'collaboration', 'disease', 'ebo...    2006-02-23
# 13    ['demo', 'design', 'interface design', 'techno...    2006-02-06
# 14    ['children', 'design', 'education', 'entrepren...    2006-02-23
# 15    ['entertainment', 'music', 'performance', 'vio...    2006-02-23
# 16    ['creativity', 'entertainment', 'music', 'perf...    2004-02-26
# 17    ['MacArthur grant', 'alternative energy', 'des...    2006-02-24
# 18    ['DNA', 'biology', 'creativity', 'design', 'in...    2005-02-25
# 19    ['business', 'collaboration', 'culture', 'inve...    2005-07-14
# 20    ['business', 'collaboration', 'culture', 'glob...    2006-02-23
# 21    ['collaboration', 'comedy', 'community', 'cult...    2004-02-24
# 22    ['business', 'communication', 'community', 'cu...    2006-02-23
# 23    ['cognitive science', 'culture', 'evolution', ...    2006-02-24
# 24    ['culture', 'entertainment', 'gender', 'global...    2004-02-04
# 25    ['climate change', 'cosmos', 'culture', 'envir...    2005-07-14
# 26    ['astronomy', 'biology', 'cognitive science', ...    2005-07-07
# 27    ['business', 'cities', 'culture', 'economics',...    2004-02-27
# 28    ['business', 'choice', 'consumerism', 'culture...    2004-02-26
# 29    ['TED Brain Trust', 'brain', 'choice', 'cultur...    2004-02-02
# ...                                                 ...           ...
# 2520  ['AI', 'computers', 'economics', 'future', 'hu...    2017-04-24
# 2521  ['biology', 'biomechanics', 'cancer', 'chemist...    2016-04-24
# 2522  ['Africa', 'art', 'beauty', 'creativity', 'per...    2017-04-24
# 2523  ['TEDx', 'business', 'capitalism', 'community'...    2016-10-08
# 2524  ['Africa', 'TED Fellows', 'art', 'creativity',...    2017-04-24
# 2525  ['TEDx', 'activism', 'children', 'family', 'po...    2016-05-24
# 2526  ['AI', 'education', 'intelligence', 'robots', ...    2017-04-24
# 2527  ['TEDx', 'United States', 'activism', 'democra...    2017-04-23
# 2528  ['TEDx', 'ancient world', 'archaeology', 'cons...    2016-06-08
# 2529  ['TEDx', 'community', 'humanity', 'identity', ...    2015-04-24
# 2530  ['architecture', 'art', 'cities', 'creativity'...    2017-04-24
# 2531  ['TEDx', 'security', 'social media', 'terroris...    2016-06-18
# 2532  ['algorithm', 'business', 'collaboration', 'co...    2017-04-24
# 2533  ['TED en Español', 'art', 'creativity', 'desig...    2017-04-24
# 2534  ['TEDx', 'art', 'climate change', 'environment...    2017-04-07
# 2535  ['Africa', 'activism', 'cities', 'government',...    2017-08-27
# 2536  ['TEDx', 'communication', 'friendship', 'polit...    2017-07-08
# 2537  ['happiness', 'humanity', 'personal growth', '...    2017-04-24
# 2538  ['TEDx', 'business', 'corruption', 'economics'...    2016-11-11
# 2539  ['Africa', 'agriculture', 'farming', 'food', '...    2017-08-27
# 2540  ['business', 'capitalism', 'collaboration', 'e...    2017-07-20
# 2541             ['TEDx', 'physics', 'play', 'science']    2017-02-19
# 2542  ['Africa', 'activism', 'art', 'community', 'hi...    2017-08-27
# 2543  ['DNA', 'Human body', 'biology', 'data', 'entr...    2017-04-24
# 2544  ['Africa', 'agriculture', 'history', 'leadersh...    2017-08-27
# 2545  ['TED Residency', 'United States', 'community'...    2017-06-06
# 2546  ['Mars', 'South America', 'TED Fellows', 'astr...    2017-04-24
# 2547  ['AI', 'ants', 'fish', 'future', 'innovation',...    2017-04-24
# 2548  ['Internet', 'TEDx', 'United States', 'communi...    2017-07-08
# 2549  ['cities', 'design', 'future', 'infrastructure...    2017-04-24
#
# [2550 rows x 2 columns]

# %%
ted.tags.str.contains('science').value_counts()
# Out:
# False    1946
# True      604
# Name: tags, dtype: int64

# %%
ted.tags.str.contains('climate').value_counts()
# Out:
# False    2463
# True       87
# Name: tags, dtype: int64

# %%
ted.tags.str.contains('agriculture').value_counts()
# Out:
# False    2514
# True       36
# Name: tags, dtype: int64

# %%
ted.tags.str.contains('Africa').value_counts()
# Out:
# False    2445
# True      105
# Name: tags, dtype: int64

# %%
ted.tags.str.contains('fish').value_counts()
# Out:
# False    2522
# True       28
# Name: tags, dtype: int64

# %%
ted.tags.str.contains('environment').value_counts()
# Out:
# False    2385
# True      165
# Name: tags, dtype: int64

# %%
ted.tags.str.contains('collaboration').value_counts()
# Out:
# False    2376
# True      174
# Name: tags, dtype: int64

# %%
ted.tags.str.contains('business').value_counts()
# Out:
# False    2195
# True      355
# Name: tags, dtype: int64

# %%
ted.tags.str.contains('education').value_counts()
# Out:
# False    2397
# True      153
# Name: tags, dtype: int64

# %%
ted.tags.str.contains('climate').value_counts()
# Out:
# False    2463
# True       87
# Name: tags, dtype: int64

# %%
ted.tags.str.contains('art').value_counts()
# Out:
# False    2271
# True      279
# Name: tags, dtype: int64

# %%
ted.tags.str.contains('climate').value_counts()
# Out:
# False    2463
# True       87
# Name: tags, dtype: int64

# %%
def science_tags(x):
    for i in x:
        if i['name'] == ['science', 'climate', 'environment']:
            return i['count']

# %%
ted.tags.apply(science_tags)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-712ab6ce0d82> in <module>
# ----> 1 ted.tags.apply(science_tags)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-50-61570e043f00> in science_tags(x)
#       1 def science_tags(x):
#       2     for i in x:
# ----> 3         if i['name'] == ['science', 'climate', 'environment']:
#       4             return i['count']
#
# TypeError: string indices must be integers

# %%
ted.groupby('speaker_occupation').film_datetime.tail()
# Out:
# 0      2006-02-25
# 2      2006-02-24
# 3      2006-02-26
# 5      2006-02-02
# 6      2006-02-24
# 8      2006-02-02
# 9      2006-02-25
# 10     2006-02-26
# 12     2006-02-23
# 13     2006-02-06
# 14     2006-02-23
# 15     2006-02-23
# 16     2004-02-26
# 17     2006-02-24
# 18     2005-02-25
# 19     2005-07-14
# 20     2006-02-23
# 21     2004-02-24
# 22     2006-02-23
# 23     2006-02-24
# 24     2004-02-04
# 25     2005-07-14
# 29     2004-02-02
# 31     2005-02-26
# 32     2005-07-14
# 33     2005-07-13
# 34     2005-07-01
# 35     2005-07-14
# 36     2005-07-12
# 37     2006-02-24
#           ...
# 2520   2017-04-24
# 2521   2016-04-24
# 2522   2017-04-24
# 2523   2016-10-08
# 2524   2017-04-24
# 2525   2016-05-24
# 2526   2017-04-24
# 2527   2017-04-23
# 2528   2016-06-08
# 2529   2015-04-24
# 2530   2017-04-24
# 2531   2016-06-18
# 2532   2017-04-24
# 2533   2017-04-24
# 2534   2017-04-07
# 2535   2017-08-27
# 2536   2017-07-08
# 2537   2017-04-24
# 2538   2016-11-11
# 2539   2017-08-27
# 2540   2017-07-20
# 2541   2017-02-19
# 2542   2017-08-27
# 2543   2017-04-24
# 2544   2017-08-27
# 2545   2017-06-06
# 2546   2017-04-24
# 2547   2017-04-24
# 2548   2017-07-08
# 2549   2017-04-24
# Name: film_datetime, Length: 2103, dtype: datetime64[ns]

# %%
ted.speaker_occupation.value_counts()
# Out:
# Writer                                          45
# Designer                                        34
# Artist                                          34
# Journalist                                      33
# Entrepreneur                                    31
# Architect                                       30
# Inventor                                        27
# Psychologist                                    26
# Photographer                                    25
# Filmmaker                                       21
# Economist                                       20
# Neuroscientist                                  20
# Educator                                        20
# Author                                          20
# Philosopher                                     16
# Roboticist                                      16
# Biologist                                       15
# Physicist                                       14
# Marine biologist                                11
# Musician                                        11
# Technologist                                    10
# Activist                                        10
# Global health expert; data visionary            10
# Philanthropist                                   9
# Astronomer                                       9
# Oceanographer                                    9
# Graphic designer                                 9
# Poet                                             9
# Behavioral economist                             9
# Historian                                        9
#                                                 ..
# African grey parrot                              1
# Geneticist, physician                            1
# COO, Unilever                                    1
# Disaster relief expert                           1
# Author, journalist                               1
# Biologist, Nobel laureate                        1
# Longevity coach, explorer                        1
# Founder, Gravity                                 1
# Language                                         1
# Biological miner                                 1
# Airborne logistics activist                      1
# Medical researcher and educator                  1
# Writer, columnist                                1
# Transhumanist                                    1
# Stuntman                                         1
# YouTube educator                                 1
# X-ray visionary                                  1
# Cognitive scientist and design critic            1
# Creative spirit                                  1
# Poet, playwright                                 1
# Protector of whales                              1
# Pianist, composer                                1
# Translator, plain language activist              1
# Amateur musicians                                1
# Social investment visionary                      1
# Marketing expert                                 1
# Citizen biomedical researcher                    1
# Film executive                                   1
# Psychologist, author                             1
# Director of photography, National Geographic     1
# Name: speaker_occupation, Length: 1458, dtype: int64

# %%
occupation_counts = ted.speaker_occupation.value_counts()

# %%
top_occupations = occupation_counts[occupation_counts >= 5].index

# %%
top_occupations
# Out:
# Index(['Writer', 'Designer', 'Artist', 'Journalist', 'Entrepreneur',
#        'Architect', 'Inventor', 'Psychologist', 'Photographer', 'Filmmaker',
#        'Economist', 'Neuroscientist', 'Educator', 'Author', 'Philosopher',
#        'Roboticist', 'Biologist', 'Physicist', 'Marine biologist', 'Musician',
#        'Technologist', 'Activist', 'Global health expert; data visionary',
#        'Philanthropist', 'Astronomer', 'Oceanographer', 'Graphic designer',
#        'Poet', 'Behavioral economist', 'Historian', 'Singer/songwriter',
#        'Social psychologist', 'Computer scientist', 'Novelist', 'Engineer',
#        'Futurist', 'Mathematician', 'Astrophysicist', 'Techno-illusionist',
#        'Climate advocate', 'Legal activist', 'Comedian',
#        'Performance poet, multimedia artist', 'Reporter',
#        'Social entrepreneur', 'Evolutionary biologist', 'Photojournalist',
#        'Writer, activist', 'Singer-songwriter', 'Researcher', 'Chef',
#        'Physician', 'Game designer', 'Paleontologist',
#        'Investor and advocate for moral leadership', 'Science writer',
#        'Tech visionary', 'Violinist', 'Sound consultant',
#        'Social Media Theorist', 'Environmentalist, futurist',
#        'Musician, activist', 'Producer', 'Chemist', 'Sculptor', 'Cartoonist',
#        'Surgeon', 'Data scientist'],
#       dtype='object')

# %%
ted[ted.speaker_occupation.isin(top_occupations)]
# Out:
#       comments                                        description  duration  \
# 1          265  With the same humor and humanity he exuded in ...       977
# 4          593  You've never seen data presented like this. Wi...      1190
# 7           46  Architect Joshua Prince-Ramus takes the audien...      1198
# 11          55  Jehane Noujaim unveils her 2006 TED Prize wish...      1538
# 14          99  Nicholas Negroponte, founder of the MIT Media ...      1057
# 15         325  Violinist Sirena Huang gives a technically bri...      1481
# 2533  Tomás Saraceno: Would you live in a floating ...            1
# 2534  Benjamin Grant: What it feels like to see Eart...            1
# 2535        OluTimehin Adegbeye: Who belongs in a city?            1
# 2537  Emily Esfahani Smith: There's more to life tha...            1
# 2538  Alexander Wagner: What really motivates people...            1
# 2539  Pierre Thiam: A forgotten ancient grain that c...            1
# 2541  Helen Czerski: The fascinating physics of ever...            1
# 2542  Sethembile Msezane: Living sculptures that sta...            1
# 2545  Duarte Geraldino: What we're missing in the de...            1
# 2549  Karoliina Korppoo: How a video game might help...            1
#
#       published_date                                            ratings  \
# 1         1151367060  [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 4         1151440680  [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
# 7         1152490260  [{'id': 9, 'name': 'Ingenious', 'count': 195},...
# 11        1153786260  [{'id': 1, 'name': 'Beautiful', 'count': 70}, ...
# 14        1154391060  [{'id': 3, 'name': 'Courageous', 'count': 83},...
# 15        1154995860  [{'id': 1, 'name': 'Beautiful', 'count': 1671}...
# 26        1158019860  [{'id': 1, 'name': 'Beautiful', 'count': 333},...
# 27        1158624660  [{'id': 7, 'name': 'Funny', 'count': 485}, {'i...
# 28        1158624660  [{'id': 7, 'name': 'Funny', 'count': 1668}, {'...
# 30        1159229460  [{'id': 7, 'name': 'Funny', 'count': 1526}, {'...
# 34        1160439060  [{'id': 1, 'name': 'Beautiful', 'count': 60}, ...
# 39        1162253460  [{'id': 11, 'name': 'Longwinded', 'count': 41}...
# 40        1162253460  [{'id': 1, 'name': 'Beautiful', 'count': 106},...
# 46        1165363860  [{'id': 3, 'name': 'Courageous', 'count': 180}...
# 48        1166055060  [{'id': 7, 'name': 'Funny', 'count': 949}, {'i...
# 50        1167696660  [{'id': 8, 'name': 'Informative', 'count': 265...
# 53        1168301460  [{'id': 1, 'name': 'Beautiful', 'count': 126},...
# 54        1168992660  [{'id': 1, 'name': 'Beautiful', 'count': 214},...
# 56        1170202260  [{'id': 10, 'name': 'Inspiring', 'count': 94},...
# 60        1171843860  [{'id': 9, 'name': 'Ingenious', 'count': 89}, ...
# 62        1172621460  [{'id': 7, 'name': 'Funny', 'count': 199}, {'i...
# 63        1175559060  [{'id': 9, 'name': 'Ingenious', 'count': 37}, ...
# 64        1175559060  [{'id': 9, 'name': 'Ingenious', 'count': 60}, ...
# 65        1175559060  [{'id': 3, 'name': 'Courageous', 'count': 637}...
# 70        1175731860  [{'id': 9, 'name': 'Ingenious', 'count': 121},...
# 71        1175731860  [{'id': 1, 'name': 'Beautiful', 'count': 27}, ...
# 72        1175731860  [{'id': 2, 'name': 'Confusing', 'count': 31}, ...
# 74        1175731860  [{'id': 2, 'name': 'Confusing', 'count': 69}, ...
# 78        1175731860  [{'id': 9, 'name': 'Ingenious', 'count': 448},...
# 79        1175731860  [{'id': 9, 'name': 'Ingenious', 'count': 78}, ...
# ...              ...                                                ...
# 2431      1492440513  [{'id': 1, 'name': 'Beautiful', 'count': 344},...
# 2432      1492527759  [{'id': 8, 'name': 'Informative', 'count': 201...
# 2434      1492700670  [{'id': 24, 'name': 'Persuasive', 'count': 133...
# 2436      1493046727  [{'id': 3, 'name': 'Courageous', 'count': 121}...
# 2442      1493738150  [{'id': 3, 'name': 'Courageous', 'count': 220}...
# 2444      1493909824  [{'id': 1, 'name': 'Beautiful', 'count': 197},...
# 2449      1494601475  [{'id': 8, 'name': 'Informative', 'count': 171...
# 2456      1495465574  [{'id': 10, 'name': 'Inspiring', 'count': 950}...
# 2464      1496327443  [{'id': 10, 'name': 'Inspiring', 'count': 196}...
# 2465      1496400857  [{'id': 1, 'name': 'Beautiful', 'count': 151},...
# 2467      1496674795  [{'id': 10, 'name': 'Inspiring', 'count': 188}...
# 2470      1496933333  [{'id': 8, 'name': 'Informative', 'count': 374...
# 2487      1500044323  [{'id': 24, 'name': 'Persuasive', 'count': 293...
# 2493      1500907957  [{'id': 10, 'name': 'Inspiring', 'count': 130}...
# 2498      1501513721  [{'id': 3, 'name': 'Courageous', 'count': 27},...
# 2499      1501599710  [{'id': 10, 'name': 'Inspiring', 'count': 94},...
# 2502      1501859800  [{'id': 10, 'name': 'Inspiring', 'count': 72},...
# 2506      1502375863  [{'id': 1, 'name': 'Beautiful', 'count': 174},...
# 2523      1503932075  [{'id': 3, 'name': 'Courageous', 'count': 46},...
# 2530      1504623555  [{'id': 2, 'name': 'Confusing', 'count': 2}, {...
# 2533      1504796048  [{'id': 1, 'name': 'Beautiful', 'count': 29}, ...
# 2534      1504814438  [{'id': 10, 'name': 'Inspiring', 'count': 46},...
# 2535      1504882266  [{'id': 3, 'name': 'Courageous', 'count': 77},...
# 2537      1505227376  [{'id': 1, 'name': 'Beautiful', 'count': 484},...
# 2538      1505246451  [{'id': 10, 'name': 'Inspiring', 'count': 50},...
# 2539      1505313942  [{'id': 10, 'name': 'Inspiring', 'count': 73},...
# 2541      1505419202  [{'id': 11, 'name': 'Longwinded', 'count': 29}...
# 2542      1505488093  [{'id': 1, 'name': 'Beautiful', 'count': 41}, ...
# 2545      1505851216  [{'id': 3, 'name': 'Courageous', 'count': 24},...
# 2549      1506092422  [{'id': 21, 'name': 'Unconvincing', 'count': 2...
#
#                                           related_talks  \
# 1     [{'id': 243, 'hero': 'https://pe.tedcdn.com/im...
# 4     [{'id': 2056, 'hero': 'https://pe.tedcdn.com/i...
# 7     [{'id': 750, 'hero': 'https://pe.tedcdn.com/im...
# 11    [{'id': 2228, 'hero': 'https://pe.tedcdn.com/i...
# 14    [{'id': 2043, 'hero': 'https://pe.tedcdn.com/i...
# 15    [{'id': 2273, 'hero': 'https://pe.tedcdn.com/i...
# 26    [{'id': 1276, 'hero': 'https://pe.tedcdn.com/i...
# 27    [{'id': 20, 'hero': 'https://pe.tedcdn.com/ima...
# 28    [{'id': 93, 'hero': 'https://pe.tedcdn.com/ima...
# 30    [{'id': 2023, 'hero': 'https://pe.tedcdn.com/i...
# 34    [{'id': 2213, 'hero': 'https://pe.tedcdn.com/i...
# 39    [{'id': 156, 'hero': 'https://pe.tedcdn.com/im...
# 40    [{'id': 279, 'hero': 'https://pe.tedcdn.com/im...
# 46    [{'id': 75, 'hero': 'https://pe.tedcdn.com/ima...
# 48    [{'id': 148, 'hero': 'https://pe.tedcdn.com/im...
# 50    [{'id': 643, 'hero': 'https://pe.tedcdn.com/im...
# 53    [{'id': 2264, 'hero': 'https://pe.tedcdn.com/i...
# 54    [{'id': 167, 'hero': 'https://pe.tedcdn.com/im...
# 56    [{'id': 58, 'hero': 'https://pe.tedcdn.com/ima...
# 60    [{'id': 90, 'hero': 'https://pe.tedcdn.com/ima...
# 62    [{'id': 93, 'hero': 'https://pe.tedcdn.com/ima...
# 63    [{'id': 59, 'hero': 'https://pe.tedcdn.com/ima...
# 64    [{'id': 340, 'hero': 'https://pe.tedcdn.com/im...
# 65    [{'id': 56, 'hero': 'https://pe.tedcdn.com/ima...
# 70    [{'id': 2, 'hero': 'https://pe.tedcdn.com/imag...
# 71    [{'id': 227, 'hero': 'https://pe.tedcdn.com/im...
# 72    [{'id': 356, 'hero': 'https://pe.tedcdn.com/im...
# 74    [{'id': 27, 'hero': 'https://pe.tedcdn.com/ima...
# 78    [{'id': 162, 'hero': 'https://pe.tedcdn.com/im...
# 79    [{'id': 42, 'hero': 'https://pe.tedcdn.com/ima...
# ...                                                 ...
# 2431  [{'id': 2183, 'hero': 'https://pe.tedcdn.com/i...
# 2432  [{'id': 2723, 'hero': 'https://pe.tedcdn.com/i...
# 2434  [{'id': 2130, 'hero': 'https://pe.tedcdn.com/i...
# 2436  [{'id': 2665, 'hero': 'https://pe.tedcdn.com/i...
# 2442  [{'id': 1651, 'hero': 'https://pe.tedcdn.com/i...
# 2444  [{'id': 2213, 'hero': 'https://pe.tedcdn.com/i...
# 2449  [{'id': 886, 'hero': 'https://pe.tedcdn.com/im...
# 2456  [{'id': 2324, 'hero': 'https://pe.tedcdn.com/i...
# 2464  [{'id': 2673, 'hero': 'https://pe.tedcdn.com/i...
# 2465  [{'id': 2248, 'hero': 'https://pe.tedcdn.com/i...
# 2467  [{'id': 2625, 'hero': 'https://pe.tedcdn.com/i...
# 2470  [{'id': 2495, 'hero': 'https://pe.tedcdn.com/i...
# 2487  [{'id': 2798, 'hero': 'https://pe.tedcdn.com/i...
# 2493  [{'id': 2580, 'hero': 'https://pe.tedcdn.com/i...
# 2498  [{'id': 2318, 'hero': 'https://pe.tedcdn.com/i...
# 2499  [{'id': 2532, 'hero': 'https://pe.tedcdn.com/i...
# 2502  [{'id': 2533, 'hero': 'https://pe.tedcdn.com/i...
# 2506  [{'id': 2491, 'hero': 'https://pe.tedcdn.com/i...
# 2523  [{'id': 1041, 'hero': 'https://pe.tedcdn.com/i...
# 2530  [{'id': 2774, 'hero': 'https://pe.tedcdn.com/i...
# 2533  [{'id': 1085, 'hero': 'https://pe.tedcdn.com/i...
# 2534  [{'id': 2511, 'hero': 'https://pe.tedcdn.com/i...
# 2535  [{'id': 2880, 'hero': 'https://pe.tedcdn.com/i...
# 2537  [{'id': 2399, 'hero': 'https://pe.tedcdn.com/i...
# 2538  [{'id': 1246, 'hero': 'https://pe.tedcdn.com/i...
# 2539  [{'id': 2873, 'hero': 'https://pe.tedcdn.com/i...
# 2541  [{'id': 2491, 'hero': 'https://pe.tedcdn.com/i...
# 2542  [{'id': 2873, 'hero': 'https://pe.tedcdn.com/i...
# 2545  [{'id': 2596, 'hero': 'https://pe.tedcdn.com/i...
# 2549  [{'id': 2682, 'hero': 'https://pe.tedcdn.com/i...
#
#                               speaker_occupation  \
# 1                               Climate advocate
# 4           Global health expert; data visionary
# 7                                      Architect
# 11                                     Filmmaker
# 14                                Tech visionary
# 15                                     Violinist
# 26                        Evolutionary biologist
# 27                                     Economist
# 28                                        Writer
# 30                                  Psychologist
# 34    Investor and advocate for moral leadership
# 39                            Musician, activist
# 40                                  Photographer
# 46                            Musician, activist
# 48           Performance poet, multimedia artist
# 50                                        Author
# 53                                  Photographer
# 54                                Astrophysicist
# 56                                        Writer
# 60                                      Inventor
# 62                                    Journalist
# 63                                      Activist
# 64                                     Biologist
# 65                               Photojournalist
# 70                                      Inventor
# 71                                      Futurist
# 72                              Graphic designer
# 74                                     Architect
# 78                                        Artist
# 79                                   Philosopher
# ...                                          ...
# 2431                                   Architect
# 2432                                  Astronomer
# 2434                                   Physician
# 2436                                  Journalist
# 2442                                   Historian
# 2444                                Entrepreneur
# 2449                               Oceanographer
# 2456                                   Historian
# 2464                                   Physician
# 2465                                    Musician
# 2467                                 Philosopher
# 2470                              Neuroscientist
# 2487                                Psychologist
# 2493                                   Architect
# 2498                                  Roboticist
# 2499                                      Artist
# 2502                          Computer scientist
# 2506                              Science writer
# 2523                                Entrepreneur
# 2530                                      Artist
# 2533                                      Artist
# 2534                                      Author
# 2535                            Writer, activist
# 2537                                      Author
# 2538                                   Economist
# 2539                                        Chef
# 2541                                   Physicist
# 2542                                      Artist
# 2545                                  Journalist
# 2549                               Game designer
#
#                                                    tags  \
# 1     ['alternative energy', 'cars', 'climate change...
# 4     ['Africa', 'Asia', 'Google', 'demo', 'economic...
# 7     ['architecture', 'collaboration', 'culture', '...
# 11    ['TED Prize', 'art', 'culture', 'entertainment...
# 14    ['children', 'design', 'education', 'entrepren...
# 15    ['entertainment', 'music', 'performance', 'vio...
# 26    ['astronomy', 'biology', 'cognitive science', ...
# 27    ['business', 'cities', 'culture', 'economics',...
# 28    ['business', 'choice', 'consumerism', 'culture...
# 30    ['business', 'choice', 'culture', 'decision-ma...
# 34    ['Africa', 'TED Brain Trust', 'business', 'cul...
# 39    ['AIDS', 'Africa', 'activism', 'entertainment'...
# 40    ['TED Prize', 'art', 'cities', 'culture', 'des...
# 46    ['TED Brain Trust', 'activism', 'art', 'collab...
# 48    ['culture', 'entertainment', 'love', 'performa...
# 50    ['business', 'cities', 'culture', 'entrepreneu...
# 53    ['activism', 'art', 'culture', 'design', 'film...
# 54    ['astronomy', 'climate change', 'complexity', ...
# 56    ['cities', 'culture', 'design', 'disease', 'he...
# 60    ['MacArthur grant', 'collaboration', 'design',...
# 62    ['choice', 'culture', 'happiness', 'health', '...
# 63    ['Africa', 'TED Prize', 'business', 'culture',...
# 64    ['TED Prize', 'ants', 'biodiversity', 'biology...
# 65    ['activism', 'art', 'culture', 'global issues'...
# 70    ['business', 'cars', 'industrial design', 'inn...
# 71    ['DNA', 'TED Brain Trust', 'biotech', 'busines...
# 72    ['TED Brain Trust', 'art', 'design', 'happines...
# 74    ['architecture', 'cities', 'culture', 'design'...
# 78    ['Brazil', 'animation', 'art', 'creativity', '...
# 79    ['biotech', 'culture', 'future', 'global issue...
# ...                                                 ...
# 2431  ['TEDNYC', 'architecture', 'art', 'collaborati...
# 2432  ['astronomy', 'discovery', 'space', 'telescope...
# 2434  ['Addiction', 'TEDMED', 'cancer', 'communicati...
# 2436  ['Africa', 'communication', 'community', 'glob...
# 2442  ['TEDx', 'communication', 'global issues', 'hi...
# 2444  ['Africa', 'TED Fellows', 'activism', 'communi...
# 2449  ['Anthropocene', 'Senses', 'TEDx', 'animals', ...
# 2456  ['capitalism', 'economics', 'inequality', 'mon...
# 2464  ['Africa', 'TED Prize', 'collaboration', 'dise...
# 2465                 ['history', 'live music', 'music']
# 2467  ['Internet', 'communication', 'democracy', 'id...
# 2470  ['AI', 'algorithm', 'brain', 'cognitive scienc...
# 2487  ['Addiction', 'computers', 'interface design',...
# 2493  ['architecture', 'cities', 'community', 'desig...
# 2498         ['demo', 'future', 'robots', 'technology']
# 2499  ['art', 'history', 'identity', 'inequality', '...
# 2502  ['AI', 'algorithm', 'computers', 'sight', 'tec...
# 2506  ['Moon', 'TEDx', 'astronomy', 'beauty', 'natur...
# 2523  ['TEDx', 'business', 'capitalism', 'community'...
# 2530  ['architecture', 'art', 'cities', 'creativity'...
# 2533  ['TED en Español', 'art', 'creativity', 'desig...
# 2534  ['TEDx', 'art', 'climate change', 'environment...
# 2535  ['Africa', 'activism', 'cities', 'government',...
# 2537  ['happiness', 'humanity', 'personal growth', '...
# 2538  ['TEDx', 'business', 'corruption', 'economics'...
# 2539  ['Africa', 'agriculture', 'farming', 'food', '...
# 2541             ['TEDx', 'physics', 'play', 'science']
# 2542  ['Africa', 'activism', 'art', 'community', 'hi...
# 2545  ['TED Residency', 'United States', 'community'...
# 2549  ['cities', 'design', 'future', 'infrastructure...
#
#                                                   title  \
# 1                           Averting the climate crisis
# 4                       The best stats you've ever seen
# 7                Behind the design of Seattle's library
# 11                        My wish: A global day of film
# 14                                 One Laptop per Child
# 15                      An 11-year-old's magical violin
# 26                    Why the universe seems so strange
# 27                    The freakonomics of crack dealing
# 28                Choice, happiness and spaghetti sauce
# 30                                The paradox of choice
# 34                     Invest in Africa's own solutions
# 39                    My wish: Three actions for Africa
# 40    My wish: Manufactured landscapes and green edu...
# 46                       Fight injustice with raw video
# 48                         If I controlled the Internet
# 50                    The hidden world of shadow cities
# 53                        Photos of endangered cultures
# 54                           Is this our final century?
# 56      How the "ghost map" helped end a killer disease
# 60                                  Everyday inventions
# 62                                In praise of slowness
# 63                           My wish: Rebuilding Rwanda
# 64              My wish: Build the Encyclopedia of Life
# 65             My wish: Let my photographs bear witness
# 70                                 To invent is to give
# 71           The life code that will reshape the future
# 72                                  Happiness by design
# 74                      How architecture can connect us
# 78           Art with wire, sugar, chocolate and string
# 79       A philosophical quest for our biggest problems
# ...                                                 ...
# 2431                   How do you build a sacred space?
# 2432       How radio telescopes show us unseen galaxies
# 2434              A doctor's case for medical marijuana
# 2436                       How fake news does real harm
# 2442                Behind the lies of Holocaust denial
# 2444  There's no shame in taking care of your mental...
# 2449             How human noise affects ocean habitats
# 2456  Poverty isn't a lack of character; it's a lack...
# 2464  No one should die because they live too far fr...
# 2465                   Songs that bring history to life
# 2467  How to see past your own perspective and find ...
# 2470  What happens in your brain when you pay attent...
# 2487                 Why our screens make us less happy
# 2493  How cohousing can make us happier (and live lo...
# 2498  Meet Spot, the robot dog that can run, hop and...
# 2499                             Can art amend history?
# 2502  How computers learn to recognize objects insta...
# 2506  You owe it to yourself to experience a total s...
# 2470  https://www.ted.com/talks/mehdi_ordikhani_seye...   1781721
# 2487  https://www.ted.com/talks/adam_alter_why_our_s...   1858990
# 2493  https://www.ted.com/talks/grace_kim_how_cohous...   1363680
# 2498  https://www.ted.com/talks/marc_raibert_meet_sp...   1475823
# 2499  https://www.ted.com/talks/titus_kaphar_can_art...    890748
# 2502  https://www.ted.com/talks/joseph_redmon_how_a_...   1164777
# 2506  https://www.ted.com/talks/david_baron_you_owe_...   1319327
# 2523  https://www.ted.com/talks/niki_okuk_when_worke...    744793
# 2530  https://www.ted.com/talks/daan_roosegaarde_a_s...    591131
# 2533  https://www.ted.com/talks/tomas_saraceno_would...    248411
# 2534  https://www.ted.com/talks/benjamin_grant_what_...    646174
# 2535  https://www.ted.com/talks/olutimehin_adegbeye_...    707788
# 2537  https://www.ted.com/talks/emily_esfahani_smith...   1009069
# 2538  https://www.ted.com/talks/alexander_wagner_wha...    621431
# 2539  https://www.ted.com/talks/pierre_thiam_a_forgo...    527314
# 2541  https://www.ted.com/talks/helen_czerski_fun_ho...    656791
# 2542  https://www.ted.com/talks/sethembile_msezane_l...    542088
# 2545  https://www.ted.com/talks/duarte_geraldino_wha...    450430
# 2549  https://www.ted.com/talks/karoliina_korppoo_ho...    391721
#
#      film_datetime
# 1       2006-02-25
# 4       2006-02-22
# 7       2006-02-23
# 11      2006-02-26
# 14      2006-02-23
# 15      2006-02-23
# 26      2005-07-07
# 27      2004-02-27
# 28      2004-02-26
# 30      2005-07-15
# 34      2005-07-01
# 39      2005-02-24
# 40      2005-02-17
# 46      2006-02-23
# 48      2006-11-30
# 50      2005-07-14
# 53      2006-02-23
# 54      2005-07-14
# 56      2006-11-30
# 60      2006-02-23
# 62      2005-07-07
# 63      2007-03-08
# 64      2007-03-08
# 65      2007-03-08
# 70      2002-02-02
# 71      2003-02-02
# 72      2004-02-02
# 74      2005-02-25
# 78      2003-02-27
# 79      2005-07-14
# ...            ...
# 2431    2017-03-08
# 2432    2016-10-14
# 2434    2016-11-30
# 2436    2017-02-11
# 2442    2017-04-07
# 2444    2017-02-11
# 2449    2016-11-05
# 2456    2017-04-24
# 2464    2017-04-24
# 2465    2016-02-15
# 2467    2017-04-24
# 2470    2017-04-24
# 2487    2017-04-24
# 2493    2017-04-24
# 2498    2017-04-24
# 2499    2017-04-24
# 2502    2017-04-24
# 2506    2017-07-08
# 2523    2016-10-08
# 2530    2017-04-24
# 2533    2017-04-24
# 2534    2017-04-07
# 2535    2017-08-27
# 2537    2017-04-24
# 2538    2016-11-11
# 2539    2017-08-27
# 2541    2017-02-19
# 2542    2017-08-27
# 2545    2017-06-06
# 2549    2017-04-24
#
# [786 rows x 18 columns]

# %%
ted_top_occupations = ted[ted.speaker_occupation.isin(top_occupations)]

# %%
ted_top_occupations.groupby('speaker_occupation').film_datetime.sortby()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-643c4bbd3971> in <module>
# ----> 1 ted_top_occupations.groupby('speaker_occupation').film_datetime.sortby()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     534
#     535         raise AttributeError("%r object has no attribute %r" %
# --> 536                              (type(self).__name__, attr))
#     537
#     538     @Substitution(klass='GroupBy',
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'sortby'

# %%
ted.dtypes
#number things would probably be easiest to create from
#comments, duration, film_date, languages*, num_speaker, published_date, views
#maybe comments and number of languages**
#views vs published date?
# Out:
# comments                       int64
# description                   object
# duration                       int64
# event                         object
# film_date                      int64
# languages                      int64
# main_speaker                  object
# name                          object
# num_speaker                    int64
# published_date                 int64
# ratings                       object
# related_talks                 object
# speaker_occupation            object
# tags                          object
# title                         object
# url                           object
# views                          int64
# film_datetime         datetime64[ns]
# dtype: object

# %%
ted[['comments', 'languages']].sort_values('comments')
# Out:
#       comments  languages
# 2534         2          1
# 2542         3          1
# 2528         3          5
# 2501         3         12
# 2407         5          0
# 2546         6          3
# 2507         6         12
# 2392         6         19
# 2313         6         25
# 2494         7         10
# 2543         7          1
# 2538         7          1
# 2549         8          1
# 2535         8          4
# 2511         8          8
# 2476         8         24
# 2319         8         28
# 2533         9          2
# 2524         9         12
# 202          9         19
# 2539        10          2
# 2286        10         22
# 2544        10          1
# 2465        10          8
# 2547        10          1
# 2317        11         21
# 2418        11          0
# 2428        11         20
# 2263        11         18
# 2491        11          4
# ...        ...        ...
# 500       1094         44
# 614       1137         49
# 1163      1155         44
# 530       1155         46
# 730       1217         33
# 1779      1234         32
# 692       1234         57
# 641       1309         34
# 1114      1328         42
# 553       1329         42
# 1940      1355         41
# 1450      1413         34
# 1453      1451         27
# 694       1502         32
# 667       1545         36
# 1448      1586         33
# 381       1604         49
# 1030      1627          0
# 1537      1640         30
# 837       1927         52
# 677       1930         45
# 661       2272         31
# 1346      2290         51
# 840       2374         35
# 954       2492         35
# 1787      2673         33
# 201       2877         49
# 644       3356         39
# 0         4553         60
# 96        6404         42
#
# [2550 rows x 2 columns]

# %%
plt.subplot(1,2,1)
ted.comments.plot(kind='line')
plt.ylabel('Comments')

plt.subplot(1,2,2)
ted.languages.plot(kind='line')
plt.ylabel('languages')

plt.subplots_adjust(bottom=0.1, right=2, top=0.9)

# %%
ted.languages.mean()
# Out:
# 27.326274509803923

# %%
ted.languages.median()
# Out:
# 28.0

# %%
ted.languages.mode()
# Out:
# 0    26
# dtype: int64

# %%
x = ted.languages
y = ted.comments

# %%
plt.figure(figsize = (12,8))
mpl.rcParams['font.size'] = 12
plt.scatter(x,y, s=2, color='black')

plt.xlabel('Languages', fontsize=16)
plt.ylabel('Comments', fontsize=16)
plt.title('Does the number of languages affect the number of comments?', fontsize=16);

# %%
ted.languages.describe()
# Out:
# count    2550.000000
# mean       27.326275
# std         9.563452
# min         0.000000
# 25%        23.000000
# 50%        28.000000
# 75%        33.000000
# max        72.000000
# Name: languages, dtype: float64

# %%
ted.languages.plot(kind='box')

# %%
ted.comments.describe()
# Out:
# count    2550.000000
# mean      191.562353
# std       282.315223
# min         2.000000
# 25%        63.000000
# 50%       118.000000
# 75%       221.750000
# max      6404.000000
# Name: comments, dtype: float64

# %%
ted.comments.plot(kind='box')

# %% [markdown]
# ## 3. More PANDAS (if time)
#
# Review the following PANDAS for ecology tutorial and pick a few topics to work on:
#
# https://datacarpentry.org/python-ecology-lesson/
#
# Explain your methods in words and comment your code.
#
# #### Note the above is a good reference for basic pandas operations.
