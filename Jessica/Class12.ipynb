# %%
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
# %matplotlib inline
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
from mpl_toolkits.basemap import Basemap

# %%
import matplotlib as mpl

### I don't like the way the figures were saving.
# mpl.rcParams['figure.figsize'] = [12,8]
# mpl.rcParams['figure.dpi'] = 150
# mpl.rcParams['savefig.dpi'] = 200

mpl.rcParams['font.size'] = 16
mpl.rcParams['legend.fontsize'] = 'medium'
mpl.rcParams['figure.titlesize'] = 'medium'
mpl.rcParams['lines.linewidth'] = 2.0

# %% [markdown]
# # HYCOM

# %%
path = '/Users/xfm684/Documents/Research/HYCOM/hycom_gomu_501_'
tail = '00_t000.nc'

# %%
name = '20020101'
test = xr.open_dataset(path+name+tail, decode_times=False)

########## P L O T ##############

limN, limS, limE, limW = 32, 18, -78, -100

fig = plt.figure(figsize=(16,12), facecolor = 'w')
## m is map projection
m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')
# resolution options: crude, low, intermediate, high, full

m.drawcoastlines()
m.fillcontinents(color='lightgrey')

# now add in some data:
var = test.surf_el[0,:,:]
var_name = "Surface Elevation"
punits = "meters"
## projection must be applied (m) 
x, y = m(test.lon,test.lat)
im1 = m.pcolormesh(x,y,var,zorder = 0, cmap = 'jet', vmin=-.2, vmax=.8) ##this is where you add the color is basemap
cbar = m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(var_name + ' ('+ punits + ')')

U = test.water_u[0,0,:,:]
V = test.water_v[0,0,:,:]
Q = plt.quiver(x[::11], y[::11], U[::11, ::11], V[::11, ::11])#,headlength=1, headaxislength=1)#, linewidth=0.5)
qk = plt.quiverkey(Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')

dlat = 2
dlon = 4
m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])

plt.title('HYCOM ' + name, y=1.08)
# fig.savefig('HYCOM_' + name)
# Out:
# Text(0.5, 1.08, 'HYCOM 20020101')

# %%
name = '20020201'
test = xr.open_dataset(path+name+tail, decode_times=False)

########## P L O T ##############

limN, limS, limE, limW = 32, 18, -78, -100

fig = plt.figure(figsize=(8,8), facecolor = 'w')
## m is map projection
m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')
# resolution options: crude, low, intermediate, high, full

m.drawcoastlines()
m.fillcontinents(color='lightgrey')

# now add in some data:
var = test.surf_el[0,:,:]
var_name = "Surface Elevation"
punits = "meters"
## projection must be applied (m) 
x, y = m(test.lon,test.lat)
im1 = m.pcolormesh(x,y,var,zorder = 0, cmap = 'jet', vmin=-0.5, vmax=0.5) ##this is where you add the color is basemap
cbar = m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(var_name + ' ('+ punits + ')')

U = test.water_u[0,0,:,:]
V = test.water_v[0,0,:,:]
Q = plt.quiver(x[::10], y[::10], U[::10, ::10], V[::10, ::10], scale=50)#,headlength=1, headaxislength=1)#, linewidth=0.5)
qk = plt.quiverkey(Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')

dlat = 2
dlon = 4
m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])

plt.title('HYCOM ' + name, y=1.08)
fig.savefig('HYCOM_' + name)

# %%
name = '20020301'
test = xr.open_dataset(path+name+tail, decode_times=False)

########## P L O T ##############

limN, limS, limE, limW = 32, 18, -78, -100

fig = plt.figure(figsize=(8,8), facecolor = 'w')
## m is map projection
m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')
# resolution options: crude, low, intermediate, high, full

m.drawcoastlines()
m.fillcontinents(color='lightgrey')

# now add in some data:
var = test.surf_el[0,:,:]
var_name = "Surface Elevation"
punits = "meters"
## projection must be applied (m) 
x, y = m(test.lon,test.lat)
im1 = m.pcolormesh(x,y,var,zorder = 0, cmap = 'jet', vmin=-0.5, vmax=0.5) ##this is where you add the color is basemap
cbar = m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(var_name + ' ('+ punits + ')')

U = test.water_u[0,0,:,:]
V = test.water_v[0,0,:,:]
Q = plt.quiver(x[::10], y[::10], U[::10, ::10], V[::10, ::10], scale=50)#,headlength=1, headaxislength=1)#, linewidth=0.5)
qk = plt.quiverkey(Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')

dlat = 2
dlon = 4
m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])

plt.title('HYCOM ' + name, y=1.08)
fig.savefig('HYCOM_' + name)

# %%
name = '20020401'
test = xr.open_dataset(path+name+tail, decode_times=False)

########## P L O T ##############

limN, limS, limE, limW = 32, 18, -78, -100

fig = plt.figure(figsize=(8,8), facecolor = 'w')
## m is map projection
m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')
# resolution options: crude, low, intermediate, high, full

m.drawcoastlines()
m.fillcontinents(color='lightgrey')

# now add in some data:
var = test.surf_el[0,:,:]
var_name = "Surface Elevation"
punits = "meters"
## projection must be applied (m) 
x, y = m(test.lon,test.lat)
im1 = m.pcolormesh(x,y,var,zorder = 0, cmap = 'jet', vmin=-0.6, vmax=0.5) ##this is where you add the color is basemap
cbar = m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(var_name + ' ('+ punits + ')')

U = test.water_u[0,0,:,:]
V = test.water_v[0,0,:,:]
Q = plt.quiver(x[::10], y[::10], U[::10, ::10], V[::10, ::10], scale=50)#,headlength=1, headaxislength=1)#, linewidth=0.5)
qk = plt.quiverkey(Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')

dlat = 2
dlon = 4
m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])

plt.title('HYCOM ' + name, y=1.08)
fig.savefig('HYCOM_' + name)

# %%
name = '20020501'
test = xr.open_dataset(path+name+tail, decode_times=False)

########## P L O T ##############

limN, limS, limE, limW = 32, 18, -78, -100

fig = plt.figure(figsize=(8,8), facecolor = 'w')
## m is map projection
m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')
# resolution options: crude, low, intermediate, high, full

m.drawcoastlines()
m.fillcontinents(color='lightgrey')

# now add in some data:
var = test.surf_el[0,:,:]
var_name = "Surface Elevation"
punits = "meters"
## projection must be applied (m) 
x, y = m(test.lon,test.lat)
im1 = m.pcolormesh(x,y,var,zorder = 0, cmap = 'jet', vmin=-0.6, vmax=0.5) ##this is where you add the color is basemap
cbar = m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(var_name + ' ('+ punits + ')')

U = test.water_u[0,0,:,:]
V = test.water_v[0,0,:,:]
Q = plt.quiver(x[::10], y[::10], U[::10, ::10], V[::10, ::10], scale=50)#,headlength=1, headaxislength=1)#, linewidth=0.5)
qk = plt.quiverkey(Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')

dlat = 2
dlon = 4
m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])

plt.title('HYCOM ' + name, y=1.08)
fig.savefig('HYCOM_' + name)

# %%
name = '20020601'
test = xr.open_dataset(path+name+tail, decode_times=False)

########## P L O T ##############

limN, limS, limE, limW = 32, 18, -78, -100

fig = plt.figure(figsize=(8,8), facecolor = 'w')
## m is map projection
m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')
# resolution options: crude, low, intermediate, high, full

m.drawcoastlines()
m.fillcontinents(color='lightgrey')

# now add in some data:
var = test.surf_el[0,:,:]
var_name = "Surface Elevation"
punits = "meters"
## projection must be applied (m) 
x, y = m(test.lon,test.lat)
im1 = m.pcolormesh(x,y,var,zorder = 0, cmap = 'jet', vmin=-0.5, vmax=0.5) ##this is where you add the color is basemap
cbar = m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(var_name + ' ('+ punits + ')')

U = test.water_u[0,0,:,:]
V = test.water_v[0,0,:,:]
Q = plt.quiver(x[::10], y[::10], U[::10, ::10], V[::10, ::10], scale=50)#,headlength=1, headaxislength=1)#, linewidth=0.5)
qk = plt.quiverkey(Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')

dlat = 2
dlon = 4
m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])

plt.title('HYCOM ' + name, y=1.08)
fig.savefig('HYCOM_' + name)

# %%
name = '20020701'
test = xr.open_dataset(path+name+tail, decode_times=False)

########## P L O T ##############

limN, limS, limE, limW = 32, 18, -78, -100

fig = plt.figure(figsize=(8,8), facecolor = 'w')
## m is map projection
m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')
# resolution options: crude, low, intermediate, high, full

m.drawcoastlines()
m.fillcontinents(color='lightgrey')

# now add in some data:
var = test.surf_el[0,:,:]
var_name = "Surface Elevation"
punits = "meters"
## projection must be applied (m) 
x, y = m(test.lon,test.lat)
im1 = m.pcolormesh(x,y,var,zorder = 0, cmap = 'jet', vmin=-0.5, vmax=0.5) ##this is where you add the color is basemap
cbar = m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(var_name + ' ('+ punits + ')')

U = test.water_u[0,0,:,:]
V = test.water_v[0,0,:,:]
Q = plt.quiver(x[::10], y[::10], U[::10, ::10], V[::10, ::10], scale=50)#,headlength=1, headaxislength=1)#, linewidth=0.5)
qk = plt.quiverkey(Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')

dlat = 2
dlon = 4
m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])

plt.title('HYCOM ' + name, y=1.08)
fig.savefig('HYCOM_' + name)

# %%
name = '20020801'
test = xr.open_dataset(path+name+tail, decode_times=False)

########## P L O T ##############

limN, limS, limE, limW = 32, 18, -78, -100

fig = plt.figure(figsize=(8,8), facecolor = 'w')
## m is map projection
m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')
# resolution options: crude, low, intermediate, high, full

m.drawcoastlines()
m.fillcontinents(color='lightgrey')

# now add in some data:
var = test.surf_el[0,:,:]
var_name = "Surface Elevation"
punits = "meters"
## projection must be applied (m) 
x, y = m(test.lon,test.lat)
im1 = m.pcolormesh(x,y,var,zorder = 0, cmap = 'jet', vmin=-0.6, vmax=0.6) ##this is where you add the color is basemap
cbar = m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(var_name + ' ('+ punits + ')')

U = test.water_u[0,0,:,:]
V = test.water_v[0,0,:,:]
Q = plt.quiver(x[::10], y[::10], U[::10, ::10], V[::10, ::10], scale=50)#,headlength=1, headaxislength=1)#, linewidth=0.5)
qk = plt.quiverkey(Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')

dlat = 2
dlon = 4
m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])

plt.title('HYCOM ' + name, y=1.08)
fig.savefig('HYCOM_' + name)

# %%
name = '20020901'
test = xr.open_dataset(path+name+tail, decode_times=False)

########## P L O T ##############

limN, limS, limE, limW = 32, 18, -78, -100

fig = plt.figure(figsize=(8,8), facecolor = 'w')
## m is map projection
m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')
# resolution options: crude, low, intermediate, high, full

m.drawcoastlines()
m.fillcontinents(color='lightgrey')

# now add in some data:
var = test.surf_el[0,:,:]
var_name = "Surface Elevation"
punits = "meters"
## projection must be applied (m) 
x, y = m(test.lon,test.lat)
im1 = m.pcolormesh(x,y,var,zorder = 0, cmap = 'jet', vmin=-0.6, vmax=0.7) ##this is where you add the color is basemap
cbar = m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(var_name + ' ('+ punits + ')')

U = test.water_u[0,0,:,:]
V = test.water_v[0,0,:,:]
Q = plt.quiver(x[::10], y[::10], U[::10, ::10], V[::10, ::10], scale=50)#,headlength=1, headaxislength=1)#, linewidth=0.5)
qk = plt.quiverkey(Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')

dlat = 2
dlon = 4
m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])

plt.title('HYCOM ' + name, y=1.08)
fig.savefig('HYCOM_' + name)

# %%
name = '20021001'
test = xr.open_dataset(path+name+tail, decode_times=False)

########## P L O T ##############

limN, limS, limE, limW = 32, 18, -78, -100

fig = plt.figure(figsize=(8,8), facecolor = 'w')
## m is map projection
m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')
# resolution options: crude, low, intermediate, high, full

m.drawcoastlines()
m.fillcontinents(color='lightgrey')

# now add in some data:
var = test.surf_el[0,:,:]
var_name = "Surface Elevation"
punits = "meters"
## projection must be applied (m) 
x, y = m(test.lon,test.lat)
im1 = m.pcolormesh(x,y,var,zorder = 0, cmap = 'jet', vmin=-0.6, vmax=0.7) ##this is where you add the color is basemap
cbar = m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(var_name + ' ('+ punits + ')')

U = test.water_u[0,0,:,:]
V = test.water_v[0,0,:,:]
Q = plt.quiver(x[::10], y[::10], U[::10, ::10], V[::10, ::10], scale=50)#,headlength=1, headaxislength=1)#, linewidth=0.5)
qk = plt.quiverkey(Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')

dlat = 2
dlon = 4
m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])

plt.title('HYCOM ' + name, y=1.08)
fig.savefig('HYCOM_' + name)

# %%
name = '20021101'
test = xr.open_dataset(path+name+tail, decode_times=False)

########## P L O T ##############

limN, limS, limE, limW = 32, 18, -78, -100

fig = plt.figure(figsize=(8,8), facecolor = 'w')
## m is map projection
m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')
# resolution options: crude, low, intermediate, high, full

m.drawcoastlines()
m.fillcontinents(color='lightgrey')

# now add in some data:
var = test.surf_el[0,:,:]
var_name = "Surface Elevation"
punits = "meters"
## projection must be applied (m) 
x, y = m(test.lon,test.lat)
im1 = m.pcolormesh(x,y,var,zorder = 0, cmap = 'jet', vmin=-0.6, vmax=0.7) ##this is where you add the color is basemap
cbar = m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(var_name + ' ('+ punits + ')')

U = test.water_u[0,0,:,:]
V = test.water_v[0,0,:,:]
Q = plt.quiver(x[::10], y[::10], U[::10, ::10], V[::10, ::10], scale=50)#,headlength=1, headaxislength=1)#, linewidth=0.5)
qk = plt.quiverkey(Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')

dlat = 2
dlon = 4
m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])

plt.title('HYCOM ' + name, y=1.08)
fig.savefig('HYCOM_' + name)

# %%
name = '20021201'
test = xr.open_dataset(path+name+tail, decode_times=False)

########## P L O T ##############

limN, limS, limE, limW = 32, 18, -78, -100

fig = plt.figure(figsize=(8,8), facecolor = 'w')
## m is map projection
m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')
# resolution options: crude, low, intermediate, high, full

m.drawcoastlines()
m.fillcontinents(color='lightgrey')

# now add in some data:
var = test.surf_el[0,:,:]
var_name = "Surface Elevation"
punits = "meters"
## projection must be applied (m) 
x, y = m(test.lon,test.lat)
im1 = m.pcolormesh(x,y,var,zorder = 0, cmap = 'jet', vmin=-0.6, vmax=0.7) ##this is where you add the color is basemap
cbar = m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(var_name + ' ('+ punits + ')')

U = test.water_u[0,0,:,:]
V = test.water_v[0,0,:,:]
Q = plt.quiver(x[::10], y[::10], U[::10, ::10], V[::10, ::10], scale=50)#,headlength=1, headaxislength=1)#, linewidth=0.5)
qk = plt.quiverkey(Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')

dlat = 2
dlon = 4
m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])

plt.title('HYCOM ' + name, y=1.08)
fig.savefig('HYCOM_' + name)

# %% [markdown]
# # GECKO

# %%
path = '/Users/xfm684/Documents/Research/GECKO/v_gekco2_'
tail = '.nc'

# %%
test.u
# Out:
# <xarray.DataArray 'u' (time: 1, lat: 114, lon: 181)>
# array([[[-1.611691,  6.129444, ...,       nan,       nan],
#         [23.029583, 28.834724, ...,       nan,       nan],
#         ...,
#         [      nan,       nan, ..., -2.29872 ,  4.245584],
#         [      nan,       nan, ...,  4.645259, 10.774105]]], dtype=float32)
# Coordinates:
#   * time     (time) int32 20020101
#   * lon      (lon) float32 260.0 260.25 260.5 260.75 ... 304.5 304.75 305.0
#   * lat      (lat) float32 4.875 5.125 5.375 5.625 ... 32.625 32.875 33.125
# Attributes:
#     long_name:      u
#     units:          cm/s
#     FillValue:      0.0
#     valid_min:      -99.03519
#     valid_max:      101.22935
#     standard_name:  u

# %%
name = '20020101'
test = xr.open_dataset(path+name+tail, decode_times=False)

########## P L O T ##############

limN, limS, limE, limW = 32, 18, 282, 260

fig = plt.figure(figsize=(16,12), facecolor = 'w')
## m is map projection
m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')
# resolution options: crude, low, intermediate, high, full

m.drawcoastlines()
m.fillcontinents(color='lightgrey')

# now add in some data:
var = test.h[0,:,:]/100
var_name = "Surface Elevation"
punits = "meters"
## projection must be applied (m) 
x, y = m(test.lon,test.lat)
im1 = m.pcolormesh(x,y,var,zorder = 0, cmap = 'jet') ##this is where you add the color is basemap
cbar = m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(var_name + ' ('+ punits + ')')

U = test.u[0,:,:]/100
V = test.v[0,:,:]/100
Q = plt.quiver(x[::2], y[::2], U[::2, ::2], V[::2, ::2])#, scale=.01)#,headlength=1, headaxislength=1)#, linewidth=0.5)
qk = plt.quiverkey(Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')

dlat = 2
dlon = 4
m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])

plt.title('GECKO ' + name, y=1.08)
fig.savefig('GECKO_'+ name)

# %%
name = '20020201'
test = xr.open_dataset(path+name+tail, decode_times=False)

########## P L O T ##############

limN, limS, limE, limW = 32, 18, 282, 260

fig = plt.figure(figsize=(8,8), facecolor = 'w')
## m is map projection
m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')
# resolution options: crude, low, intermediate, high, full

m.drawcoastlines()
m.fillcontinents(color='lightgrey')

# now add in some data:
var = test.h[0,:,:]/100
var_name = "Surface Elevation"
punits = "meters"
## projection must be applied (m) 
x, y = m(test.lon,test.lat)
im1 = m.pcolormesh(x,y,var,zorder = 0, cmap = 'jet') ##this is where you add the color is basemap
cbar = m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(var_name + ' ('+ punits + ')')

U = test.u[0,:,:]/100
V = test.v[0,:,:]/100
Q = plt.quiver(x[::2], y[::2], U[::2, ::2], V[::2, ::2])#, scale=.01)#,headlength=1, headaxislength=1)#, linewidth=0.5)
qk = plt.quiverkey(Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')

dlat = 2
dlon = 4
m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])

plt.title('GECKO ' + name, y=1.08)
fig.savefig('GECKO_'+ name)

# %%
name = '20020301'
test = xr.open_dataset(path+name+tail, decode_times=False)

########## P L O T ##############

limN, limS, limE, limW = 32, 18, 282, 260

fig = plt.figure(figsize=(8,8), facecolor = 'w')
## m is map projection
m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')
# resolution options: crude, low, intermediate, high, full

m.drawcoastlines()
m.fillcontinents(color='lightgrey')

# now add in some data:
var = test.h[0,:,:]/100
var_name = "Surface Elevation"
punits = "meters"
## projection must be applied (m) 
x, y = m(test.lon,test.lat)
im1 = m.pcolormesh(x,y,var,zorder = 0, cmap = 'jet') ##this is where you add the color is basemap
cbar = m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(var_name + ' ('+ punits + ')')

U = test.u[0,:,:]/100
V = test.v[0,:,:]/100
Q = plt.quiver(x[::2], y[::2], U[::2, ::2], V[::2, ::2])#, scale=.01)#,headlength=1, headaxislength=1)#, linewidth=0.5)
qk = plt.quiverkey(Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')

dlat = 2
dlon = 4
m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])

plt.title('GECKO ' + name, y=1.08)
fig.savefig('GECKO_'+ name)

# %%
name = '20020401'
test = xr.open_dataset(path+name+tail, decode_times=False)

########## P L O T ##############

limN, limS, limE, limW = 32, 18, 282, 260

fig = plt.figure(figsize=(8,8), facecolor = 'w')
## m is map projection
m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')
# resolution options: crude, low, intermediate, high, full

m.drawcoastlines()
m.fillcontinents(color='lightgrey')

# now add in some data:
var = test.h[0,:,:]/100
var_name = "Surface Elevation"
punits = "meters"
## projection must be applied (m) 
x, y = m(test.lon,test.lat)
im1 = m.pcolormesh(x,y,var,zorder = 0, cmap = 'jet') ##this is where you add the color is basemap
cbar = m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(var_name + ' ('+ punits + ')')

U = test.u[0,:,:]/100
V = test.v[0,:,:]/100
Q = plt.quiver(x[::2], y[::2], U[::2, ::2], V[::2, ::2])#, scale=.01)#,headlength=1, headaxislength=1)#, linewidth=0.5)
qk = plt.quiverkey(Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')

dlat = 2
dlon = 4
m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])

plt.title('GECKO ' + name, y=1.08)
fig.savefig('GECKO_'+ name)

# %%
name = '20020501'
test = xr.open_dataset(path+name+tail, decode_times=False)

########## P L O T ##############

limN, limS, limE, limW = 32, 18, 282, 260

fig = plt.figure(figsize=(8,8), facecolor = 'w')
## m is map projection
m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')
# resolution options: crude, low, intermediate, high, full

m.drawcoastlines()
m.fillcontinents(color='lightgrey')

# now add in some data:
var = test.h[0,:,:]/100
var_name = "Surface Elevation"
punits = "meters"
## projection must be applied (m) 
x, y = m(test.lon,test.lat)
im1 = m.pcolormesh(x,y,var,zorder = 0, cmap = 'jet') ##this is where you add the color is basemap
cbar = m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(var_name + ' ('+ punits + ')')

U = test.u[0,:,:]/100
V = test.v[0,:,:]/100
Q = plt.quiver(x[::2], y[::2], U[::2, ::2], V[::2, ::2])#, scale=.01)#,headlength=1, headaxislength=1)#, linewidth=0.5)
qk = plt.quiverkey(Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')

dlat = 2
dlon = 4
m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])

plt.title('GECKO ' + name, y=1.08)
fig.savefig('GECKO_'+ name)

# %%
name = '20020601'
test = xr.open_dataset(path+name+tail, decode_times=False)

########## P L O T ##############

limN, limS, limE, limW = 32, 18, 282, 260

fig = plt.figure(figsize=(8,8), facecolor = 'w')
## m is map projection
m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')
# resolution options: crude, low, intermediate, high, full

m.drawcoastlines()
m.fillcontinents(color='lightgrey')

# now add in some data:
var = test.h[0,:,:]/100
var_name = "Surface Elevation"
punits = "meters"
## projection must be applied (m) 
x, y = m(test.lon,test.lat)
im1 = m.pcolormesh(x,y,var,zorder = 0, cmap = 'jet') ##this is where you add the color is basemap
cbar = m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(var_name + ' ('+ punits + ')')

U = test.u[0,:,:]/100
V = test.v[0,:,:]/100
Q = plt.quiver(x[::2], y[::2], U[::2, ::2], V[::2, ::2])#, scale=.01)#,headlength=1, headaxislength=1)#, linewidth=0.5)
qk = plt.quiverkey(Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')

dlat = 2
dlon = 4
m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])

plt.title('GECKO ' + name, y=1.08)
fig.savefig('GECKO_'+ name)

# %%
name = '20020701'
test = xr.open_dataset(path+name+tail, decode_times=False)

########## P L O T ##############

limN, limS, limE, limW = 32, 18, 282, 260

fig = plt.figure(figsize=(8,8), facecolor = 'w')
## m is map projection
m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')
# resolution options: crude, low, intermediate, high, full

m.drawcoastlines()
m.fillcontinents(color='lightgrey')

# now add in some data:
var = test.h[0,:,:]/100
var_name = "Surface Elevation"
punits = "meters"
## projection must be applied (m) 
x, y = m(test.lon,test.lat)
im1 = m.pcolormesh(x,y,var,zorder = 0, cmap = 'jet') ##this is where you add the color is basemap
cbar = m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(var_name + ' ('+ punits + ')')

U = test.u[0,:,:]/100
V = test.v[0,:,:]/100
Q = plt.quiver(x[::2], y[::2], U[::2, ::2], V[::2, ::2])#, scale=.01)#,headlength=1, headaxislength=1)#, linewidth=0.5)
qk = plt.quiverkey(Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')

dlat = 2
dlon = 4
m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])

plt.title('GECKO ' + name, y=1.08)
fig.savefig('GECKO_'+ name)

# %%
name = '20020801'
test = xr.open_dataset(path+name+tail, decode_times=False)

########## P L O T ##############

limN, limS, limE, limW = 32, 18, 282, 260

fig = plt.figure(figsize=(8,8), facecolor = 'w')
## m is map projection
m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')
# resolution options: crude, low, intermediate, high, full

m.drawcoastlines()
m.fillcontinents(color='lightgrey')

# now add in some data:
var = test.h[0,:,:]/100
var_name = "Surface Elevation"
punits = "meters"
## projection must be applied (m) 
x, y = m(test.lon,test.lat)
im1 = m.pcolormesh(x,y,var,zorder = 0, cmap = 'jet') ##this is where you add the color is basemap
cbar = m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(var_name + ' ('+ punits + ')')

U = test.u[0,:,:]/100
V = test.v[0,:,:]/100
Q = plt.quiver(x[::2], y[::2], U[::2, ::2], V[::2, ::2])#, scale=.01)#,headlength=1, headaxislength=1)#, linewidth=0.5)
qk = plt.quiverkey(Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')

dlat = 2
dlon = 4
m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])

plt.title('GECKO ' + name, y=1.08)
fig.savefig('GECKO_'+ name)

# %%
name = '20020901'
test = xr.open_dataset(path+name+tail, decode_times=False)

########## P L O T ##############

limN, limS, limE, limW = 32, 18, 282, 260

fig = plt.figure(figsize=(8,8), facecolor = 'w')
## m is map projection
m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')
# resolution options: crude, low, intermediate, high, full

m.drawcoastlines()
m.fillcontinents(color='lightgrey')

# now add in some data:
var = test.h[0,:,:]/100
var_name = "Surface Elevation"
punits = "meters"
## projection must be applied (m) 
x, y = m(test.lon,test.lat)
im1 = m.pcolormesh(x,y,var,zorder = 0, cmap = 'jet') ##this is where you add the color is basemap
cbar = m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(var_name + ' ('+ punits + ')')

U = test.u[0,:,:]/100
V = test.v[0,:,:]/100
Q = plt.quiver(x[::2], y[::2], U[::2, ::2], V[::2, ::2])#, scale=.01)#,headlength=1, headaxislength=1)#, linewidth=0.5)
qk = plt.quiverkey(Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')

dlat = 2
dlon = 4
m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])

plt.title('GECKO ' + name, y=1.08)
fig.savefig('GECKO_'+ name)

# %%
name = '20021001'
test = xr.open_dataset(path+name+tail, decode_times=False)

########## P L O T ##############

limN, limS, limE, limW = 32, 18, 282, 260

fig = plt.figure(figsize=(8,8), facecolor = 'w')
## m is map projection
m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')
# resolution options: crude, low, intermediate, high, full

m.drawcoastlines()
m.fillcontinents(color='lightgrey')

# now add in some data:
var = test.h[0,:,:]/100
var_name = "Surface Elevation"
punits = "meters"
## projection must be applied (m) 
x, y = m(test.lon,test.lat)
im1 = m.pcolormesh(x,y,var,zorder = 0, cmap = 'jet') ##this is where you add the color is basemap
cbar = m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(var_name + ' ('+ punits + ')')

U = test.u[0,:,:]/100
V = test.v[0,:,:]/100
Q = plt.quiver(x[::2], y[::2], U[::2, ::2], V[::2, ::2])#, scale=.01)#,headlength=1, headaxislength=1)#, linewidth=0.5)
qk = plt.quiverkey(Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')

dlat = 2
dlon = 4
m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])

plt.title('GECKO ' + name, y=1.08)
fig.savefig('GECKO_'+ name)

# %%
name = '20021101'
test = xr.open_dataset(path+name+tail, decode_times=False)

########## P L O T ##############

limN, limS, limE, limW = 32, 18, 282, 260

fig = plt.figure(figsize=(8,8), facecolor = 'w')
## m is map projection
m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')
# resolution options: crude, low, intermediate, high, full

m.drawcoastlines()
m.fillcontinents(color='lightgrey')

# now add in some data:
var = test.h[0,:,:]/100
var_name = "Surface Elevation"
punits = "meters"
## projection must be applied (m) 
x, y = m(test.lon,test.lat)
im1 = m.pcolormesh(x,y,var,zorder = 0, cmap = 'jet') ##this is where you add the color is basemap
cbar = m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(var_name + ' ('+ punits + ')')

U = test.u[0,:,:]/100
V = test.v[0,:,:]/100
Q = plt.quiver(x[::2], y[::2], U[::2, ::2], V[::2, ::2])#, scale=.01)#,headlength=1, headaxislength=1)#, linewidth=0.5)
qk = plt.quiverkey(Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')

dlat = 2
dlon = 4
m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])

plt.title('GECKO ' + name, y=1.08)
fig.savefig('GECKO_'+ name)

# %%
name = '20021201'
test = xr.open_dataset(path+name+tail, decode_times=False)

########## P L O T ##############

limN, limS, limE, limW = 32, 18, 282, 260

fig = plt.figure(figsize=(8,8), facecolor = 'w')
## m is map projection
m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')
# resolution options: crude, low, intermediate, high, full

m.drawcoastlines()
m.fillcontinents(color='lightgrey')

# now add in some data:
var = test.h[0,:,:]/100
var_name = "Surface Elevation"
punits = "meters"
## projection must be applied (m) 
x, y = m(test.lon,test.lat)
im1 = m.pcolormesh(x,y,var,zorder = 0, cmap = 'jet') ##this is where you add the color is basemap
cbar = m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(var_name + ' ('+ punits + ')')

U = test.u[0,:,:]/100
V = test.v[0,:,:]/100
Q = plt.quiver(x[::2], y[::2], U[::2, ::2], V[::2, ::2])#, scale=.01)#,headlength=1, headaxislength=1)#, linewidth=0.5)
qk = plt.quiverkey(Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')

dlat = 2
dlon = 4
m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])

plt.title('GECKO ' + name, y=1.08)
fig.savefig('GECKO_'+ name)

# %% [markdown]
# # Side by Side

# %%
#### H Y C O M ####
h_path = '/Users/xfm684/Documents/Research/HYCOM/hycom_gomu_501_'
h_tail = '00_t000.nc'
h_name = '20020101'
h_test = xr.open_dataset(h_path+h_name+h_tail, decode_times=False)

limN, limS, limE, limW = 32, 18, -78, -100
h_m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')

h_var = h_test.surf_el[0,:,:]
h_var_name = "Surface Elevation"
h_punits = "meters"
h_x, h_y = m(h_test.lon,h_test.lat)

h_U = h_test.water_u[0,0,:,:]
h_V = h_test.water_v[0,0,:,:]

# %%
#### G E C K O ####
g_path = '/Users/xfm684/Documents/Research/GECKO/v_gekco2_'
g_tail = '.nc'
g_name = '20020101'
g_test = xr.open_dataset(g_path+g_name+g_tail, decode_times=False)

limN, limS, limE, limW = 32, 18, 282, 260
g_m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')

g_var = g_test.h[0,:,:]/100
g_var_name = "Surface Elevation"
g_punits = "meters"

g_x, g_y = m(g_test.lon,g_test.lat)

g_U = g_test.u[0,:,:]/100 #because it's in centimeters and I want m/s
g_V = g_test.v[0,:,:]/100

# %%
mpl.rcParams['font.size'] = 9
fig, ax = plt.subplots(figsize=(20,16), facecolor = 'w', ncols = 2)


plt.subplot(2,2,1)
h_m.drawcoastlines()
h_m.fillcontinents(color='lightgrey')
im1 = h_m.pcolormesh(h_x,h_y,h_var,zorder = 0, cmap = 'jet', vmin=-.2, vmax=.8) ##this is where you add the color is basemap
cbar = h_m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(h_var_name + ' ('+ h_punits + ')')
h_Q = plt.quiver(h_x[::15], h_y[::15], h_U[::15, ::15], h_V[::15, ::15], scale=30)#,headlength=1, headaxislength=1)#, linewidth=0.5)
h_qk = plt.quiverkey(h_Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')
dlat = 2
dlon = 4
h_m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
h_m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])
plt.title('HYCOM ' + h_name, y=1.08)



plt.subplot(2,2,2)
g_m.drawcoastlines()
g_m.fillcontinents(color='lightgrey')
im1 = g_m.pcolormesh(g_x,g_y,g_var,zorder = 0, cmap = 'jet') ##this is where you add the color is basemap
cbar = g_m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(g_var_name + ' ('+ g_punits + ')')
Q = plt.quiver(g_x[::2], g_y[::2], g_U[::2, ::2], g_V[::2, ::2])#, scale=.01)#,headlength=1, headaxislength=1)#, linewidth=0.5)
qk = plt.quiverkey(Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')
dlat = 2
dlon = 4
g_m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
g_m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])
plt.title('GECKO ' + g_name, y=1.08)

fig.savefig('20020101')

# %%
#### H Y C O M ####
h_path = '/Users/xfm684/Documents/Research/HYCOM/hycom_gomu_501_'
h_tail = '00_t000.nc'
h_name = '20020201'
h_test = xr.open_dataset(h_path+h_name+h_tail, decode_times=False)

limN, limS, limE, limW = 32, 18, -78, -100
h_m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')

h_var = h_test.surf_el[0,:,:]
h_var_name = "Surface Elevation"
h_punits = "meters"
h_x, h_y = m(h_test.lon,h_test.lat)

h_U = h_test.water_u[0,0,:,:]
h_V = h_test.water_v[0,0,:,:]

# %%
#### G E C K O ####
g_path = '/Users/xfm684/Documents/Research/GECKO/v_gekco2_'
g_tail = '.nc'
g_name = '20020201'
g_test = xr.open_dataset(g_path+g_name+g_tail, decode_times=False)

limN, limS, limE, limW = 32, 18, 282, 260
g_m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')

g_var = g_test.h[0,:,:]/100
g_var_name = "Surface Elevation"
g_punits = "meters"

g_x, g_y = m(g_test.lon,g_test.lat)

g_U = g_test.u[0,:,:]/100 #because it's in centimeters and I want m/s
g_V = g_test.v[0,:,:]/100

# %%
mpl.rcParams['font.size'] = 9
fig, ax = plt.subplots(figsize=(12,8), facecolor = 'w', ncols = 2)


plt.subplot(2,2,1)
h_m.drawcoastlines()
h_m.fillcontinents(color='lightgrey')
im1 = h_m.pcolormesh(h_x,h_y,h_var,zorder = 0, cmap = 'jet', vmin=-0.5, vmax=0.5) ##this is where you add the color is basemap
cbar = h_m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(h_var_name + ' ('+ h_punits + ')')
h_Q = plt.quiver(h_x[::15], h_y[::15], h_U[::15, ::15], h_V[::15, ::15], scale=30)#,headlength=1, headaxislength=1)#, linewidth=0.5)
h_qk = plt.quiverkey(h_Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')
dlat = 2
dlon = 4
h_m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
h_m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])
plt.title('HYCOM ' + h_name, y=1.08)



plt.subplot(2,2,2)
g_m.drawcoastlines()
g_m.fillcontinents(color='lightgrey')
im1 = g_m.pcolormesh(g_x,g_y,g_var,zorder = 0, cmap = 'jet') ##this is where you add the color is basemap
cbar = g_m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(g_var_name + ' ('+ g_punits + ')')
Q = plt.quiver(g_x[::2], g_y[::2], g_U[::2, ::2], g_V[::2, ::2])#, scale=.01)#,headlength=1, headaxislength=1)#, linewidth=0.5)
qk = plt.quiverkey(Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')
dlat = 2
dlon = 4
g_m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
g_m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])
plt.title('GECKO ' + g_name, y=1.08)

fig.savefig(g_name)

# %%
#### H Y C O M ####
h_path = '/Users/xfm684/Documents/Research/HYCOM/hycom_gomu_501_'
h_tail = '00_t000.nc'
h_name = '20020301'
h_test = xr.open_dataset(h_path+h_name+h_tail, decode_times=False)

limN, limS, limE, limW = 32, 18, -78, -100
h_m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')

h_var = h_test.surf_el[0,:,:]
h_var_name = "Surface Elevation"
h_punits = "meters"
h_x, h_y = m(h_test.lon,h_test.lat)

h_U = h_test.water_u[0,0,:,:]
h_V = h_test.water_v[0,0,:,:]

# %%
#### G E C K O ####
g_path = '/Users/xfm684/Documents/Research/GECKO/v_gekco2_'
g_tail = '.nc'
g_name = '20020301'
g_test = xr.open_dataset(g_path+g_name+g_tail, decode_times=False)

limN, limS, limE, limW = 32, 18, 282, 260
g_m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')

g_var = g_test.h[0,:,:]/100
g_var_name = "Surface Elevation"
g_punits = "meters"

g_x, g_y = m(g_test.lon,g_test.lat)

g_U = g_test.u[0,:,:]/100 #because it's in centimeters and I want m/s
g_V = g_test.v[0,:,:]/100

# %%
mpl.rcParams['font.size'] = 9
fig, ax = plt.subplots(figsize=(12,8), facecolor = 'w', ncols = 2)


plt.subplot(2,2,1)
h_m.drawcoastlines()
h_m.fillcontinents(color='lightgrey')
im1 = h_m.pcolormesh(h_x,h_y,h_var,zorder = 0, cmap = 'jet', vmin=-0.6, vmax=0.6) ##this is where you add the color is basemap
cbar = h_m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(h_var_name + ' ('+ h_punits + ')')
h_Q = plt.quiver(h_x[::15], h_y[::15], h_U[::15, ::15], h_V[::15, ::15], scale=30)#,headlength=1, headaxislength=1)#, linewidth=0.5)
h_qk = plt.quiverkey(h_Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')
dlat = 2
dlon = 4
h_m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
h_m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])
plt.title('HYCOM ' + h_name, y=1.08)



plt.subplot(2,2,2)
g_m.drawcoastlines()
g_m.fillcontinents(color='lightgrey')
im1 = g_m.pcolormesh(g_x,g_y,g_var,zorder = 0, cmap = 'jet') ##this is where you add the color is basemap
cbar = g_m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(g_var_name + ' ('+ g_punits + ')')
Q = plt.quiver(g_x[::2], g_y[::2], g_U[::2, ::2], g_V[::2, ::2])#, scale=.01)#,headlength=1, headaxislength=1)#, linewidth=0.5)
qk = plt.quiverkey(Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')
dlat = 2
dlon = 4
g_m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
g_m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])
plt.title('GECKO ' + g_name, y=1.08)

fig.savefig(g_name)

# %%
#### H Y C O M ####
h_path = '/Users/xfm684/Documents/Research/HYCOM/hycom_gomu_501_'
h_tail = '00_t000.nc'
h_name = '20020401'
h_test = xr.open_dataset(h_path+h_name+h_tail, decode_times=False)

limN, limS, limE, limW = 32, 18, -78, -100
h_m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')

h_var = h_test.surf_el[0,:,:]
h_var_name = "Surface Elevation"
h_punits = "meters"
h_x, h_y = m(h_test.lon,h_test.lat)

h_U = h_test.water_u[0,0,:,:]
h_V = h_test.water_v[0,0,:,:]

# %%
#### G E C K O ####
g_path = '/Users/xfm684/Documents/Research/GECKO/v_gekco2_'
g_tail = '.nc'
g_name = '20020401'
g_test = xr.open_dataset(g_path+g_name+g_tail, decode_times=False)

limN, limS, limE, limW = 32, 18, 282, 260
g_m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')

g_var = g_test.h[0,:,:]/100
g_var_name = "Surface Elevation"
g_punits = "meters"

g_x, g_y = m(g_test.lon,g_test.lat)

g_U = g_test.u[0,:,:]/100 #because it's in centimeters and I want m/s
g_V = g_test.v[0,:,:]/100

# %%
mpl.rcParams['font.size'] = 9
fig, ax = plt.subplots(figsize=(12,8), facecolor = 'w', ncols = 2)


plt.subplot(2,2,1)
h_m.drawcoastlines()
h_m.fillcontinents(color='lightgrey')
im1 = h_m.pcolormesh(h_x,h_y,h_var,zorder = 0, cmap = 'jet', vmin=-0.7, vmax=0.6) ##this is where you add the color is basemap
cbar = h_m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(h_var_name + ' ('+ h_punits + ')')
h_Q = plt.quiver(h_x[::15], h_y[::15], h_U[::15, ::15], h_V[::15, ::15], scale=30)#,headlength=1, headaxislength=1)#, linewidth=0.5)
h_qk = plt.quiverkey(h_Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')
dlat = 2
dlon = 4
h_m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
h_m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])
plt.title('HYCOM ' + h_name, y=1.08)



plt.subplot(2,2,2)
g_m.drawcoastlines()
g_m.fillcontinents(color='lightgrey')
im1 = g_m.pcolormesh(g_x,g_y,g_var,zorder = 0, cmap = 'jet') ##this is where you add the color is basemap
cbar = g_m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(g_var_name + ' ('+ g_punits + ')')
Q = plt.quiver(g_x[::2], g_y[::2], g_U[::2, ::2], g_V[::2, ::2])#, scale=.01)#,headlength=1, headaxislength=1)#, linewidth=0.5)
qk = plt.quiverkey(Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')
dlat = 2
dlon = 4
g_m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
g_m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])
plt.title('GECKO ' + g_name, y=1.08)

fig.savefig(g_name)

# %%
#### H Y C O M ####
h_path = '/Users/xfm684/Documents/Research/HYCOM/hycom_gomu_501_'
h_tail = '00_t000.nc'
h_name = '20020501'
h_test = xr.open_dataset(h_path+h_name+h_tail, decode_times=False)

limN, limS, limE, limW = 32, 18, -78, -100
h_m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')

h_var = h_test.surf_el[0,:,:]
h_var_name = "Surface Elevation"
h_punits = "meters"
h_x, h_y = m(h_test.lon,h_test.lat)

h_U = h_test.water_u[0,0,:,:]
h_V = h_test.water_v[0,0,:,:]

# %%
#### G E C K O ####
g_path = '/Users/xfm684/Documents/Research/GECKO/v_gekco2_'
g_tail = '.nc'
g_name = '20020501'
g_test = xr.open_dataset(g_path+g_name+g_tail, decode_times=False)

limN, limS, limE, limW = 32, 18, 282, 260
g_m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')

g_var = g_test.h[0,:,:]/100
g_var_name = "Surface Elevation"
g_punits = "meters"

g_x, g_y = m(g_test.lon,g_test.lat)

g_U = g_test.u[0,:,:]/100 #because it's in centimeters and I want m/s
g_V = g_test.v[0,:,:]/100

# %%
mpl.rcParams['font.size'] = 9
fig, ax = plt.subplots(figsize=(12,8), facecolor = 'w', ncols = 2)


plt.subplot(2,2,1)
h_m.drawcoastlines()
h_m.fillcontinents(color='lightgrey')
im1 = h_m.pcolormesh(h_x,h_y,h_var,zorder = 0, cmap = 'jet', vmin=-0.7, vmax=0.5) ##this is where you add the color is basemap
cbar = h_m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(h_var_name + ' ('+ h_punits + ')')
h_Q = plt.quiver(h_x[::15], h_y[::15], h_U[::15, ::15], h_V[::15, ::15], scale=30)#,headlength=1, headaxislength=1)#, linewidth=0.5)
h_qk = plt.quiverkey(h_Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')
dlat = 2
dlon = 4
h_m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
h_m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])
plt.title('HYCOM ' + h_name, y=1.08)



plt.subplot(2,2,2)
g_m.drawcoastlines()
g_m.fillcontinents(color='lightgrey')
im1 = g_m.pcolormesh(g_x,g_y,g_var,zorder = 0, cmap = 'jet') ##this is where you add the color is basemap
cbar = g_m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(g_var_name + ' ('+ g_punits + ')')
Q = plt.quiver(g_x[::2], g_y[::2], g_U[::2, ::2], g_V[::2, ::2])#, scale=.01)#,headlength=1, headaxislength=1)#, linewidth=0.5)
qk = plt.quiverkey(Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')
dlat = 2
dlon = 4
g_m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
g_m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])
plt.title('GECKO ' + g_name, y=1.08)

fig.savefig(g_name)

# %%
#### H Y C O M ####
h_path = '/Users/xfm684/Documents/Research/HYCOM/hycom_gomu_501_'
h_tail = '00_t000.nc'
h_name = '20020601'
h_test = xr.open_dataset(h_path+h_name+h_tail, decode_times=False)

limN, limS, limE, limW = 32, 18, -78, -100
h_m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')

h_var = h_test.surf_el[0,:,:]
h_var_name = "Surface Elevation"
h_punits = "meters"
h_x, h_y = m(h_test.lon,h_test.lat)

h_U = h_test.water_u[0,0,:,:]
h_V = h_test.water_v[0,0,:,:]

# %%
#### G E C K O ####
g_path = '/Users/xfm684/Documents/Research/GECKO/v_gekco2_'
g_tail = '.nc'
g_name = '20020601'
g_test = xr.open_dataset(g_path+g_name+g_tail, decode_times=False)

limN, limS, limE, limW = 32, 18, 282, 260
g_m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')

g_var = g_test.h[0,:,:]/100
g_var_name = "Surface Elevation"
g_punits = "meters"

g_x, g_y = m(g_test.lon,g_test.lat)

g_U = g_test.u[0,:,:]/100 #because it's in centimeters and I want m/s
g_V = g_test.v[0,:,:]/100

# %%
mpl.rcParams['font.size'] = 9
fig, ax = plt.subplots(figsize=(12,8), facecolor = 'w', ncols = 2)


plt.subplot(2,2,1)
h_m.drawcoastlines()
h_m.fillcontinents(color='lightgrey')
im1 = h_m.pcolormesh(h_x,h_y,h_var,zorder = 0, cmap = 'jet', vmin=-0.5, vmax=0.5) ##this is where you add the color is basemap
cbar = h_m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(h_var_name + ' ('+ h_punits + ')')
h_Q = plt.quiver(h_x[::15], h_y[::15], h_U[::15, ::15], h_V[::15, ::15], scale=30)#,headlength=1, headaxislength=1)#, linewidth=0.5)
h_qk = plt.quiverkey(h_Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')
dlat = 2
dlon = 4
h_m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
h_m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])
plt.title('HYCOM ' + h_name, y=1.08)



plt.subplot(2,2,2)
g_m.drawcoastlines()
g_m.fillcontinents(color='lightgrey')
im1 = g_m.pcolormesh(g_x,g_y,g_var,zorder = 0, cmap = 'jet') ##this is where you add the color is basemap
cbar = g_m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(g_var_name + ' ('+ g_punits + ')')
Q = plt.quiver(g_x[::2], g_y[::2], g_U[::2, ::2], g_V[::2, ::2])#, scale=.01)#,headlength=1, headaxislength=1)#, linewidth=0.5)
qk = plt.quiverkey(Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')
dlat = 2
dlon = 4
g_m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
g_m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])
plt.title('GECKO ' + g_name, y=1.08)

fig.savefig(g_name)

# %%
#### H Y C O M ####
h_path = '/Users/xfm684/Documents/Research/HYCOM/hycom_gomu_501_'
h_tail = '00_t000.nc'
h_name = '20020701'
h_test = xr.open_dataset(h_path+h_name+h_tail, decode_times=False)

limN, limS, limE, limW = 32, 18, -78, -100
h_m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')

h_var = h_test.surf_el[0,:,:]
h_var_name = "Surface Elevation"
h_punits = "meters"
h_x, h_y = m(h_test.lon,h_test.lat)

h_U = h_test.water_u[0,0,:,:]
h_V = h_test.water_v[0,0,:,:]

# %%
#### G E C K O ####
g_path = '/Users/xfm684/Documents/Research/GECKO/v_gekco2_'
g_tail = '.nc'
g_name = '20020701'
g_test = xr.open_dataset(g_path+g_name+g_tail, decode_times=False)

limN, limS, limE, limW = 32, 18, 282, 260
g_m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')

g_var = g_test.h[0,:,:]/100
g_var_name = "Surface Elevation"
g_punits = "meters"

g_x, g_y = m(g_test.lon,g_test.lat)

g_U = g_test.u[0,:,:]/100 #because it's in centimeters and I want m/s
g_V = g_test.v[0,:,:]/100

# %%
mpl.rcParams['font.size'] = 9
fig, ax = plt.subplots(figsize=(12,8), facecolor = 'w', ncols = 2)


plt.subplot(2,2,1)
h_m.drawcoastlines()
h_m.fillcontinents(color='lightgrey')
im1 = h_m.pcolormesh(h_x,h_y,h_var,zorder = 0, cmap = 'jet', vmin=-0.6, vmax=0.6) ##this is where you add the color is basemap
cbar = h_m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(h_var_name + ' ('+ h_punits + ')')
h_Q = plt.quiver(h_x[::15], h_y[::15], h_U[::15, ::15], h_V[::15, ::15], scale=30)#,headlength=1, headaxislength=1)#, linewidth=0.5)
h_qk = plt.quiverkey(h_Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')
dlat = 2
dlon = 4
h_m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
h_m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])
plt.title('HYCOM ' + h_name, y=1.08)



plt.subplot(2,2,2)
g_m.drawcoastlines()
g_m.fillcontinents(color='lightgrey')
im1 = g_m.pcolormesh(g_x,g_y,g_var,zorder = 0, cmap = 'jet') ##this is where you add the color is basemap
cbar = g_m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(g_var_name + ' ('+ g_punits + ')')
Q = plt.quiver(g_x[::2], g_y[::2], g_U[::2, ::2], g_V[::2, ::2])#, scale=.01)#,headlength=1, headaxislength=1)#, linewidth=0.5)
qk = plt.quiverkey(Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')
dlat = 2
dlon = 4
g_m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
g_m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])
plt.title('GECKO ' + g_name, y=1.08)

fig.savefig(g_name)

# %%
#### H Y C O M ####
h_path = '/Users/xfm684/Documents/Research/HYCOM/hycom_gomu_501_'
h_tail = '00_t000.nc'
h_name = '20020801'
h_test = xr.open_dataset(h_path+h_name+h_tail, decode_times=False)

limN, limS, limE, limW = 32, 18, -78, -100
h_m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')

h_var = h_test.surf_el[0,:,:]
h_var_name = "Surface Elevation"
h_punits = "meters"
h_x, h_y = m(h_test.lon,h_test.lat)

h_U = h_test.water_u[0,0,:,:]
h_V = h_test.water_v[0,0,:,:]

# %%
#### G E C K O ####
g_path = '/Users/xfm684/Documents/Research/GECKO/v_gekco2_'
g_tail = '.nc'
g_name = '20020801'
g_test = xr.open_dataset(g_path+g_name+g_tail, decode_times=False)

limN, limS, limE, limW = 32, 18, 282, 260
g_m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')

g_var = g_test.h[0,:,:]/100
g_var_name = "Surface Elevation"
g_punits = "meters"

g_x, g_y = m(g_test.lon,g_test.lat)

g_U = g_test.u[0,:,:]/100 #because it's in centimeters and I want m/s
g_V = g_test.v[0,:,:]/100

# %%
mpl.rcParams['font.size'] = 9
fig, ax = plt.subplots(figsize=(12,8), facecolor = 'w', ncols = 2)


plt.subplot(2,2,1)
h_m.drawcoastlines()
h_m.fillcontinents(color='lightgrey')
im1 = h_m.pcolormesh(h_x,h_y,h_var,zorder = 0, cmap = 'jet', vmin=-0.7, vmax=0.7) ##this is where you add the color is basemap
cbar = h_m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(h_var_name + ' ('+ h_punits + ')')
h_Q = plt.quiver(h_x[::15], h_y[::15], h_U[::15, ::15], h_V[::15, ::15], scale=30)#,headlength=1, headaxislength=1)#, linewidth=0.5)
h_qk = plt.quiverkey(h_Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')
dlat = 2
dlon = 4
h_m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
h_m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])
plt.title('HYCOM ' + h_name, y=1.08)



plt.subplot(2,2,2)
g_m.drawcoastlines()
g_m.fillcontinents(color='lightgrey')
im1 = g_m.pcolormesh(g_x,g_y,g_var,zorder = 0, cmap = 'jet') ##this is where you add the color is basemap
cbar = g_m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(g_var_name + ' ('+ g_punits + ')')
Q = plt.quiver(g_x[::2], g_y[::2], g_U[::2, ::2], g_V[::2, ::2])#, scale=.01)#,headlength=1, headaxislength=1)#, linewidth=0.5)
qk = plt.quiverkey(Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')
dlat = 2
dlon = 4
g_m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
g_m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])
plt.title('GECKO ' + g_name, y=1.08)

fig.savefig(g_name)

# %%
#### H Y C O M ####
h_path = '/Users/xfm684/Documents/Research/HYCOM/hycom_gomu_501_'
h_tail = '00_t000.nc'
h_name = '20020901'
h_test = xr.open_dataset(h_path+h_name+h_tail, decode_times=False)

limN, limS, limE, limW = 32, 18, -78, -100
h_m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')

h_var = h_test.surf_el[0,:,:]
h_var_name = "Surface Elevation"
h_punits = "meters"
h_x, h_y = m(h_test.lon,h_test.lat)

h_U = h_test.water_u[0,0,:,:]
h_V = h_test.water_v[0,0,:,:]

# %%
#### G E C K O ####
g_path = '/Users/xfm684/Documents/Research/GECKO/v_gekco2_'
g_tail = '.nc'
g_name = '20020901'
g_test = xr.open_dataset(g_path+g_name+g_tail, decode_times=False)

limN, limS, limE, limW = 32, 18, 282, 260
g_m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')

g_var = g_test.h[0,:,:]/100
g_var_name = "Surface Elevation"
g_punits = "meters"

g_x, g_y = m(g_test.lon,g_test.lat)

g_U = g_test.u[0,:,:]/100 #because it's in centimeters and I want m/s
g_V = g_test.v[0,:,:]/100

# %%
mpl.rcParams['font.size'] = 9
fig, ax = plt.subplots(figsize=(12,8), facecolor = 'w', ncols = 2)


plt.subplot(2,2,1)
h_m.drawcoastlines()
h_m.fillcontinents(color='lightgrey')
im1 = h_m.pcolormesh(h_x,h_y,h_var,zorder = 0, cmap = 'jet', vmin=-0.7, vmax=0.7) ##this is where you add the color is basemap
cbar = h_m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(h_var_name + ' ('+ h_punits + ')')
h_Q = plt.quiver(h_x[::15], h_y[::15], h_U[::15, ::15], h_V[::15, ::15], scale=30)#,headlength=1, headaxislength=1)#, linewidth=0.5)
h_qk = plt.quiverkey(h_Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')
dlat = 2
dlon = 4
h_m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
h_m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])
plt.title('HYCOM ' + h_name, y=1.08)



plt.subplot(2,2,2)
g_m.drawcoastlines()
g_m.fillcontinents(color='lightgrey')
im1 = g_m.pcolormesh(g_x,g_y,g_var,zorder = 0, cmap = 'jet') ##this is where you add the color is basemap
cbar = g_m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(g_var_name + ' ('+ g_punits + ')')
Q = plt.quiver(g_x[::2], g_y[::2], g_U[::2, ::2], g_V[::2, ::2])#, scale=.01)#,headlength=1, headaxislength=1)#, linewidth=0.5)
qk = plt.quiverkey(Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')
dlat = 2
dlon = 4
g_m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
g_m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])
plt.title('GECKO ' + g_name, y=1.08)

fig.savefig(g_name)

# %%
#### H Y C O M ####
h_path = '/Users/xfm684/Documents/Research/HYCOM/hycom_gomu_501_'
h_tail = '00_t000.nc'
h_name = '20021001'
h_test = xr.open_dataset(h_path+h_name+h_tail, decode_times=False)

limN, limS, limE, limW = 32, 18, -78, -100
h_m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')

h_var = h_test.surf_el[0,:,:]
h_var_name = "Surface Elevation"
h_punits = "meters"
h_x, h_y = m(h_test.lon,h_test.lat)

h_U = h_test.water_u[0,0,:,:]
h_V = h_test.water_v[0,0,:,:]

# %%
#### G E C K O ####
g_path = '/Users/xfm684/Documents/Research/GECKO/v_gekco2_'
g_tail = '.nc'
g_name = '20021001'
g_test = xr.open_dataset(g_path+g_name+g_tail, decode_times=False)

limN, limS, limE, limW = 32, 18, 282, 260
g_m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')

g_var = g_test.h[0,:,:]/100
g_var_name = "Surface Elevation"
g_punits = "meters"

g_x, g_y = m(g_test.lon,g_test.lat)

g_U = g_test.u[0,:,:]/100 #because it's in centimeters and I want m/s
g_V = g_test.v[0,:,:]/100

# %%
mpl.rcParams['font.size'] = 9
fig, ax = plt.subplots(figsize=(12,8), facecolor = 'w', ncols = 2)


plt.subplot(2,2,1)
h_m.drawcoastlines()
h_m.fillcontinents(color='lightgrey')
im1 = h_m.pcolormesh(h_x,h_y,h_var,zorder = 0, cmap = 'jet', vmin=-0.7, vmax=0.7) ##this is where you add the color is basemap
cbar = h_m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(h_var_name + ' ('+ h_punits + ')')
h_Q = plt.quiver(h_x[::15], h_y[::15], h_U[::15, ::15], h_V[::15, ::15], scale=30)#,headlength=1, headaxislength=1)#, linewidth=0.5)
h_qk = plt.quiverkey(h_Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')
dlat = 2
dlon = 4
h_m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
h_m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])
plt.title('HYCOM ' + h_name, y=1.08)



plt.subplot(2,2,2)
g_m.drawcoastlines()
g_m.fillcontinents(color='lightgrey')
im1 = g_m.pcolormesh(g_x,g_y,g_var,zorder = 0, cmap = 'jet') ##this is where you add the color is basemap
cbar = g_m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(g_var_name + ' ('+ g_punits + ')')
Q = plt.quiver(g_x[::2], g_y[::2], g_U[::2, ::2], g_V[::2, ::2])#, scale=.01)#,headlength=1, headaxislength=1)#, linewidth=0.5)
qk = plt.quiverkey(Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')
dlat = 2
dlon = 4
g_m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
g_m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])
plt.title('GECKO ' + g_name, y=1.08)

fig.savefig(g_name)

# %%
#### H Y C O M ####
h_path = '/Users/xfm684/Documents/Research/HYCOM/hycom_gomu_501_'
h_tail = '00_t000.nc'
h_name = '20021101'
h_test = xr.open_dataset(h_path+h_name+h_tail, decode_times=False)

limN, limS, limE, limW = 32, 18, -78, -100
h_m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')

h_var = h_test.surf_el[0,:,:]
h_var_name = "Surface Elevation"
h_punits = "meters"
h_x, h_y = m(h_test.lon,h_test.lat)

h_U = h_test.water_u[0,0,:,:]
h_V = h_test.water_v[0,0,:,:]

# %%
#### G E C K O ####
g_path = '/Users/xfm684/Documents/Research/GECKO/v_gekco2_'
g_tail = '.nc'
g_name = '20021101'
g_test = xr.open_dataset(g_path+g_name+g_tail, decode_times=False)

limN, limS, limE, limW = 32, 18, 282, 260
g_m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')

g_var = g_test.h[0,:,:]/100
g_var_name = "Surface Elevation"
g_punits = "meters"

g_x, g_y = m(g_test.lon,g_test.lat)

g_U = g_test.u[0,:,:]/100 #because it's in centimeters and I want m/s
g_V = g_test.v[0,:,:]/100

# %%
mpl.rcParams['font.size'] = 9
fig, ax = plt.subplots(figsize=(12,8), facecolor = 'w', ncols = 2)


plt.subplot(2,2,1)
h_m.drawcoastlines()
h_m.fillcontinents(color='lightgrey')
im1 = h_m.pcolormesh(h_x,h_y,h_var,zorder = 0, cmap = 'jet', vmin=-0.7, vmax=0.7) ##this is where you add the color is basemap
cbar = h_m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(h_var_name + ' ('+ h_punits + ')')
h_Q = plt.quiver(h_x[::15], h_y[::15], h_U[::15, ::15], h_V[::15, ::15], scale=30)#,headlength=1, headaxislength=1)#, linewidth=0.5)
h_qk = plt.quiverkey(h_Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')
dlat = 2
dlon = 4
h_m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
h_m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])
plt.title('HYCOM ' + h_name, y=1.08)



plt.subplot(2,2,2)
g_m.drawcoastlines()
g_m.fillcontinents(color='lightgrey')
im1 = g_m.pcolormesh(g_x,g_y,g_var,zorder = 0, cmap = 'jet') ##this is where you add the color is basemap
cbar = g_m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(g_var_name + ' ('+ g_punits + ')')
Q = plt.quiver(g_x[::2], g_y[::2], g_U[::2, ::2], g_V[::2, ::2])#, scale=.01)#,headlength=1, headaxislength=1)#, linewidth=0.5)
qk = plt.quiverkey(Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')
dlat = 2
dlon = 4
g_m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
g_m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])
plt.title('GECKO ' + g_name, y=1.08)

fig.savefig(g_name)

# %%
#### H Y C O M ####
h_path = '/Users/xfm684/Documents/Research/HYCOM/hycom_gomu_501_'
h_tail = '00_t000.nc'
h_name = '20021201'
h_test = xr.open_dataset(h_path+h_name+h_tail, decode_times=False)

limN, limS, limE, limW = 32, 18, -78, -100
h_m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')

h_var = h_test.surf_el[0,:,:]
h_var_name = "Surface Elevation"
h_punits = "meters"
h_x, h_y = m(h_test.lon,h_test.lat)

h_U = h_test.water_u[0,0,:,:]
h_V = h_test.water_v[0,0,:,:]

# %%
#### G E C K O ####
g_path = '/Users/xfm684/Documents/Research/GECKO/v_gekco2_'
g_tail = '.nc'
g_name = '20021201'
g_test = xr.open_dataset(g_path+g_name+g_tail, decode_times=False)

limN, limS, limE, limW = 32, 18, 282, 260
g_m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')

g_var = g_test.h[0,:,:]/100
g_var_name = "Surface Elevation"
g_punits = "meters"

g_x, g_y = m(g_test.lon,g_test.lat)

g_U = g_test.u[0,:,:]/100 #because it's in centimeters and I want m/s
g_V = g_test.v[0,:,:]/100

# %%
mpl.rcParams['font.size'] = 9
fig, ax = plt.subplots(figsize=(12,8), facecolor = 'w', ncols = 2)


plt.subplot(2,2,1)
h_m.drawcoastlines()
h_m.fillcontinents(color='lightgrey')
im1 = h_m.pcolormesh(h_x,h_y,h_var,zorder = 0, cmap = 'jet', vmin=-0.6, vmax=0.7) ##this is where you add the color is basemap
cbar = h_m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(h_var_name + ' ('+ h_punits + ')')
h_Q = plt.quiver(h_x[::15], h_y[::15], h_U[::15, ::15], h_V[::15, ::15], scale=30)#,headlength=1, headaxislength=1)#, linewidth=0.5)
h_qk = plt.quiverkey(h_Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')
dlat = 2
dlon = 4
h_m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
h_m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])
plt.title('HYCOM ' + h_name, y=1.08)



plt.subplot(2,2,2)
g_m.drawcoastlines()
g_m.fillcontinents(color='lightgrey')
im1 = g_m.pcolormesh(g_x,g_y,g_var,zorder = 0, cmap = 'jet') ##this is where you add the color is basemap
cbar = g_m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(g_var_name + ' ('+ g_punits + ')')
Q = plt.quiver(g_x[::2], g_y[::2], g_U[::2, ::2], g_V[::2, ::2])#, scale=.01)#,headlength=1, headaxislength=1)#, linewidth=0.5)
qk = plt.quiverkey(Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')
dlat = 2
dlon = 4
g_m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
g_m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])
plt.title('GECKO ' + g_name, y=1.08)

fig.savefig(g_name)

# %%
############################ S C R A T C H ##############################

# %%
path = '/Users/xfm684/Documents/Research/HYCOM/hycom_gomu_501_'
tail = '00_t000.nc'
name = '20020101'

# %%
test = xr.open_dataset(path+name+tail, decode_times=False)

# %%
path = '/Users/xfm684/Documents/Research/HYCOM/hycom_gomu_501_'
date = '2002*01'
tail = '00_t000.nc'

# %%
hycom2002_test = xr.open_mfdataset('/Users/xfm684/Documents/Research/HYCOM/hycom_gomu_501_2002*0100_t000.nc', decode_times=False)

# %%
hycom2002_test = xr.open_mfdataset(path + date + tail, decode_times=False)

# %%
hycom2002_test = xr.open_mfdataset('/Users/xfm684/Documents/Research/HYCOM/hycom_gomu_501_2002*', decode_times=False)

# %%
#No matter which way I do it, it's only plotting 6 identical plots...

# %%
hycom2002_test.time
#shows the 12 months for first hycome 2002 test

# %%
hycom2002_test.time

# %%
hycom2002_test.time
#third one should be all dates in 2002 which shows more with the ellipsis

# %%
hycom2002_test.time.shape[0]

# %%
for time_index in range(0, hycom2002_test.time.shape[0]):
    print(time_index)

# %%
for time_index in range(0, hycom2002_test.time.shape[0]):
    limN, limS, limE, limW = 32, 18, -78, -100
    fig = plt.figure(figsize=(8,8), facecolor = 'w')
    m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')
    m.drawcoastlines()
    m.fillcontinents(color='lightgrey')
    #data
    var = hycom2002_test.surf_el[0,:,:]
    var_name = "Surface Elevation"
    punits = "meters"
    x, y = m(hycom2002_test.lon,hycom2002_test.lat)
    #plot
    im1 = m.pcolormesh(x,y,var,zorder = 0, cmap = 'jet', vmin=-.2, vmax=.8) 
    cbar = m.colorbar(im1,location='bottom',pad="5%")
    cbar.set_label(var_name + ' ('+ punits + ')')
    #Quiver
    U = hycom2002_test.water_u[0,0,:,:]
    V = hycom2002_test.water_v[0,0,:,:]
    Q = plt.quiver(x[::11], y[::11], U[::11, ::11], V[::11, ::11])
    qk = plt.quiverkey(Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')
    #maps
    dlat = 2
    dlon = 4
    m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
    m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])
    plt.title('HYCOM', y=1.08)
    # fig.savefig('HYCOM_' + name)

# %%
########## P L O T ##############

limN, limS, limE, limW = 32, 18, -78, -100

fig = plt.figure(figsize=(8,8), facecolor = 'w')
## m is map projection
m = Basemap(projection='cyl', llcrnrlon=limW, \
      urcrnrlon=limE, llcrnrlat=limS, urcrnrlat=limN, resolution='l')
# resolution options: crude, low, intermediate, high, full

m.drawcoastlines()
m.fillcontinents(color='lightgrey')

# now add in some data:
var = test.surf_el[0,:,:]
var_name = "Surface Elevation"
punits = "meters"
## projection must be applied (m) 
x, y = m(test.lon,test.lat)
im1 = m.pcolormesh(x,y,var,zorder = 0, cmap = 'jet', vmin=-.2, vmax=.8) ##this is where you add the color is basemap
cbar = m.colorbar(im1,location='bottom',pad="5%")
cbar.set_label(var_name + ' ('+ punits + ')')

U = test.water_u[0,0,:,:]
V = test.water_v[0,0,:,:]
Q = plt.quiver(x[::11], y[::11], U[::11, ::11], V[::11, ::11])#,headlength=1, headaxislength=1)#, linewidth=0.5)
qk = plt.quiverkey(Q, 0.1,0.9,1, r'$1 \frac{m}{s}$', labelpos='W')

dlat = 2
dlon = 4
m.drawparallels(np.arange(-90.,90.,dlat), linewidth=0.5, labels=[1,0,0,0])
m.drawmeridians(np.arange(-180.,180.,dlon), linewidth=0.5, labels=[0,0,1,0])

plt.title('HYCOM ' + name, y=1.08)
# fig.savefig('HYCOM_' + name)
